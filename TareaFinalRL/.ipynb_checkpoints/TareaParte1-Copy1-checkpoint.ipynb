# %% [markdown]
# # Tarea Parte 1: Aprendiendo a jugar Pacman con TD($\lambda$)
#
# En 1992, Gerald Tesauro sorprendio al mundo con *TD-Gammon*, el primer programa de computadora que podia jugar Backgammon a un nivel cercano al de los mejores jugadores profesionales del momento.
#
# <img src='attachment:image.png' width = 250 height = 180/>
#
# TD-Gammon estaba basado en el algoritmo TD($\lambda$), una tecnica que generaliza y conecta el metodo de Monte Carlo y el metodo de *Temporal Difference Learning* que aprendimos en clase. TD-Gammon es en realidad un metodo aproximado que utiliza redes neuronales debido a la gran cantidad de estados posibles en el juego, mas informacion [aqui](http://www.bkgm.com/articles/tesauro/tdl.html). En la proxima tarea entenderan mas la idea detras de los metodos aproximados, en esta nos consentratemos en lo que corresponde a TD($\lambda$).
#
# Encontran series de preguntas y ejercicios marcados en rojo que deberan contestar y entregar.

# %% [markdown]
# ## El Algoritmo TD($\lambda$)
#
#
# La implementacion mas sencilla del algoritmo TD($\lambda$) es a traves de la siguiente version que utiliza *trazas de eligibilidad*. Podemos usar la version on-policy u off-policy del algoritmo.
#
#
# ## SARSA TD($\lambda$)  (On-policy control)
# * **Inputs**:
#     + Velocidad de aprendizaje $0 < \alpha < 1$
#     + Tasa de descuento de la utilidad en el futuro $0 < \gamma \leq 1$
#     + Parametro del algoritmo $0\leq \lambda \leq 1$ cuyo significado aun tenemos que entender.
# * **Outputs**
#     + Una tabla $Q$ donde $Q(s,a)$ es la utilidad o pago total esperado por episodio al tomar la accion $a$ en el estado $s$.
# * **Inicializar** la tabla de valor estado-accion $Q$ y la traza de elegibilidad $e$ como funcion de cada pareja estado-accion $(s,a)$.
# * **Para cada episodio** con estado-accion inicial $(s_0, a_0)$:
#     + Poner la **eligibidad en cero**, i.e., $e(s,a) = 0$  para toda pareja $(s,a)$
#     + Para cada $t$ mientras el episodio no haya terminado:
#         - **Aumentar la traza de eligibilidad** para la pareja actual $$e(s_t, a_t) = e(s_t, a_t) + 1$$
#         - **Hacer una transicion** a un nuevo estado-accion $(s_{t+1}, a_{t+1})$ obteniendo un pago $r_{t+1}$.
#         - <span style='color: blue'>**Calcular la diferencia en utilidad segun la regla SARSA**</span>
#           $$ \delta = r_{t+1} + \gamma Q(s_{t+1}, a_{t+1}) - Q(s_t,a_t) $$
#         - **Para cada pareja estado accion $(s, a)$**:
#             * **Actualizar la matriz $Q$** con la regla:
#             $$ Q(s,a) = Q(s,a) + \alpha\delta e(s,a)$$
#             * **Actualizar la traza de elegibilidad**
#             $$ e(s,a) = \lambda \gamma e(s,a) $$
#
# ## Q-Learning TD($\lambda$)  (Off-policy control)
#
# El algoritmo es practicamente identico pero la regla para calcular $\delta$ y actualizar el valor de $Q$ es:
#
# * + - <span style='color: blue'>**Calcular la diferencia en utilidad segun la regla Q-Learning**</span>:
#      $$ \delta = r_{t+1} + \gamma \left(\max_{a}Q(s_{t+1}, a)\right) - Q(s_t,a_t) $$

# %% [markdown]
# ### <span style='color: red'> Serie de preguntas 1 </span>
#
# Para las siguientes preguntas supongan que $\gamma = 1$ como usualmente suele hacerse en las tareas episodicas.
#
# 1. Verifica que si $\lambda = 0$ entonces el algoritmo anterior se converite en el metodo de *Temporal Difference Learning* que estudiamos en clase.
# 2. Verifica que con $\lambda = 1$ recuperamos un metodo similar al de Monte Carlo que estudiamos en clase (con la diferencia solamente de que la tabla $Q$ se actualiza durante los episodios y no solo al final).
# 3. Explica intuitivamente porque $e(s,a)$ es una traza de elegibilidad?
# 4. Que es $\lambda$? Intuitivamente, cual es el efecto de cambiar el valor de $\lambda$?
# 5. Esta pregunta es mas general y no tiene que ver solo con TD($\lambda$), cual es la diferencia entre control *off-policy* y *on-policy*, y que implicacion tiene al momento de elegir acciones?

# %% [markdown]
# ## Aprendiendo a jugar PacMan
#
# A continuacion tendran que hacer una implementacion del algoritmo para aprender a jugar Pacman. Les ayudate con algunas partes del codigo

# %% [markdown]
# ### 1. Cargar el juego PacMan

# %%
using PyCall 
@pyimport gym
env = gym.make("Pong-v0")
# Out:
# [2017-05-03 01:03:15,274] Making new env: Pong-v0
# PyObject <TimeLimit<AtariEnv<Pong-v0>>>

# %% [markdown]
# ### 2. Determinar el espacio de estados/observaciones y de acciones

# %% [markdown]
# El conjunto de estados es discreto. La version del juego que utilizaremos utiliza la memoria RAM, que esta hecho de 128 bytes (128 entradas y cada byte puede tener 256 valores).
#
# Hay otra version de MsPacman que utiliza pixeles en vez de RAM, pero el conjunto de estado se vuelve mas grande.

# %%
println(env[:observation_space])
# Out:
# PyObject Box(210, 160, 3)

# %% [markdown]
# En cada estado Ms Pacman puede tomar 9 posibles acciones. Realmente no necesitamos saber que significa cada accion para implementar el algoritmo.

# %%
println(env[:action_space])
# Out:
# PyObject Discrete(6)

# %%
function preprocess(arr::Array, n::Int = 5)
    arr = (.21arr[30:end,:,1] + .71arr[30:end,:,2] + .07arr[30:end,:,3]) / 255.
    h, w = size(arr)
    pre = Array{Bool}(div(h, n), div(w, n)) # preallocate size
    @inbounds for j in 1:div(w, n)
        @inbounds for i in 1:div(h, n)
              pre[i, j] = maximum(arr[(n*(i-1)+1):(i*n), (n*(j-1)+1):(j*n)]) > 0.5 ? 0 : 1
        end
    end
    join(find(pre[:]),",")
end
# Out:
# preprocess (generic function with 2 methods)

# %% [markdown]
# ### 3. Hacer simulaciones y preprocesar estados
#
# Antes de aplicar el algoritmo queremos ver que podamos hacer simulaciones.
#
# Un metodo que nos sera conveniente por el momento que no tenemos una politica entrenada es tomar acciones completamente al azar, para eso existe un metodo de muestreo de acciones (pudimos haber usado `rand(0:8)` si de antemano ya sabiamos que el espacio de acciones es de tamamo 9, las acciones comienzan numerandose en 0 por default debido a la interfaz con Python).

# %%
env[:action_space][:sample]()
# Out:
# 4

# %% [markdown]
# El siguiente codigo muestra un loop en el que se juegan 5 episodios completamente al azar (evidentemente, en todos pierde MsPacman). Es importante entender esta parte para poder aprender a jugar.

# %%
for i in 1:5 # jugar 5 episodios
    state = env[:reset]() # regresa el ambiente al comienzo de un episodio
    done = false # sera true cuando termine el episodio
    ep_reward = 0 # iniciar pago total en el episodio
    ep_steps = 0 # iniciar pasos totales en el episodio
    while !done 
        env[:render]() # crea la visualizacion del estado del juego
        action = env[:action_space][:sample]() # selecionar accion al azar
        state, reward, done, info = env[:step](action) # simula una transicion
        ep_reward += reward # agrega el pago de la transicion al pago del ep.
        ep_steps += 1 # agrega un paso al total de pasos en el episodio
    end
    println("Ep. $i terminado en $ep_steps pasos con pago $ep_reward")
end
env[:render](close = true) # es la unica forma de cerrar la visualizacion
# Out:
# Ep. 1 terminado en 1246 pasos con pago -20.0
# Ep. 2 terminado en 1254 pasos con pago -20.0
# Ep. 3 terminado en 1391 pasos con pago -20.0
# Ep. 4 terminado en 1236 pasos con pago -20.0
# Ep. 5 terminado en 1199 pasos con pago -21.0

# %% [markdown]
# Tras ver las simulaciones es evidente que no debemos incluir datos como el marcador. Para tratar de reducir el universo de estados, vamos a quitar esos pixeles.

# %% [markdown]
# ### 4. Como inicializar y manipular $Q$ y $e$
#
# La forma mas tentadora de almacenar la informacion de $Q$ y $e$ es utilizando una matriz o un vector. Muchas veces en la practica es mucho mas facil y eficiente usar *tablas hash*, que en Julia son llamadas *diccionarios*. Una tabla hash es una estructura de datos que consiste de *claves* y *valores*, asignando a cada clave un valor. Es una estructura no ordenada, a diferencia de un vector.
#
# Usualmente iniciamos los diccionarios vacios y agregamos claves la primera vez que ocurren. En problemas de reinforcement learning hay muchisimos estados que nunca son visitados y que resulta ineficiente o imposible almacenar un valor para cada estado (como en el ajedrez). Las tablas has permite solo asignar valores a las tuplas de estado-accion observables, mas similar a como aprendemos en la realidad.

# %%
Q = eligibility = Dict() # inicializa el diccionario y la funcion de eligibilidad
# Out:
# Dict{Any,Any} with 0 entries

# %% [markdown]
# Las parejas estado-accion se pueden modelar como tuplas, representadas en Julia con parentesis $(s,a)$. El siguiente ejemplo muestra como manipular $Q$ como un diccionario que tiene como claves las tuplas $(s,a)$. Se pueden usar brackets [] para accesar el valor de las claves de un diccionario en julia.

# %%
state = env[:reset]() # inicializa un episodio y guarda el estado inicial
action = env[:action_space][:sample]() # elige alguna accion al azar
println(haskey(Q, (state, action))) # consulta si existe una clave para ese (estado,accion)
# Out:
# false

# %%
Q[(state, action)] = 0 # asi asignamos valores
println(haskey(Q, (state, action))) # ahora ya tiene la clave
println(Q[(state, action)]) # asi recuperamos el valor asignado
# Out:
# true
# 0

# %% [markdown]
# Afortunadamente Julia ya tiene una manera de asignar un valor *default* en caso de que una clave nunca haya sido asignada aun, esto se logra con el metodo `get` y asignado el valor *default* como tercer argumento.

# %%
Q = Dict()
random_state, random_action = rand(2)
println(get(Q, (random_state, random_action), 0))
Q[(random_state, random_action)] = 1
println(get(Q, (random_state, random_action), 0))
# Out:
# 0
# 1

# %% [markdown]
# Un problema comun que querremos resolver es encontrar el maximo valor de $Q$ dado un estado $s$,
# iterando sobre todas las posibles acciones $a$. Este paso es esencial para determinar la decision optima segun la estimacion actual de valor
# $$\text{argmax}_a Q(s,a)$$
# Queremos mostrar como es posible programar esto en Julia con un ejemplo:

# %%
Q = Dict()
state = "I am a state"
action_space = 0:3
Q[(state, 0)] = Q[(state, 3)] = 1 # dos entradas con mayor valor
Q[(state, 1)] = Q[(state, 2)] = 0
Q
# Out:
# Dict{Any,Any} with 4 entries:
#   ("I am a state",2) => 0
#   ("I am a state",1) => 0
#   ("I am a state",3) => 1
#   ("I am a state",0) => 1

# %%
Q_values_for_state = [get(Q, (state, a), 0) for a in action_space] # ejemplo de list comprehension
max_Q_value = maximum(Q_values_for_state)
println(max_Q_value) # max_a Q(s,a)
# Out:
# 1

# %% [markdown]
# Quisieramos encontrar *todas* las parejas que dan el maximo valor de $Q$. La mayoria de los algoritmos regresan solo un valor que maximiza. Muy facilmente podriamos definir nuestra propia funcion que hiciera esto, aqui simplemente vamos a usar lo que ya existe programado usando comprehension de listas

# %% [markdown]
# ### <span style='color: red'> Ejercicio necesario </span>
# 1. Escribe una funcion llamada allindmax que devuelva los indices de todos los elementos maximos de un vector. Ni python ni julia tienen preprogramada esta funcion (as far as I know). Pueden encontrar utiles las funciones `find` y `findmax` de julia o la instruccion `value.index(max(value))` de python.

# %%
function allindmax(arr::Array)
    indmax = Int[1]
    maxval = -Inf
    for i in 2:length(arr) 
        if arr[i] > maxval
            indmax = [i]
            maxval = arr[i]
        elseif arr[i] == maxval
            push!(indmax, i)
        end          
    end
    return indmax
end
# Out:
# allindmax (generic function with 1 method)

# %% [markdown]
# ### 5. Como crear un agente (una politica) que toma decisiones optimas
#
# Los metodos que vamos a implementar son de tipo $\epsilon$-greedy, lo que significa que el agente que aprende a jugar Pacman siempre tomara una decision de acuerda a la mejor estimacion de $Q$, y con una probabilidad $\epsilon$ tomara una decision completamente aleatoria.
#
# Tradicionalmente $\epsilon$ debe comenzar con un valor muy grande durante la face inicial de aprendizaje e ir disminuyendo gradualmente. Por simplicidad, en todo nuestro codigo sera una constante dada al inicio del algoritmo, es muy facil hacer las adaptaciones necesarias para que disminuya con el tiempo.
#
# La politica es muy sencilla y debe consistir en los siguientes ingredientes:
#
# #### Ingredientes de una politica de tipo $\epsilon$-greedy:
# * **Inputs**
#     1. `state`: el estado actual en el cual se tiene que tomar una accion
#     2. `actions`: las acciones disponibles al estado `state`
#     3. `Q`: la mejor estimacion hasta el momento de la matriz `Q`, que se usara para tomar la decision greedy $$\mathrm{greedy}(\text{state}) = \mathrm{argmax}_{a\in\text{actions}} Q(\text{state}, a)$$
#     4. $\epsilon$: la probabilidad de tomar una decision completamente al azar y no greedy
# * **Output**
#     + La accion $\mathrm{policy}(\text{state})$ decidida por
#         - aleatoriamente entre cualquier accion con probabilidad $\epsilon$
#         - aleatoriamente entre las acciones que maximicen $Q(\text{state}, \cdot)$ con probabilidad $1-\epsilon$.
#
# A continuacion vemos una implementacion:

# %%
function policy(state::Any, action_space::Any, Q::Dict, ϵ::Float64)
    if rand() > ϵ # Prob(rand() > eps) = 1 - eps => Then be greedy
        state_Q_values = [get(Q, (state, a), 0.) for a in action_space] # All Q values for state and te given ations
        return(rand(action_space[allindmax(state_Q_values)])) # Random action from the actions that maximize Q for state
    else # Prob(rand() <= eps) = eps => Then take random action
        return(rand(action_space)) # Totally random actions
    end
end
# Out:
# policy (generic function with 1 method)

# %% [markdown]
# ### 6. Poner todo junto y entrenar
#
# Pudimos haber empezado por aqui, pero seria solo codigo sin saber que hace cada parte. Podemos ensamblar todo segun la receta del algoritmo y ponerlo dentro de una funcion de entrenamiento.
#
# #### Ejemplo con SARSA TD($\lambda$)

# %%
function sarsa_td_lambda(
        env, # el ambiente de open ai gym para trabajar
        Q = Dict(); # recibe Q y la sobreescribe, mejorando su estimacion
        λ = 0.1, # eligibility trace parameter
        α = 0.05, # learning rate
        γ = 1., # discount rate
        ϵ = 0.15, # exploration rate
        action_space = 0:(env[:action_space][:n] - 1), # available actions
        n_episodes = 10000, # number of episodes
        render = false, # show game visualization (much slower when rendering...)
        print_ep = true, # print results after each episode,
        max_time = 3600 # maximo 1 hora
    )
    # Outer loop for episodes
    ep_reward_hist = Float64[] # empty float array
    ep_steps_hist = Int[]
    total_time = 0.
    for i in 1:n_episodes
        tic() # comienza el reloj
        # Reset game and render
        state = env[:reset]() # regresa el ambiente al comienzo de un episodio
        state = preprocess(state)
        render && env[:render]() # si render es true, crea la visualizacion del estado del juego
        # Reset eligibility
        eligibility = Dict() # tambien regresa la traza de eligibilidad
        # Get initial action
        action = policy(state, action_space, Q, ϵ) # selecionar accion con politica
        if !haskey(Q, (state, action)) Q[(state, action)] = 0. end # add key if missing
        # Episode iteration information
        done = false # sera true cuando termine el episodio
        ep_reward = 0. # iniciar pago total en el episodio
        ep_steps = 0 # iniciar pasos totales en el episodio
        while !done 
            # Add to eligibility
            eligibility[(state, action)] = get(eligibility, (state, action), 0.) + 1.
            # Simulate transition
            new_state, reward, done, info = env[:step](action) # simula una transicion
            new_state = preprocess(new_state)
            new_action = policy(new_state, action_space, Q, ϵ) # selecionar accion con politica
            if !haskey(Q, (new_state, new_action)) Q[(new_state, new_action)] = 0. end # add key if missing
            # Compute utility difference (delta)
            δ = reward + γ*Q[(new_state, new_action)] - Q[(state, action)] 
            # Update Q and eligibity
            for (s, a) in keys(eligibility)
                Q[(s, a)] = Q[(s, a)] + α*δ
                eligibility[(s, a)] = λ*γ*eligibility[(s, a)] # no need for get si ya existe la clave
            end
            # Change new states to old states for next step
            state = new_state
            action = new_action
            # Save episode information and render if needed
            render && env[:render]()
            ep_reward += reward # agrega el pago de la transicion al pago del ep.|
            ep_steps += 1 # agrega un paso al total de pasos en el episodio
        end
        push!(ep_reward_hist, ep_reward)
        push!(ep_steps_hist, ep_steps)
        print_ep && println("Ep. $i terminado en $ep_steps pasos con pago $ep_reward") # imprime si print_ep es true
        total_time += toq() # agrega el tiempo de este episodio al tiempo total
        total_time > max_time && break
    end
    render && env[:render](close = true)
    return Q, ep_reward_hist, ep_steps_hist
end

# %% [markdown]
# Ahora corremos la funcion

# %%
Q = Dict{Tuple{String, Int}, Float32}() # Be more specific to save more time
# Out:
# Dict{Tuple{String,Int64},Float32} with 0 entries

# %%
Q, rewards, steps = sarsa_td_lambda(env, Q, λ = 0.9, ϵ = 0.1, render = true, n_episodes = 30000, max_time = 1);
# Out:
# Ep. 1 terminado en 1098 pasos con pago -21.0
#   5.995562 seconds (14.90 M allocations: 2.423 GB, 2.74% gc time)

# %%
Q, rewards, steps = sarsa_td_lambda(env, Q, λ = 0.9, ϵ = 0.1, render = true, n_episodes = 30000, max_time = 30000);
# Out:
# Ep. 1 terminado en 1372 pasos con pago -18.0
# Ep. 2 terminado en 1182 pasos con pago -21.0
# Ep. 3 terminado en 1118 pasos con pago -21.0
# Ep. 4 terminado en 1431 pasos con pago -20.0
# Ep. 5 terminado en 1273 pasos con pago -20.0
# Ep. 6 terminado en 1111 pasos con pago -21.0
# Ep. 7 terminado en 1398 pasos con pago -19.0
# Ep. 8 terminado en 1186 pasos con pago -21.0
# Ep. 9 terminado en 1310 pasos con pago -20.0
# Ep. 10 terminado en 1336 pasos con pago -20.0
# Ep. 11 terminado en 1146 pasos con pago -21.0
# Ep. 12 terminado en 1211 pasos con pago -20.0
# Ep. 13 terminado en 1311 pasos con pago -20.0
# Ep. 14 terminado en 1329 pasos con pago -20.0
# Ep. 15 terminado en 1206 pasos con pago -20.0
# Ep. 16 terminado en 1372 pasos con pago -19.0
# Ep. 17 terminado en 1127 pasos con pago -20.0
# Ep. 18 terminado en 1079 pasos con pago -21.0
# Ep. 19 terminado en 1114 pasos con pago -21.0
# Ep. 20 terminado en 1377 pasos con pago -20.0
# Ep. 21 terminado en 1142 pasos con pago -21.0
# Ep. 22 terminado en 1335 pasos con pago -21.0
# Ep. 23 terminado en 1138 pasos con pago -21.0
# Ep. 24 terminado en 1124 pasos con pago -21.0
# Ep. 25 terminado en 1021 pasos con pago -21.0
# Ep. 26 terminado en 1266 pasos con pago -20.0
# Ep. 27 terminado en 1182 pasos con pago -21.0
# Ep. 28 terminado en 1304 pasos con pago -20.0
# Ep. 29 terminado en 1062 pasos con pago -21.0
# Ep. 30 terminado en 1494 pasos con pago -18.0
# Ep. 31 terminado en 1185 pasos con pago -21.0
# Ep. 32 terminado en 1391 pasos con pago -19.0
# Ep. 33 terminado en 1438 pasos con pago -20.0
# Ep. 34 terminado en 1139 pasos con pago -21.0
# Ep. 35 terminado en 1234 pasos con pago -20.0
# Ep. 36 terminado en 1461 pasos con pago -20.0
# Ep. 37 terminado en 1178 pasos con pago -21.0
# Ep. 38 terminado en 1094 pasos con pago -21.0
# Ep. 39 terminado en 1414 pasos con pago -19.0
# Ep. 40 terminado en 1180 pasos con pago -21.0
# Ep. 41 terminado en 1067 pasos con pago -21.0
# Ep. 42 terminado en 1121 pasos con pago -21.0
# Ep. 43 terminado en 1342 pasos con pago -20.0
# Ep. 44 terminado en 1293 pasos con pago -19.0
# Ep. 45 terminado en 1193 pasos con pago -21.0
# Ep. 46 terminado en 1266 pasos con pago -21.0
# Ep. 47 terminado en 1301 pasos con pago -20.0
# Ep. 48 terminado en 1389 pasos con pago -18.0
# Ep. 49 terminado en 1125 pasos con pago -21.0
# Ep. 50 terminado en 1160 pasos con pago -21.0
# Ep. 51 terminado en 1202 pasos con pago -20.0
# Ep. 52 terminado en 1252 pasos con pago -19.0
# Ep. 53 terminado en 1157 pasos con pago -20.0
# Ep. 54 terminado en 1090 pasos con pago -21.0
# Ep. 55 terminado en 1189 pasos con pago -21.0
# Ep. 56 terminado en 1378 pasos con pago -20.0
# Ep. 57 terminado en 1395 pasos con pago -19.0
# Ep. 58 terminado en 1245 pasos con pago -20.0
# Ep. 59 terminado en 1225 pasos con pago -20.0
# Ep. 60 terminado en 1312 pasos con pago -20.0
# Ep. 61 terminado en 1335 pasos con pago -19.0
# Ep. 62 terminado en 1062 pasos con pago -21.0
# Ep. 63 terminado en 1213 pasos con pago -20.0
# Ep. 64 terminado en 1270 pasos con pago -20.0
# Ep. 65 terminado en 1089 pasos con pago -21.0
# Ep. 66 terminado en 1324 pasos con pago -19.0
# Ep. 67 terminado en 1064 pasos con pago -21.0
# Ep. 68 terminado en 1281 pasos con pago -21.0
# Ep. 69 terminado en 1470 pasos con pago -19.0
# Ep. 70 terminado en 1265 pasos con pago -19.0
# Ep. 71 terminado en 1100 pasos con pago -21.0
# Ep. 72 terminado en 1238 pasos con pago -20.0
# Ep. 73 terminado en 1320 pasos con pago -20.0
# Ep. 74 terminado en 1220 pasos con pago -20.0
# Ep. 75 terminado en 1057 pasos con pago -21.0
# Ep. 76 terminado en 1334 pasos con pago -21.0
# Ep. 77 terminado en 1305 pasos con pago -19.0
# Ep. 78 terminado en 1279 pasos con pago -20.0
# Ep. 79 terminado en 1444 pasos con pago -18.0
# Ep. 80 terminado en 1245 pasos con pago -19.0
# Ep. 81 terminado en 1075 pasos con pago -21.0
# Ep. 82 terminado en 1723 pasos con pago -16.0
# Ep. 83 terminado en 1453 pasos con pago -18.0
# Ep. 84 terminado en 1223 pasos con pago -20.0
# Ep. 85 terminado en 1158 pasos con pago -21.0
# Ep. 86 terminado en 1250 pasos con pago -19.0
# Ep. 87 terminado en 1374 pasos con pago -21.0
# Ep. 88 terminado en 1238 pasos con pago -19.0
# Ep. 89 terminado en 1341 pasos con pago -20.0
# Ep. 90 terminado en 1017 pasos con pago -21.0
# Ep. 91 terminado en 1234 pasos con pago -21.0
# Ep. 92 terminado en 1499 pasos con pago -18.0
# Ep. 93 terminado en 1220 pasos con pago -20.0
# Ep. 94 terminado en 1371 pasos con pago -19.0
# Ep. 95 terminado en 1056 pasos con pago -21.0
# Ep. 96 terminado en 1252 pasos con pago -21.0
# Ep. 97 terminado en 1498 pasos con pago -20.0
# Ep. 98 terminado en 1390 pasos con pago -20.0
# Ep. 99 terminado en 1211 pasos con pago -21.0
# Ep. 100 terminado en 1302 pasos con pago -19.0
# Ep. 101 terminado en 1199 pasos con pago -21.0
# Ep. 102 terminado en 1350 pasos con pago -19.0
# Ep. 103 terminado en 1278 pasos con pago -19.0
# Ep. 104 terminado en 1053 pasos con pago -21.0
# Ep. 105 terminado en 1012 pasos con pago -21.0
# Ep. 106 terminado en 1264 pasos con pago -21.0
# Ep. 107 terminado en 1261 pasos con pago -21.0
# Ep. 108 terminado en 1018 pasos con pago -21.0
# Ep. 109 terminado en 1499 pasos con pago -19.0
# Ep. 110 terminado en 1232 pasos con pago -20.0
# Ep. 111 terminado en 1301 pasos con pago -21.0
# Ep. 112 terminado en 1138 pasos con pago -21.0
# Ep. 113 terminado en 1239 pasos con pago -20.0
# Ep. 114 terminado en 1053 pasos con pago -21.0
# Ep. 115 terminado en 1302 pasos con pago -19.0
# Ep. 116 terminado en 1086 pasos con pago -21.0
# Ep. 117 terminado en 1104 pasos con pago -21.0
# Ep. 118 terminado en 1370 pasos con pago -21.0
# Ep. 119 terminado en 1121 pasos con pago -20.0
# Ep. 120 terminado en 1205 pasos con pago -20.0
# Ep. 121 terminado en 1225 pasos con pago -21.0
# Ep. 122 terminado en 1266 pasos con pago -19.0
# Ep. 123 terminado en 1487 pasos con pago -18.0
# Ep. 124 terminado en 1293 pasos con pago -20.0
# Ep. 125 terminado en 1314 pasos con pago -20.0
# Ep. 126 terminado en 1242 pasos con pago -21.0
# Ep. 127 terminado en 1303 pasos con pago -21.0
# Ep. 128 terminado en 1090 pasos con pago -21.0
# Ep. 129 terminado en 1126 pasos con pago -21.0
# Ep. 130 terminado en 1323 pasos con pago -21.0
# Ep. 131 terminado en 1638 pasos con pago -19.0
# Ep. 132 terminado en 1180 pasos con pago -21.0
# Ep. 133 terminado en 1322 pasos con pago -20.0
# Ep. 134 terminado en 1217 pasos con pago -20.0
# Ep. 135 terminado en 1240 pasos con pago -20.0
# Ep. 136 terminado en 1186 pasos con pago -21.0
# Ep. 137 terminado en 1165 pasos con pago -20.0
# Ep. 138 terminado en 1143 pasos con pago -21.0
# Ep. 139 terminado en 1015 pasos con pago -21.0
# Ep. 140 terminado en 1125 pasos con pago -20.0
# Ep. 141 terminado en 1214 pasos con pago -20.0
# Ep. 142 terminado en 1396 pasos con pago -19.0
# Ep. 143 terminado en 1107 pasos con pago -21.0
# Ep. 144 terminado en 1207 pasos con pago -21.0
# Ep. 145 terminado en 1407 pasos con pago -18.0
# Ep. 146 terminado en 1131 pasos con pago -20.0
# Ep. 147 terminado en 1125 pasos con pago -21.0
# Ep. 148 terminado en 1175 pasos con pago -20.0
# Ep. 149 terminado en 1350 pasos con pago -19.0
# Ep. 150 terminado en 1273 pasos con pago -19.0
# Ep. 151 terminado en 1236 pasos con pago -20.0
# Ep. 152 terminado en 1148 pasos con pago -20.0
# Ep. 153 terminado en 1086 pasos con pago -21.0
# Ep. 154 terminado en 1151 pasos con pago -21.0
# Ep. 155 terminado en 1382 pasos con pago -19.0
# Ep. 156 terminado en 1209 pasos con pago -21.0
# Ep. 157 terminado en 1525 pasos con pago -20.0
# Ep. 158 terminado en 1466 pasos con pago -19.0
# Ep. 159 terminado en 1192 pasos con pago -20.0
# Ep. 160 terminado en 1617 pasos con pago -17.0
# Ep. 161 terminado en 1241 pasos con pago -20.0
# Ep. 162 terminado en 1489 pasos con pago -19.0
# Ep. 163 terminado en 1201 pasos con pago -21.0
# Ep. 164 terminado en 1198 pasos con pago -21.0
# Ep. 165 terminado en 1046 pasos con pago -21.0
# Ep. 166 terminado en 1269 pasos con pago -19.0
# Ep. 167 terminado en 1027 pasos con pago -21.0
# Ep. 168 terminado en 1444 pasos con pago -18.0
# Ep. 169 terminado en 1108 pasos con pago -21.0
# Ep. 170 terminado en 1366 pasos con pago -19.0
# Ep. 171 terminado en 1219 pasos con pago -21.0
# Ep. 172 terminado en 1528 pasos con pago -18.0
# Ep. 173 terminado en 1208 pasos con pago -21.0
# Ep. 174 terminado en 1379 pasos con pago -19.0
# Ep. 175 terminado en 1177 pasos con pago -21.0
# Ep. 176 terminado en 1708 pasos con pago -18.0
# Ep. 177 terminado en 1028 pasos con pago -21.0
# Ep. 178 terminado en 1145 pasos con pago -21.0
# Ep. 179 terminado en 1129 pasos con pago -21.0
# Ep. 180 terminado en 1156 pasos con pago -20.0
# Ep. 181 terminado en 1136 pasos con pago -20.0
# Ep. 182 terminado en 1237 pasos con pago -20.0
# Ep. 183 terminado en 1080 pasos con pago -21.0
# Ep. 184 terminado en 1234 pasos con pago -20.0
# Ep. 185 terminado en 1089 pasos con pago -21.0
# Ep. 186 terminado en 1213 pasos con pago -21.0
# Ep. 187 terminado en 1433 pasos con pago -19.0
# Ep. 188 terminado en 1377 pasos con pago -19.0
# Ep. 189 terminado en 1139 pasos con pago -21.0
# Ep. 190 terminado en 1322 pasos con pago -20.0
# Ep. 191 terminado en 1692 pasos con pago -18.0
# Ep. 192 terminado en 1254 pasos con pago -19.0
# Ep. 193 terminado en 1169 pasos con pago -21.0
# Ep. 194 terminado en 1110 pasos con pago -21.0
# Ep. 195 terminado en 1311 pasos con pago -20.0
# Ep. 196 terminado en 1214 pasos con pago -20.0
# Ep. 197 terminado en 1040 pasos con pago -21.0
# Ep. 198 terminado en 1212 pasos con pago -21.0
# Ep. 199 terminado en 1121 pasos con pago -20.0
# Ep. 200 terminado en 1320 pasos con pago -19.0
# Ep. 201 terminado en 1060 pasos con pago -21.0
# Ep. 202 terminado en 1014 pasos con pago -21.0
# Ep. 203 terminado en 1418 pasos con pago -19.0
# Ep. 204 terminado en 1327 pasos con pago -19.0
# Ep. 205 terminado en 1141 pasos con pago -21.0
# Ep. 206 terminado en 1100 pasos con pago -21.0
# Ep. 207 terminado en 1247 pasos con pago -21.0
# Ep. 208 terminado en 1198 pasos con pago -20.0
# Ep. 209 terminado en 1184 pasos con pago -21.0
# Ep. 210 terminado en 1216 pasos con pago -21.0
# Ep. 211 terminado en 1270 pasos con pago -21.0
# Ep. 212 terminado en 1017 pasos con pago -21.0
# Ep. 213 terminado en 1160 pasos con pago -21.0
# Ep. 214 terminado en 1264 pasos con pago -19.0
# Ep. 215 terminado en 1265 pasos con pago -19.0
# Ep. 216 terminado en 1252 pasos con pago -21.0
# Ep. 217 terminado en 1370 pasos con pago -21.0
# Ep. 218 terminado en 1080 pasos con pago -21.0
# Ep. 219 terminado en 1137 pasos con pago -21.0
# Ep. 220 terminado en 1021 pasos con pago -21.0
# Ep. 221 terminado en 1264 pasos con pago -20.0
# Ep. 222 terminado en 1293 pasos con pago -20.0
# Ep. 223 terminado en 1123 pasos con pago -20.0
# Ep. 224 terminado en 1406 pasos con pago -20.0
# Ep. 225 terminado en 1137 pasos con pago -21.0
# Ep. 226 terminado en 1215 pasos con pago -21.0
# Ep. 227 terminado en 1165 pasos con pago -21.0
# Ep. 228 terminado en 1209 pasos con pago -20.0
# Ep. 229 terminado en 1019 pasos con pago -21.0
# Ep. 230 terminado en 1101 pasos con pago -21.0
# Ep. 231 terminado en 1192 pasos con pago -21.0
# Ep. 232 terminado en 1076 pasos con pago -21.0
# Ep. 233 terminado en 1507 pasos con pago -21.0
# Ep. 234 terminado en 1320 pasos con pago -19.0
# Ep. 235 terminado en 1510 pasos con pago -18.0
# Ep. 236 terminado en 1267 pasos con pago -19.0
# Ep. 237 terminado en 1224 pasos con pago -20.0
# Ep. 238 terminado en 1209 pasos con pago -20.0
# Ep. 239 terminado en 1040 pasos con pago -21.0
# Ep. 240 terminado en 1332 pasos con pago -20.0
# Ep. 241 terminado en 1210 pasos con pago -20.0
# Ep. 242 terminado en 1035 pasos con pago -21.0
# Ep. 243 terminado en 1119 pasos con pago -20.0
# Ep. 244 terminado en 1048 pasos con pago -21.0
# Ep. 245 terminado en 1237 pasos con pago -20.0
# Ep. 246 terminado en 1152 pasos con pago -20.0
# Ep. 247 terminado en 1091 pasos con pago -21.0
# Ep. 248 terminado en 1176 pasos con pago -20.0
# Ep. 249 terminado en 1290 pasos con pago -19.0
# Ep. 250 terminado en 1411 pasos con pago -21.0
# Ep. 251 terminado en 1191 pasos con pago -21.0
# Ep. 252 terminado en 1429 pasos con pago -18.0
# Ep. 253 terminado en 1047 pasos con pago -21.0
# Ep. 254 terminado en 1087 pasos con pago -21.0
# Ep. 255 terminado en 1225 pasos con pago -20.0
# Ep. 256 terminado en 1133 pasos con pago -21.0
# Ep. 257 terminado en 1298 pasos con pago -20.0
# Ep. 258 terminado en 1058 pasos con pago -21.0
# Ep. 259 terminado en 1167 pasos con pago -20.0
# Ep. 260 terminado en 1380 pasos con pago -21.0
# Ep. 261 terminado en 1507 pasos con pago -21.0
# Ep. 262 terminado en 1215 pasos con pago -20.0
# Ep. 263 terminado en 1092 pasos con pago -21.0
# Ep. 264 terminado en 1283 pasos con pago -20.0
# Ep. 265 terminado en 1214 pasos con pago -21.0
# Ep. 266 terminado en 1021 pasos con pago -21.0
# Ep. 267 terminado en 1222 pasos con pago -20.0
# Ep. 268 terminado en 1158 pasos con pago -20.0
# Ep. 269 terminado en 1064 pasos con pago -21.0
# Ep. 270 terminado en 1147 pasos con pago -21.0
# Ep. 271 terminado en 1362 pasos con pago -20.0
# Ep. 272 terminado en 1398 pasos con pago -21.0
# Ep. 273 terminado en 1114 pasos con pago -21.0
# Ep. 274 terminado en 1231 pasos con pago -20.0
# Ep. 275 terminado en 1317 pasos con pago -20.0
# Ep. 276 terminado en 1287 pasos con pago -20.0
# Ep. 277 terminado en 1266 pasos con pago -21.0
# Ep. 278 terminado en 1300 pasos con pago -21.0
# Ep. 279 terminado en 1249 pasos con pago -20.0
# Ep. 280 terminado en 1338 pasos con pago -21.0
# Ep. 281 terminado en 1177 pasos con pago -20.0
# Ep. 282 terminado en 1210 pasos con pago -20.0
# Ep. 283 terminado en 1287 pasos con pago -20.0
# Ep. 284 terminado en 1198 pasos con pago -20.0
# Ep. 285 terminado en 1342 pasos con pago -21.0
# Ep. 286 terminado en 1154 pasos con pago -20.0
# Ep. 287 terminado en 1151 pasos con pago -21.0
# Ep. 288 terminado en 1257 pasos con pago -20.0
# Ep. 289 terminado en 1247 pasos con pago -21.0
# Ep. 290 terminado en 1362 pasos con pago -21.0
# Ep. 291 terminado en 1024 pasos con pago -21.0
# Ep. 292 terminado en 1218 pasos con pago -21.0
# Ep. 293 terminado en 1108 pasos con pago -21.0
# Ep. 294 terminado en 1332 pasos con pago -20.0
# Ep. 295 terminado en 1321 pasos con pago -20.0
# Ep. 296 terminado en 1373 pasos con pago -19.0
# Ep. 297 terminado en 1126 pasos con pago -21.0
# Ep. 298 terminado en 1260 pasos con pago -19.0
# Ep. 299 terminado en 1053 pasos con pago -21.0
# Ep. 300 terminado en 1394 pasos con pago -19.0
# Ep. 301 terminado en 1276 pasos con pago -20.0
# Ep. 302 terminado en 1086 pasos con pago -21.0
# Ep. 303 terminado en 1301 pasos con pago -19.0
# Ep. 304 terminado en 1158 pasos con pago -20.0
# Ep. 305 terminado en 1117 pasos con pago -21.0
# Ep. 306 terminado en 1124 pasos con pago -20.0
# Ep. 307 terminado en 1099 pasos con pago -21.0
# Ep. 308 terminado en 1254 pasos con pago -19.0
# Ep. 309 terminado en 1412 pasos con pago -19.0
# Ep. 310 terminado en 1125 pasos con pago -20.0
# Ep. 311 terminado en 1153 pasos con pago -21.0
# Ep. 312 terminado en 1503 pasos con pago -18.0
# Ep. 313 terminado en 1158 pasos con pago -21.0
# Ep. 314 terminado en 1204 pasos con pago -21.0
# Ep. 315 terminado en 1096 pasos con pago -21.0
# Ep. 316 terminado en 1049 pasos con pago -21.0
# Ep. 317 terminado en 1180 pasos con pago -20.0
# Ep. 318 terminado en 1112 pasos con pago -21.0
# Ep. 319 terminado en 1057 pasos con pago -21.0
# Ep. 320 terminado en 1097 pasos con pago -21.0
# Ep. 321 terminado en 1097 pasos con pago -21.0
# Ep. 322 terminado en 1007 pasos con pago -21.0
# Ep. 323 terminado en 1169 pasos con pago -21.0
# Ep. 324 terminado en 1285 pasos con pago -20.0
# Ep. 325 terminado en 1108 pasos con pago -21.0
# Ep. 326 terminado en 1452 pasos con pago -20.0
# Ep. 327 terminado en 1384 pasos con pago -20.0
# Ep. 328 terminado en 1344 pasos con pago -21.0
# Ep. 329 terminado en 1019 pasos con pago -21.0
# Ep. 330 terminado en 1187 pasos con pago -20.0
# Ep. 331 terminado en 1406 pasos con pago -19.0
# Ep. 332 terminado en 1304 pasos con pago -20.0
# Ep. 333 terminado en 1362 pasos con pago -20.0
# Ep. 334 terminado en 1483 pasos con pago -19.0
# Ep. 335 terminado en 1145 pasos con pago -21.0
# Ep. 336 terminado en 1335 pasos con pago -20.0
# Ep. 337 terminado en 1450 pasos con pago -20.0
# Ep. 338 terminado en 1358 pasos con pago -21.0
# Ep. 339 terminado en 1096 pasos con pago -21.0
# Ep. 340 terminado en 1131 pasos con pago -21.0
# Ep. 341 terminado en 1586 pasos con pago -18.0
# Ep. 342 terminado en 1158 pasos con pago -21.0
# Ep. 343 terminado en 1126 pasos con pago -20.0
# Ep. 344 terminado en 1125 pasos con pago -21.0
# Ep. 345 terminado en 1268 pasos con pago -20.0
# Ep. 346 terminado en 1054 pasos con pago -21.0
# Ep. 347 terminado en 1173 pasos con pago -21.0
# Ep. 348 terminado en 1172 pasos con pago -21.0
# Ep. 349 terminado en 1143 pasos con pago -20.0
# Ep. 350 terminado en 1055 pasos con pago -21.0
# Ep. 351 terminado en 1088 pasos con pago -21.0
# Ep. 352 terminado en 1142 pasos con pago -21.0
# Ep. 353 terminado en 1095 pasos con pago -21.0
# Ep. 354 terminado en 1261 pasos con pago -21.0
# Ep. 355 terminado en 1179 pasos con pago -20.0
# Ep. 356 terminado en 1014 pasos con pago -21.0
# Ep. 357 terminado en 1167 pasos con pago -20.0
# Ep. 358 terminado en 1075 pasos con pago -21.0
# Ep. 359 terminado en 1089 pasos con pago -21.0
# Ep. 360 terminado en 1599 pasos con pago -18.0
# Ep. 361 terminado en 1380 pasos con pago -20.0
# Ep. 362 terminado en 1020 pasos con pago -21.0
# Ep. 363 terminado en 1068 pasos con pago -21.0
# Ep. 364 terminado en 1261 pasos con pago -20.0
# Ep. 365 terminado en 1184 pasos con pago -20.0
# Ep. 366 terminado en 1159 pasos con pago -20.0
# Ep. 367 terminado en 1455 pasos con pago -20.0
# Ep. 368 terminado en 1339 pasos con pago -20.0
# Ep. 369 terminado en 1382 pasos con pago -19.0
# Ep. 370 terminado en 1556 pasos con pago -18.0
# Ep. 371 terminado en 1122 pasos con pago -21.0
# Ep. 372 terminado en 1210 pasos con pago -21.0
# Ep. 373 terminado en 1277 pasos con pago -20.0
# Ep. 374 terminado en 1017 pasos con pago -21.0
# Ep. 375 terminado en 1189 pasos con pago -21.0
# Ep. 376 terminado en 1228 pasos con pago -20.0
# Ep. 377 terminado en 1147 pasos con pago -21.0
# Ep. 378 terminado en 1134 pasos con pago -21.0
# Ep. 379 terminado en 1184 pasos con pago -21.0
# Ep. 380 terminado en 1102 pasos con pago -21.0
# Ep. 381 terminado en 1058 pasos con pago -21.0
# Ep. 382 terminado en 1237 pasos con pago -21.0
# Ep. 383 terminado en 1207 pasos con pago -20.0
# Ep. 384 terminado en 1634 pasos con pago -17.0
# Ep. 385 terminado en 1481 pasos con pago -19.0
# Ep. 386 terminado en 1248 pasos con pago -20.0
# Ep. 387 terminado en 1370 pasos con pago -21.0
# Ep. 388 terminado en 1243 pasos con pago -21.0
# Ep. 389 terminado en 1183 pasos con pago -20.0
# Ep. 390 terminado en 1288 pasos con pago -20.0
# Ep. 391 terminado en 1168 pasos con pago -21.0
# Ep. 392 terminado en 1128 pasos con pago -21.0
# Ep. 393 terminado en 1047 pasos con pago -21.0
# Ep. 394 terminado en 1097 pasos con pago -21.0
# Ep. 395 terminado en 1241 pasos con pago -20.0
# Ep. 396 terminado en 1449 pasos con pago -19.0
# Ep. 397 terminado en 1128 pasos con pago -21.0
# Ep. 398 terminado en 1371 pasos con pago -20.0
# Ep. 399 terminado en 1268 pasos con pago -19.0
# Ep. 400 terminado en 1371 pasos con pago -20.0
# Ep. 401 terminado en 1010 pasos con pago -21.0
# Ep. 402 terminado en 1230 pasos con pago -21.0
# Ep. 403 terminado en 1307 pasos con pago -19.0
# Ep. 404 terminado en 1352 pasos con pago -20.0
# Ep. 405 terminado en 1274 pasos con pago -21.0
# Ep. 406 terminado en 1021 pasos con pago -21.0
# Ep. 407 terminado en 1170 pasos con pago -21.0
# Ep. 408 terminado en 1122 pasos con pago -20.0
# Ep. 409 terminado en 1380 pasos con pago -20.0
# Ep. 410 terminado en 1373 pasos con pago -19.0
# Ep. 411 terminado en 1187 pasos con pago -21.0
# Ep. 412 terminado en 1164 pasos con pago -21.0
# Ep. 413 terminado en 1284 pasos con pago -19.0
# Ep. 414 terminado en 1264 pasos con pago -21.0
# Ep. 415 terminado en 1139 pasos con pago -20.0
# Ep. 416 terminado en 1367 pasos con pago -21.0
# Ep. 417 terminado en 1256 pasos con pago -19.0
# Ep. 418 terminado en 1019 pasos con pago -21.0
# Ep. 419 terminado en 1151 pasos con pago -21.0
# Ep. 420 terminado en 1310 pasos con pago -21.0
# Ep. 421 terminado en 1428 pasos con pago -19.0
# Ep. 422 terminado en 1152 pasos con pago -20.0
# Ep. 423 terminado en 1318 pasos con pago -20.0
# Ep. 424 terminado en 1335 pasos con pago -21.0
# Ep. 425 terminado en 1149 pasos con pago -21.0
# Ep. 426 terminado en 1106 pasos con pago -21.0
# Ep. 427 terminado en 1076 pasos con pago -21.0
# Ep. 428 terminado en 1173 pasos con pago -21.0
# Ep. 429 terminado en 1238 pasos con pago -21.0
# Ep. 430 terminado en 1184 pasos con pago -20.0
# Ep. 431 terminado en 1569 pasos con pago -20.0
# Ep. 432 terminado en 1257 pasos con pago -21.0
# Ep. 433 terminado en 1464 pasos con pago -19.0
# Ep. 434 terminado en 1528 pasos con pago -19.0
# Ep. 435 terminado en 1144 pasos con pago -20.0
# Ep. 436 terminado en 1060 pasos con pago -21.0
# Ep. 437 terminado en 1277 pasos con pago -20.0
# Ep. 438 terminado en 1060 pasos con pago -21.0
# Ep. 439 terminado en 1199 pasos con pago -21.0
# Ep. 440 terminado en 1754 pasos con pago -16.0
# Ep. 441 terminado en 1179 pasos con pago -21.0
# Ep. 442 terminado en 1123 pasos con pago -21.0
# Ep. 443 terminado en 1129 pasos con pago -21.0
# Ep. 444 terminado en 1338 pasos con pago -20.0
# Ep. 445 terminado en 1274 pasos con pago -20.0
# Ep. 446 terminado en 1254 pasos con pago -19.0
# Ep. 447 terminado en 1011 pasos con pago -21.0
# Ep. 448 terminado en 1163 pasos con pago -20.0
# Ep. 449 terminado en 1269 pasos con pago -20.0
# Ep. 450 terminado en 1166 pasos con pago -20.0
# Ep. 451 terminado en 1208 pasos con pago -20.0
# Ep. 452 terminado en 1152 pasos con pago -20.0
# Ep. 453 terminado en 1161 pasos con pago -21.0
# Ep. 454 terminado en 1297 pasos con pago -20.0
# Ep. 455 terminado en 1234 pasos con pago -20.0
# Ep. 456 terminado en 1130 pasos con pago -21.0
# Ep. 457 terminado en 1121 pasos con pago -20.0
# Ep. 458 terminado en 1173 pasos con pago -21.0
# Ep. 459 terminado en 1139 pasos con pago -20.0
# Ep. 460 terminado en 1190 pasos con pago -20.0
# Ep. 461 terminado en 1058 pasos con pago -21.0
# Ep. 462 terminado en 1157 pasos con pago -21.0
# Ep. 463 terminado en 1277 pasos con pago -20.0
# Ep. 464 terminado en 1092 pasos con pago -21.0
# Ep. 465 terminado en 1419 pasos con pago -18.0
# Ep. 466 terminado en 1111 pasos con pago -21.0
# Ep. 467 terminado en 1395 pasos con pago -19.0
# Ep. 468 terminado en 1129 pasos con pago -21.0
# Ep. 469 terminado en 1208 pasos con pago -21.0
# Ep. 470 terminado en 1465 pasos con pago -20.0
# Ep. 471 terminado en 1029 pasos con pago -21.0
# Ep. 472 terminado en 1161 pasos con pago -20.0
# Ep. 473 terminado en 1299 pasos con pago -19.0
# Ep. 474 terminado en 1004 pasos con pago -21.0
# Ep. 475 terminado en 1339 pasos con pago -19.0
# Ep. 476 terminado en 1178 pasos con pago -20.0
# Ep. 477 terminado en 1157 pasos con pago -20.0
# Ep. 478 terminado en 1253 pasos con pago -19.0
# Ep. 479 terminado en 1204 pasos con pago -21.0
# Ep. 480 terminado en 1129 pasos con pago -21.0
# Ep. 481 terminado en 1140 pasos con pago -21.0
# Ep. 482 terminado en 1352 pasos con pago -20.0
# Ep. 483 terminado en 1487 pasos con pago -19.0
# Ep. 484 terminado en 1307 pasos con pago -19.0
# Ep. 485 terminado en 1106 pasos con pago -21.0
# Ep. 486 terminado en 1412 pasos con pago -19.0
# Ep. 487 terminado en 1124 pasos con pago -20.0
# Ep. 488 terminado en 1118 pasos con pago -20.0
# Ep. 489 terminado en 1052 pasos con pago -21.0
# Ep. 490 terminado en 1300 pasos con pago -21.0
# Ep. 491 terminado en 1320 pasos con pago -19.0
# Ep. 492 terminado en 1476 pasos con pago -20.0
# Ep. 493 terminado en 1131 pasos con pago -20.0
# Ep. 494 terminado en 1338 pasos con pago -20.0
# Ep. 495 terminado en 1516 pasos con pago -20.0
# Ep. 496 terminado en 1287 pasos con pago -20.0
# Ep. 497 terminado en 1113 pasos con pago -20.0
# Ep. 498 terminado en 1152 pasos con pago -21.0
# Ep. 499 terminado en 1382 pasos con pago -19.0
# Ep. 500 terminado en 1312 pasos con pago -19.0
# Ep. 501 terminado en 1230 pasos con pago -20.0
# Ep. 502 terminado en 1362 pasos con pago -20.0
# Ep. 503 terminado en 1328 pasos con pago -20.0
# Ep. 504 terminado en 1197 pasos con pago -20.0
# Ep. 505 terminado en 1127 pasos con pago -21.0
# Ep. 506 terminado en 1129 pasos con pago -20.0
# Ep. 507 terminado en 1110 pasos con pago -21.0
# Ep. 508 terminado en 1445 pasos con pago -18.0
# Ep. 509 terminado en 1231 pasos con pago -21.0
# Ep. 510 terminado en 1246 pasos con pago -21.0
# Ep. 511 terminado en 1383 pasos con pago -20.0
# Ep. 512 terminado en 1015 pasos con pago -21.0
# Ep. 513 terminado en 1264 pasos con pago -19.0
# Ep. 514 terminado en 1136 pasos con pago -21.0
# Ep. 515 terminado en 1154 pasos con pago -20.0
# Ep. 516 terminado en 1494 pasos con pago -19.0
# Ep. 517 terminado en 1206 pasos con pago -21.0
# Ep. 518 terminado en 1488 pasos con pago -19.0
# Ep. 519 terminado en 1567 pasos con pago -19.0
# Ep. 520 terminado en 1416 pasos con pago -19.0
# Ep. 521 terminado en 1214 pasos con pago -21.0
# Ep. 522 terminado en 1386 pasos con pago -21.0
# Ep. 523 terminado en 1335 pasos con pago -20.0
# Ep. 524 terminado en 1257 pasos con pago -21.0
# Ep. 525 terminado en 1375 pasos con pago -21.0
# Ep. 526 terminado en 1031 pasos con pago -21.0
# Ep. 527 terminado en 1624 pasos con pago -19.0
# Ep. 528 terminado en 1368 pasos con pago -20.0
# Ep. 529 terminado en 1287 pasos con pago -20.0
# Ep. 530 terminado en 1209 pasos con pago -20.0
# Ep. 531 terminado en 1138 pasos con pago -21.0
# Ep. 532 terminado en 1175 pasos con pago -21.0
# Ep. 533 terminado en 1428 pasos con pago -20.0
# Ep. 534 terminado en 1153 pasos con pago -20.0
# Ep. 535 terminado en 1212 pasos con pago -21.0
# Ep. 536 terminado en 1278 pasos con pago -20.0
# Ep. 537 terminado en 1351 pasos con pago -19.0
# Ep. 538 terminado en 1287 pasos con pago -21.0
# Ep. 539 terminado en 1406 pasos con pago -20.0
# Ep. 540 terminado en 1304 pasos con pago -20.0
# Ep. 541 terminado en 1173 pasos con pago -21.0
# Ep. 542 terminado en 1204 pasos con pago -21.0
# Ep. 543 terminado en 1200 pasos con pago -20.0
# Ep. 544 terminado en 1117 pasos con pago -20.0
# Ep. 545 terminado en 1514 pasos con pago -19.0
# Ep. 546 terminado en 1447 pasos con pago -19.0
# Ep. 547 terminado en 1213 pasos con pago -21.0
# Ep. 548 terminado en 1542 pasos con pago -20.0
# Ep. 549 terminado en 1399 pasos con pago -19.0
# Ep. 550 terminado en 1253 pasos con pago -20.0
# Ep. 551 terminado en 1544 pasos con pago -20.0
# Ep. 552 terminado en 1099 pasos con pago -21.0
# Ep. 553 terminado en 1311 pasos con pago -20.0
# Ep. 554 terminado en 1090 pasos con pago -21.0
# Ep. 555 terminado en 1249 pasos con pago -20.0
# Ep. 556 terminado en 1314 pasos con pago -20.0
# Ep. 557 terminado en 1021 pasos con pago -21.0
# Ep. 558 terminado en 1230 pasos con pago -20.0
# Ep. 559 terminado en 1350 pasos con pago -20.0
# Ep. 560 terminado en 1273 pasos con pago -21.0
# Ep. 561 terminado en 1258 pasos con pago -20.0
# Ep. 562 terminado en 1249 pasos con pago -21.0
# Ep. 563 terminado en 1419 pasos con pago -20.0
# Ep. 564 terminado en 1110 pasos con pago -21.0
# Ep. 565 terminado en 1078 pasos con pago -21.0
# Ep. 566 terminado en 1192 pasos con pago -21.0
# Ep. 567 terminado en 1024 pasos con pago -21.0
# Ep. 568 terminado en 1208 pasos con pago -20.0
# Ep. 569 terminado en 1371 pasos con pago -20.0
# Ep. 570 terminado en 1225 pasos con pago -20.0
# Ep. 571 terminado en 1444 pasos con pago -20.0
# Ep. 572 terminado en 1469 pasos con pago -20.0
# Ep. 573 terminado en 1204 pasos con pago -20.0
# Ep. 574 terminado en 1308 pasos con pago -20.0
# Ep. 575 terminado en 1196 pasos con pago -21.0
# Ep. 576 terminado en 1273 pasos con pago -20.0
# Ep. 577 terminado en 1544 pasos con pago -19.0
# Ep. 578 terminado en 1010 pasos con pago -21.0
# Ep. 579 terminado en 1043 pasos con pago -21.0
# Ep. 580 terminado en 1141 pasos con pago -21.0
# Ep. 581 terminado en 1519 pasos con pago -19.0
# Ep. 582 terminado en 1234 pasos con pago -20.0
# Ep. 583 terminado en 1117 pasos con pago -21.0
# Ep. 584 terminado en 1254 pasos con pago -20.0
# Ep. 585 terminado en 1173 pasos con pago -20.0
# Ep. 586 terminado en 1076 pasos con pago -21.0
# Ep. 587 terminado en 1131 pasos con pago -21.0
# Ep. 588 terminado en 1087 pasos con pago -21.0
# Ep. 589 terminado en 1246 pasos con pago -20.0
# Ep. 590 terminado en 1319 pasos con pago -20.0
# Ep. 591 terminado en 1025 pasos con pago -21.0
# Ep. 592 terminado en 1594 pasos con pago -17.0
# Ep. 593 terminado en 1133 pasos con pago -21.0
# Ep. 594 terminado en 1327 pasos con pago -21.0
# Ep. 595 terminado en 1516 pasos con pago -18.0
# Ep. 596 terminado en 1025 pasos con pago -21.0
# Ep. 597 terminado en 1112 pasos con pago -20.0
# Ep. 598 terminado en 1265 pasos con pago -20.0
# Ep. 599 terminado en 1304 pasos con pago -20.0
# Ep. 600 terminado en 1235 pasos con pago -20.0
# Ep. 601 terminado en 1468 pasos con pago -20.0
# Ep. 602 terminado en 1179 pasos con pago -21.0
# Ep. 603 terminado en 1350 pasos con pago -20.0
# Ep. 604 terminado en 1066 pasos con pago -21.0
# Ep. 605 terminado en 1222 pasos con pago -21.0
# Ep. 606 terminado en 1459 pasos con pago -19.0
# Ep. 607 terminado en 1319 pasos con pago -19.0
# Ep. 608 terminado en 1111 pasos con pago -21.0
# Ep. 609 terminado en 1146 pasos con pago -21.0
# Ep. 610 terminado en 1057 pasos con pago -21.0
# Ep. 611 terminado en 1201 pasos con pago -21.0
# Ep. 612 terminado en 1321 pasos con pago -19.0
# Ep. 613 terminado en 1291 pasos con pago -19.0
# Ep. 614 terminado en 1286 pasos con pago -19.0
# Ep. 615 terminado en 1698 pasos con pago -18.0
# Ep. 616 terminado en 1652 pasos con pago -17.0
# Ep. 617 terminado en 1233 pasos con pago -20.0
# Ep. 618 terminado en 1117 pasos con pago -20.0
# Ep. 619 terminado en 1179 pasos con pago -21.0
# Ep. 620 terminado en 1125 pasos con pago -20.0
# Ep. 621 terminado en 1134 pasos con pago -20.0
# Ep. 622 terminado en 1225 pasos con pago -20.0
# Ep. 623 terminado en 1059 pasos con pago -21.0
# Ep. 624 terminado en 1208 pasos con pago -20.0
# Ep. 625 terminado en 1297 pasos con pago -20.0
# Ep. 626 terminado en 1191 pasos con pago -21.0
# Ep. 627 terminado en 1101 pasos con pago -21.0
# Ep. 628 terminado en 1494 pasos con pago -19.0
# Ep. 629 terminado en 1226 pasos con pago -21.0
# Ep. 630 terminado en 1080 pasos con pago -21.0
# Ep. 631 terminado en 1232 pasos con pago -21.0
# Ep. 632 terminado en 1188 pasos con pago -21.0
# Ep. 633 terminado en 1236 pasos con pago -20.0
# Ep. 634 terminado en 1345 pasos con pago -20.0
# Ep. 635 terminado en 1266 pasos con pago -21.0
# Ep. 636 terminado en 1070 pasos con pago -21.0
# Ep. 637 terminado en 1220 pasos con pago -21.0
# Ep. 638 terminado en 1212 pasos con pago -21.0
# Ep. 639 terminado en 1218 pasos con pago -21.0
# Ep. 640 terminado en 1045 pasos con pago -21.0
# Ep. 641 terminado en 1341 pasos con pago -21.0
# Ep. 642 terminado en 1202 pasos con pago -20.0
# Ep. 643 terminado en 1025 pasos con pago -21.0
# Ep. 644 terminado en 1296 pasos con pago -20.0
# Ep. 645 terminado en 1129 pasos con pago -20.0
# Ep. 646 terminado en 1011 pasos con pago -21.0
# Ep. 647 terminado en 1404 pasos con pago -21.0
# Ep. 648 terminado en 1141 pasos con pago -21.0
# Ep. 649 terminado en 1316 pasos con pago -19.0
# Ep. 650 terminado en 1183 pasos con pago -21.0
# Ep. 651 terminado en 1710 pasos con pago -18.0
# Ep. 652 terminado en 1176 pasos con pago -20.0
# Ep. 653 terminado en 1552 pasos con pago -18.0
# Ep. 654 terminado en 1242 pasos con pago -21.0
# Ep. 655 terminado en 1454 pasos con pago -20.0
# Ep. 656 terminado en 1379 pasos con pago -21.0
# Ep. 657 terminado en 1228 pasos con pago -20.0
# Ep. 658 terminado en 1224 pasos con pago -21.0
# Ep. 659 terminado en 1285 pasos con pago -21.0
# Ep. 660 terminado en 1172 pasos con pago -20.0
# Ep. 661 terminado en 1106 pasos con pago -21.0
# Ep. 662 terminado en 1211 pasos con pago -20.0
# Ep. 663 terminado en 1023 pasos con pago -21.0
# Ep. 664 terminado en 1060 pasos con pago -21.0
# Ep. 665 terminado en 1025 pasos con pago -21.0
# Ep. 666 terminado en 1285 pasos con pago -20.0
# Ep. 667 terminado en 1197 pasos con pago -20.0
# Ep. 668 terminado en 1310 pasos con pago -19.0
# Ep. 669 terminado en 1255 pasos con pago -19.0
# Ep. 670 terminado en 1427 pasos con pago -20.0
# Ep. 671 terminado en 1717 pasos con pago -18.0
# Ep. 672 terminado en 1204 pasos con pago -20.0
# Ep. 673 terminado en 1169 pasos con pago -20.0
# Ep. 674 terminado en 1127 pasos con pago -20.0
# Ep. 675 terminado en 1074 pasos con pago -21.0
# Ep. 676 terminado en 1145 pasos con pago -21.0
# Ep. 677 terminado en 1537 pasos con pago -20.0
# Ep. 678 terminado en 1133 pasos con pago -20.0
# Ep. 679 terminado en 1205 pasos con pago -21.0
# Ep. 680 terminado en 1338 pasos con pago -20.0
# Ep. 681 terminado en 1089 pasos con pago -21.0
# Ep. 682 terminado en 1198 pasos con pago -20.0
# Ep. 683 terminado en 1062 pasos con pago -21.0
# Ep. 684 terminado en 1363 pasos con pago -20.0
# Ep. 685 terminado en 1385 pasos con pago -20.0
# Ep. 686 terminado en 1324 pasos con pago -20.0
# Ep. 687 terminado en 1538 pasos con pago -17.0
# Ep. 688 terminado en 1270 pasos con pago -20.0
# Ep. 689 terminado en 1358 pasos con pago -19.0
# Ep. 690 terminado en 1176 pasos con pago -21.0
# Ep. 691 terminado en 1248 pasos con pago -20.0
# Ep. 692 terminado en 1269 pasos con pago -20.0
# Ep. 693 terminado en 1481 pasos con pago -20.0
# Ep. 694 terminado en 1131 pasos con pago -21.0
# Ep. 695 terminado en 1563 pasos con pago -19.0
# Ep. 696 terminado en 1053 pasos con pago -21.0
# Ep. 697 terminado en 1460 pasos con pago -20.0
# Ep. 698 terminado en 1447 pasos con pago -20.0
# Ep. 699 terminado en 1194 pasos con pago -21.0
# Ep. 700 terminado en 1376 pasos con pago -19.0
# Ep. 701 terminado en 1200 pasos con pago -21.0
# Ep. 702 terminado en 1397 pasos con pago -20.0
# Ep. 703 terminado en 1191 pasos con pago -20.0
# Ep. 704 terminado en 1303 pasos con pago -20.0
# Ep. 705 terminado en 1247 pasos con pago -19.0
# Ep. 706 terminado en 1287 pasos con pago -20.0
# Ep. 707 terminado en 1261 pasos con pago -21.0
# Ep. 708 terminado en 1269 pasos con pago -20.0
# Ep. 709 terminado en 1357 pasos con pago -20.0
# Ep. 710 terminado en 1017 pasos con pago -21.0
# Ep. 711 terminado en 1113 pasos con pago -21.0
# Ep. 712 terminado en 1240 pasos con pago -19.0
# Ep. 713 terminado en 1113 pasos con pago -21.0
# Ep. 714 terminado en 1191 pasos con pago -20.0
# Ep. 715 terminado en 1267 pasos con pago -20.0
# Ep. 716 terminado en 1089 pasos con pago -21.0
# Ep. 717 terminado en 1138 pasos con pago -21.0
# Ep. 718 terminado en 1198 pasos con pago -20.0
# Ep. 719 terminado en 1217 pasos con pago -20.0
# Ep. 720 terminado en 1039 pasos con pago -21.0
# Ep. 721 terminado en 1208 pasos con pago -21.0
# Ep. 722 terminado en 1201 pasos con pago -20.0
# Ep. 723 terminado en 1118 pasos con pago -20.0
# Ep. 724 terminado en 1277 pasos con pago -21.0
# Ep. 725 terminado en 1142 pasos con pago -20.0
# Ep. 726 terminado en 1149 pasos con pago -21.0
# Ep. 727 terminado en 1055 pasos con pago -21.0
# Ep. 728 terminado en 1226 pasos con pago -19.0
# Ep. 729 terminado en 1090 pasos con pago -21.0
# Ep. 730 terminado en 1369 pasos con pago -20.0
# Ep. 731 terminado en 1218 pasos con pago -20.0
# Ep. 732 terminado en 1319 pasos con pago -19.0
# Ep. 733 terminado en 1201 pasos con pago -20.0
# Ep. 734 terminado en 1628 pasos con pago -18.0
# Ep. 735 terminado en 999 pasos con pago -21.0
# Ep. 736 terminado en 1412 pasos con pago -20.0
# Ep. 737 terminado en 1199 pasos con pago -20.0
# Ep. 738 terminado en 1050 pasos con pago -21.0
# Ep. 739 terminado en 1290 pasos con pago -20.0
# Ep. 740 terminado en 1168 pasos con pago -21.0
# Ep. 741 terminado en 1719 pasos con pago -18.0
# Ep. 742 terminado en 1344 pasos con pago -19.0
# Ep. 743 terminado en 1513 pasos con pago -19.0
# Ep. 744 terminado en 1227 pasos con pago -20.0
# Ep. 745 terminado en 1316 pasos con pago -20.0
# Ep. 746 terminado en 1405 pasos con pago -20.0
# Ep. 747 terminado en 1237 pasos con pago -20.0
# Ep. 748 terminado en 1191 pasos con pago -21.0
# Ep. 749 terminado en 1215 pasos con pago -21.0
# Ep. 750 terminado en 1106 pasos con pago -21.0
# Ep. 751 terminado en 1485 pasos con pago -20.0
# Ep. 752 terminado en 1033 pasos con pago -21.0
# Ep. 753 terminado en 1072 pasos con pago -21.0
# Ep. 754 terminado en 1118 pasos con pago -20.0
# Ep. 755 terminado en 1136 pasos con pago -21.0
# Ep. 756 terminado en 1483 pasos con pago -17.0
# Ep. 757 terminado en 1056 pasos con pago -21.0
# Ep. 758 terminado en 1123 pasos con pago -20.0
# Ep. 759 terminado en 1217 pasos con pago -21.0
# Ep. 760 terminado en 1465 pasos con pago -19.0
# Ep. 761 terminado en 1268 pasos con pago -20.0
# Ep. 762 terminado en 1359 pasos con pago -19.0
# Ep. 763 terminado en 1443 pasos con pago -19.0
# Ep. 764 terminado en 1410 pasos con pago -19.0
# Ep. 765 terminado en 1036 pasos con pago -21.0
# Ep. 766 terminado en 1216 pasos con pago -21.0
# Ep. 767 terminado en 1055 pasos con pago -21.0
# Ep. 768 terminado en 1157 pasos con pago -21.0
# Ep. 769 terminado en 1028 pasos con pago -21.0
# Ep. 770 terminado en 1116 pasos con pago -20.0
# Ep. 771 terminado en 1102 pasos con pago -21.0
# Ep. 772 terminado en 1627 pasos con pago -20.0
# Ep. 773 terminado en 1741 pasos con pago -20.0
# Ep. 774 terminado en 1124 pasos con pago -21.0
# Ep. 775 terminado en 1112 pasos con pago -21.0
# Ep. 776 terminado en 1478 pasos con pago -20.0
# Ep. 777 terminado en 1346 pasos con pago -19.0
# Ep. 778 terminado en 1068 pasos con pago -21.0
# Ep. 779 terminado en 1476 pasos con pago -19.0
# Ep. 780 terminado en 1300 pasos con pago -20.0
# Ep. 781 terminado en 1074 pasos con pago -21.0
# Ep. 782 terminado en 1281 pasos con pago -20.0
# Ep. 783 terminado en 1328 pasos con pago -21.0
# Ep. 784 terminado en 1224 pasos con pago -21.0
# Ep. 785 terminado en 1098 pasos con pago -21.0
# Ep. 786 terminado en 1085 pasos con pago -21.0
# Ep. 787 terminado en 1126 pasos con pago -21.0
# Ep. 788 terminado en 1086 pasos con pago -21.0
# Ep. 789 terminado en 1247 pasos con pago -20.0
# Ep. 790 terminado en 1177 pasos con pago -21.0
# Ep. 791 terminado en 1481 pasos con pago -20.0
# Ep. 792 terminado en 1770 pasos con pago -17.0
# Ep. 793 terminado en 1078 pasos con pago -21.0
# Ep. 794 terminado en 1314 pasos con pago -20.0
# Ep. 795 terminado en 1211 pasos con pago -20.0
# Ep. 796 terminado en 1099 pasos con pago -21.0
# Ep. 797 terminado en 1410 pasos con pago -18.0
# Ep. 798 terminado en 1060 pasos con pago -21.0
# Ep. 799 terminado en 1430 pasos con pago -20.0
# Ep. 800 terminado en 1627 pasos con pago -17.0
# Ep. 801 terminado en 1146 pasos con pago -21.0
# Ep. 802 terminado en 1219 pasos con pago -20.0
# Ep. 803 terminado en 1362 pasos con pago -19.0
# Ep. 804 terminado en 1207 pasos con pago -21.0
# Ep. 805 terminado en 1440 pasos con pago -21.0
# Ep. 806 terminado en 1100 pasos con pago -21.0
# Ep. 807 terminado en 1343 pasos con pago -20.0
# Ep. 808 terminado en 1324 pasos con pago -20.0
# Ep. 809 terminado en 1299 pasos con pago -20.0
# Ep. 810 terminado en 1087 pasos con pago -21.0
# Ep. 811 terminado en 1235 pasos con pago -20.0
# Ep. 812 terminado en 1306 pasos con pago -20.0
# Ep. 813 terminado en 1523 pasos con pago -21.0
# Ep. 814 terminado en 1009 pasos con pago -21.0
# Ep. 815 terminado en 1112 pasos con pago -20.0
# Ep. 816 terminado en 1690 pasos con pago -18.0
# Ep. 817 terminado en 1418 pasos con pago -21.0
# Ep. 818 terminado en 1153 pasos con pago -21.0
# Ep. 819 terminado en 1211 pasos con pago -20.0
# Ep. 820 terminado en 1195 pasos con pago -20.0
# Ep. 821 terminado en 1344 pasos con pago -19.0
# Ep. 822 terminado en 1264 pasos con pago -21.0
# Ep. 823 terminado en 1060 pasos con pago -21.0
# Ep. 824 terminado en 1191 pasos con pago -21.0
# Ep. 825 terminado en 1285 pasos con pago -20.0
# Ep. 826 terminado en 1173 pasos con pago -21.0
# Ep. 827 terminado en 1347 pasos con pago -20.0
# Ep. 828 terminado en 1343 pasos con pago -20.0
# Ep. 829 terminado en 1263 pasos con pago -20.0
# Ep. 830 terminado en 1234 pasos con pago -21.0
# Ep. 831 terminado en 1632 pasos con pago -19.0
# Ep. 832 terminado en 1305 pasos con pago -21.0
# Ep. 833 terminado en 1020 pasos con pago -21.0
# Ep. 834 terminado en 1290 pasos con pago -21.0
# Ep. 835 terminado en 1313 pasos con pago -21.0
# Ep. 836 terminado en 1458 pasos con pago -20.0
# Ep. 837 terminado en 1277 pasos con pago -21.0
# Ep. 838 terminado en 1372 pasos con pago -19.0
# Ep. 839 terminado en 1012 pasos con pago -21.0
# Ep. 840 terminado en 1108 pasos con pago -21.0
# Ep. 841 terminado en 1474 pasos con pago -19.0
# Ep. 842 terminado en 1406 pasos con pago -19.0
# Ep. 843 terminado en 1324 pasos con pago -21.0
# Ep. 844 terminado en 1252 pasos con pago -20.0
# Ep. 845 terminado en 1355 pasos con pago -21.0
# Ep. 846 terminado en 1015 pasos con pago -21.0
# Ep. 847 terminado en 1175 pasos con pago -21.0
# Ep. 848 terminado en 1252 pasos con pago -21.0
# Ep. 849 terminado en 1155 pasos con pago -20.0
# Ep. 850 terminado en 1151 pasos con pago -20.0
# Ep. 851 terminado en 1235 pasos con pago -20.0
# Ep. 852 terminado en 1490 pasos con pago -20.0
# Ep. 853 terminado en 1183 pasos con pago -21.0
# Ep. 854 terminado en 1198 pasos con pago -20.0
# Ep. 855 terminado en 1237 pasos con pago -20.0
# Ep. 856 terminado en 1269 pasos con pago -20.0
# Ep. 857 terminado en 1217 pasos con pago -20.0
# Ep. 858 terminado en 1108 pasos con pago -21.0
# Ep. 859 terminado en 1372 pasos con pago -19.0
# Ep. 860 terminado en 1239 pasos con pago -20.0
# Ep. 861 terminado en 1216 pasos con pago -21.0
# Ep. 862 terminado en 1262 pasos con pago -20.0
# Ep. 863 terminado en 1233 pasos con pago -20.0
# Ep. 864 terminado en 1346 pasos con pago -20.0
# Ep. 865 terminado en 1322 pasos con pago -20.0
# Ep. 866 terminado en 1537 pasos con pago -20.0
# Ep. 867 terminado en 1433 pasos con pago -20.0
# Ep. 868 terminado en 1172 pasos con pago -21.0
# Ep. 869 terminado en 1504 pasos con pago -19.0
# Ep. 870 terminado en 1267 pasos con pago -21.0
# Ep. 871 terminado en 1418 pasos con pago -19.0
# Ep. 872 terminado en 1200 pasos con pago -20.0
# Ep. 873 terminado en 1384 pasos con pago -19.0
# Ep. 874 terminado en 1588 pasos con pago -17.0
# Ep. 875 terminado en 1157 pasos con pago -20.0
# Ep. 876 terminado en 1339 pasos con pago -21.0
# Ep. 877 terminado en 1076 pasos con pago -21.0
# Ep. 878 terminado en 1085 pasos con pago -21.0
# Ep. 879 terminado en 1570 pasos con pago -18.0
# Ep. 880 terminado en 1348 pasos con pago -21.0
# Ep. 881 terminado en 1101 pasos con pago -21.0
# Ep. 882 terminado en 1185 pasos con pago -20.0
# Ep. 883 terminado en 1598 pasos con pago -19.0
# Ep. 884 terminado en 1129 pasos con pago -21.0
# Ep. 885 terminado en 1092 pasos con pago -21.0
# Ep. 886 terminado en 1313 pasos con pago -19.0
# Ep. 887 terminado en 1355 pasos con pago -20.0
# Ep. 888 terminado en 1162 pasos con pago -21.0
# Ep. 889 terminado en 1396 pasos con pago -21.0
# Ep. 890 terminado en 1062 pasos con pago -21.0
# Ep. 891 terminado en 1212 pasos con pago -20.0
# Ep. 892 terminado en 1442 pasos con pago -18.0
# Ep. 893 terminado en 1155 pasos con pago -21.0
# Ep. 894 terminado en 1272 pasos con pago -21.0
# Ep. 895 terminado en 1210 pasos con pago -21.0
# Ep. 896 terminado en 1142 pasos con pago -21.0
# Ep. 897 terminado en 1328 pasos con pago -19.0
# Ep. 898 terminado en 1175 pasos con pago -21.0
# Ep. 899 terminado en 1174 pasos con pago -21.0
# Ep. 900 terminado en 1190 pasos con pago -20.0
# Ep. 901 terminado en 1246 pasos con pago -19.0
# Ep. 902 terminado en 1390 pasos con pago -19.0
# Ep. 903 terminado en 1477 pasos con pago -19.0
# Ep. 904 terminado en 1280 pasos con pago -20.0
# Ep. 905 terminado en 1518 pasos con pago -18.0
# Ep. 906 terminado en 1538 pasos con pago -18.0
# Ep. 907 terminado en 1377 pasos con pago -21.0
# Ep. 908 terminado en 1489 pasos con pago -19.0
# Ep. 909 terminado en 1158 pasos con pago -20.0
# Ep. 910 terminado en 1442 pasos con pago -20.0
# Ep. 911 terminado en 1120 pasos con pago -21.0
# Ep. 912 terminado en 1174 pasos con pago -20.0
# Ep. 913 terminado en 1175 pasos con pago -21.0
# Ep. 914 terminado en 1173 pasos con pago -21.0
# Ep. 915 terminado en 1024 pasos con pago -21.0
# Ep. 916 terminado en 1048 pasos con pago -21.0
# Ep. 917 terminado en 1152 pasos con pago -20.0
# Ep. 918 terminado en 1181 pasos con pago -20.0
# Ep. 919 terminado en 1314 pasos con pago -20.0
# Ep. 920 terminado en 1045 pasos con pago -21.0
# Ep. 921 terminado en 1183 pasos con pago -21.0
# Ep. 922 terminado en 1223 pasos con pago -20.0
# Ep. 923 terminado en 1211 pasos con pago -21.0
# Ep. 924 terminado en 1169 pasos con pago -21.0
# Ep. 925 terminado en 1163 pasos con pago -21.0
# Ep. 926 terminado en 1172 pasos con pago -20.0
# Ep. 927 terminado en 1180 pasos con pago -21.0
# Ep. 928 terminado en 1168 pasos con pago -21.0
# Ep. 929 terminado en 1137 pasos con pago -21.0
# Ep. 930 terminado en 1116 pasos con pago -20.0
# Ep. 931 terminado en 1113 pasos con pago -21.0
# Ep. 932 terminado en 1250 pasos con pago -21.0
# Ep. 933 terminado en 1029 pasos con pago -21.0
# Ep. 934 terminado en 1443 pasos con pago -19.0
# Ep. 935 terminado en 1770 pasos con pago -18.0
# Ep. 936 terminado en 1052 pasos con pago -21.0
# Ep. 937 terminado en 1438 pasos con pago -18.0
# Ep. 938 terminado en 1243 pasos con pago -20.0
# Ep. 939 terminado en 1055 pasos con pago -21.0
# Ep. 940 terminado en 1510 pasos con pago -18.0
# Ep. 941 terminado en 1092 pasos con pago -21.0
# Ep. 942 terminado en 1223 pasos con pago -20.0
# Ep. 943 terminado en 1151 pasos con pago -21.0
# Ep. 944 terminado en 1157 pasos con pago -20.0
# Ep. 945 terminado en 1433 pasos con pago -18.0
# Ep. 946 terminado en 1183 pasos con pago -20.0
# Ep. 947 terminado en 1486 pasos con pago -20.0
# Ep. 948 terminado en 1328 pasos con pago -20.0
# Ep. 949 terminado en 1688 pasos con pago -16.0
# Ep. 950 terminado en 1322 pasos con pago -20.0
# Ep. 951 terminado en 1461 pasos con pago -18.0
# Ep. 952 terminado en 1181 pasos con pago -21.0
# Ep. 953 terminado en 1389 pasos con pago -19.0
# Ep. 954 terminado en 1247 pasos con pago -19.0
# Ep. 955 terminado en 1462 pasos con pago -20.0
# Ep. 956 terminado en 1264 pasos con pago -20.0
# Ep. 957 terminado en 1066 pasos con pago -21.0
# Ep. 958 terminado en 1435 pasos con pago -19.0
# Ep. 959 terminado en 1341 pasos con pago -19.0
# Ep. 960 terminado en 1271 pasos con pago -20.0
# Ep. 961 terminado en 1275 pasos con pago -20.0
# Ep. 962 terminado en 1119 pasos con pago -20.0
# Ep. 963 terminado en 1260 pasos con pago -20.0
# Ep. 964 terminado en 1584 pasos con pago -18.0
# Ep. 965 terminado en 1363 pasos con pago -19.0
# Ep. 966 terminado en 1141 pasos con pago -21.0
# Ep. 967 terminado en 1503 pasos con pago -18.0
# Ep. 968 terminado en 1229 pasos con pago -20.0
# Ep. 969 terminado en 1059 pasos con pago -21.0
# Ep. 970 terminado en 1394 pasos con pago -20.0
# Ep. 971 terminado en 1283 pasos con pago -20.0
# Ep. 972 terminado en 1381 pasos con pago -20.0
# Ep. 973 terminado en 1268 pasos con pago -20.0
# Ep. 974 terminado en 1020 pasos con pago -21.0
# Ep. 975 terminado en 1048 pasos con pago -21.0
# Ep. 976 terminado en 1366 pasos con pago -21.0
# Ep. 977 terminado en 1321 pasos con pago -20.0
# Ep. 978 terminado en 1610 pasos con pago -18.0
# Ep. 979 terminado en 1088 pasos con pago -21.0
# Ep. 980 terminado en 1447 pasos con pago -19.0
# Ep. 981 terminado en 1255 pasos con pago -21.0
# Ep. 982 terminado en 1184 pasos con pago -20.0
# Ep. 983 terminado en 1178 pasos con pago -21.0
# Ep. 984 terminado en 1295 pasos con pago -20.0
# Ep. 985 terminado en 1148 pasos con pago -20.0
# Ep. 986 terminado en 1163 pasos con pago -21.0
# Ep. 987 terminado en 1173 pasos con pago -21.0
# Ep. 988 terminado en 1194 pasos con pago -21.0
# Ep. 989 terminado en 1143 pasos con pago -21.0
# Ep. 990 terminado en 1117 pasos con pago -20.0
# Ep. 991 terminado en 1279 pasos con pago -20.0
# Ep. 992 terminado en 1402 pasos con pago -20.0
# Ep. 993 terminado en 1502 pasos con pago -19.0
# Ep. 994 terminado en 1243 pasos con pago -20.0
# Ep. 995 terminado en 1340 pasos con pago -19.0
# Ep. 996 terminado en 1429 pasos con pago -18.0
# Ep. 997 terminado en 1333 pasos con pago -20.0
# Ep. 998 terminado en 1418 pasos con pago -19.0
# Ep. 999 terminado en 1605 pasos con pago -20.0
# Ep. 1000 terminado en 1488 pasos con pago -18.0
# Ep. 1001 terminado en 1146 pasos con pago -21.0
# Ep. 1002 terminado en 1508 pasos con pago -18.0
# Ep. 1003 terminado en 1170 pasos con pago -21.0
# Ep. 1004 terminado en 1331 pasos con pago -20.0
# Ep. 1005 terminado en 1215 pasos con pago -20.0
# Ep. 1006 terminado en 1320 pasos con pago -20.0
# Ep. 1007 terminado en 1098 pasos con pago -21.0
# Ep. 1008 terminado en 1107 pasos con pago -21.0
# Ep. 1009 terminado en 1445 pasos con pago -19.0
# Ep. 1010 terminado en 1175 pasos con pago -21.0
# Ep. 1011 terminado en 1630 pasos con pago -19.0
# Ep. 1012 terminado en 1164 pasos con pago -21.0
# Ep. 1013 terminado en 1355 pasos con pago -20.0
# Ep. 1014 terminado en 1055 pasos con pago -21.0
# Ep. 1015 terminado en 1169 pasos con pago -21.0
# Ep. 1016 terminado en 1121 pasos con pago -21.0
# Ep. 1017 terminado en 1042 pasos con pago -21.0
# Ep. 1018 terminado en 1483 pasos con pago -19.0
# Ep. 1019 terminado en 1116 pasos con pago -21.0
# Ep. 1020 terminado en 1260 pasos con pago -21.0
# Ep. 1021 terminado en 1100 pasos con pago -21.0
# Ep. 1022 terminado en 1176 pasos con pago -21.0
# Ep. 1023 terminado en 1087 pasos con pago -21.0
# ...
# Ep. 2466 terminado en 1051 pasos con pago -21.0
# Ep. 2467 terminado en 1210 pasos con pago -21.0
# Ep. 2468 terminado en 1094 pasos con pago -21.0
# Ep. 2469 terminado en 1188 pasos con pago -21.0
# Ep. 2470 terminado en 1338 pasos con pago -20.0
# Ep. 2471 terminado en 1376 pasos con pago -20.0
# Ep. 2472 terminado en 1122 pasos con pago -21.0
# Ep. 2473 terminado en 1165 pasos con pago -21.0
# Ep. 2474 terminado en 1439 pasos con pago -20.0
# Ep. 2475 terminado en 1348 pasos con pago -19.0
# Ep. 2476 terminado en 1264 pasos con pago -19.0
# Ep. 2477 terminado en 1309 pasos con pago -19.0
# Ep. 2478 terminado en 1273 pasos con pago -21.0
# Ep. 2479 terminado en 1292 pasos con pago -20.0
# Ep. 2480 terminado en 1339 pasos con pago -20.0
# Ep. 2481 terminado en 1297 pasos con pago -19.0
# Ep. 2482 terminado en 1090 pasos con pago -21.0
# Ep. 2483 terminado en 1347 pasos con pago -21.0
# Ep. 2484 terminado en 1213 pasos con pago -20.0
# Ep. 2485 terminado en 1279 pasos con pago -20.0
# Ep. 2486 terminado en 1249 pasos con pago -21.0
# Ep. 2487 terminado en 1205 pasos con pago -21.0
# Ep. 2488 terminado en 1227 pasos con pago -20.0
# Ep. 2489 terminado en 1262 pasos con pago -21.0
# Ep. 2490 terminado en 1070 pasos con pago -21.0
# Ep. 2491 terminado en 1695 pasos con pago -17.0
# Ep. 2492 terminado en 1364 pasos con pago -19.0
# Ep. 2493 terminado en 1179 pasos con pago -20.0
# Ep. 2494 terminado en 1380 pasos con pago -19.0
# Ep. 2495 terminado en 1452 pasos con pago -19.0
# Ep. 2496 terminado en 1216 pasos con pago -20.0
# Ep. 2497 terminado en 1408 pasos con pago -19.0
# Ep. 2498 terminado en 1256 pasos con pago -20.0
# Ep. 2499 terminado en 1430 pasos con pago -19.0
# Ep. 2500 terminado en 1151 pasos con pago -21.0
# Ep. 2501 terminado en 1745 pasos con pago -17.0
# Ep. 2502 terminado en 1224 pasos con pago -20.0
# Ep. 2503 terminado en 1090 pasos con pago -21.0
# Ep. 2504 terminado en 1372 pasos con pago -20.0
# Ep. 2505 terminado en 1238 pasos con pago -21.0
# Ep. 2506 terminado en 1192 pasos con pago -21.0
# Ep. 2507 terminado en 1288 pasos con pago -20.0
# Ep. 2508 terminado en 1257 pasos con pago -20.0
# Ep. 2509 terminado en 1669 pasos con pago -19.0
# Ep. 2510 terminado en 1739 pasos con pago -17.0
# Ep. 2511 terminado en 1711 pasos con pago -18.0
# Ep. 2512 terminado en 1239 pasos con pago -21.0
# Ep. 2513 terminado en 1344 pasos con pago -19.0
# Ep. 2514 terminado en 1394 pasos con pago -20.0
# Ep. 2515 terminado en 1408 pasos con pago -21.0
# Ep. 2516 terminado en 1448 pasos con pago -19.0
# Ep. 2517 terminado en 1160 pasos con pago -20.0
# Ep. 2518 terminado en 1716 pasos con pago -19.0
# Ep. 2519 terminado en 1494 pasos con pago -19.0
# Ep. 2520 terminado en 1627 pasos con pago -18.0
# Ep. 2521 terminado en 1130 pasos con pago -21.0
# Ep. 2522 terminado en 1540 pasos con pago -18.0
# Ep. 2523 terminado en 1599 pasos con pago -20.0
# Ep. 2524 terminado en 1498 pasos con pago -20.0
# Ep. 2525 terminado en 1330 pasos con pago -20.0
# Ep. 2526 terminado en 1095 pasos con pago -21.0
# Ep. 2527 terminado en 1369 pasos con pago -18.0
# Ep. 2528 terminado en 1316 pasos con pago -21.0
# Ep. 2529 terminado en 1602 pasos con pago -19.0
# Ep. 2530 terminado en 1120 pasos con pago -20.0
# Ep. 2531 terminado en 1506 pasos con pago -20.0
# Ep. 2532 terminado en 1094 pasos con pago -21.0
# Ep. 2533 terminado en 1128 pasos con pago -21.0
# Ep. 2534 terminado en 1083 pasos con pago -21.0
# Ep. 2535 terminado en 1337 pasos con pago -20.0
# Ep. 2536 terminado en 1523 pasos con pago -19.0
# Ep. 2537 terminado en 1389 pasos con pago -20.0
# Ep. 2538 terminado en 1023 pasos con pago -21.0
# Ep. 2539 terminado en 1461 pasos con pago -18.0
# Ep. 2540 terminado en 1059 pasos con pago -21.0
# Ep. 2541 terminado en 1132 pasos con pago -21.0
# Ep. 2542 terminado en 1474 pasos con pago -19.0
# Ep. 2543 terminado en 1501 pasos con pago -19.0
# Ep. 2544 terminado en 1197 pasos con pago -20.0
# Ep. 2545 terminado en 1230 pasos con pago -20.0
# Ep. 2546 terminado en 1119 pasos con pago -20.0
# Ep. 2547 terminado en 1349 pasos con pago -20.0
# Ep. 2548 terminado en 1154 pasos con pago -21.0
# Ep. 2549 terminado en 1417 pasos con pago -19.0
# Ep. 2550 terminado en 1075 pasos con pago -21.0
# Ep. 2551 terminado en 1042 pasos con pago -21.0
# Ep. 2552 terminado en 1429 pasos con pago -20.0
# Ep. 2553 terminado en 1221 pasos con pago -21.0
# Ep. 2554 terminado en 1051 pasos con pago -21.0
# Ep. 2555 terminado en 1133 pasos con pago -21.0
# Ep. 2556 terminado en 1235 pasos con pago -20.0
# Ep. 2557 terminado en 1241 pasos con pago -21.0
# Ep. 2558 terminado en 1129 pasos con pago -21.0
# Ep. 2559 terminado en 1380 pasos con pago -20.0
# Ep. 2560 terminado en 1212 pasos con pago -20.0
# Ep. 2561 terminado en 1044 pasos con pago -21.0
# Ep. 2562 terminado en 1407 pasos con pago -20.0
# Ep. 2563 terminado en 1179 pasos con pago -21.0
# Ep. 2564 terminado en 1449 pasos con pago -19.0
# Ep. 2565 terminado en 1404 pasos con pago -20.0
# Ep. 2566 terminado en 1172 pasos con pago -21.0
# Ep. 2567 terminado en 1456 pasos con pago -20.0
# Ep. 2568 terminado en 1309 pasos con pago -20.0
# Ep. 2569 terminado en 1241 pasos con pago -21.0
# Ep. 2570 terminado en 1439 pasos con pago -21.0
# Ep. 2571 terminado en 1580 pasos con pago -18.0
# Ep. 2572 terminado en 1304 pasos con pago -21.0
# Ep. 2573 terminado en 1092 pasos con pago -21.0
# Ep. 2574 terminado en 1095 pasos con pago -21.0
# Ep. 2575 terminado en 1012 pasos con pago -21.0
# Ep. 2576 terminado en 1324 pasos con pago -19.0
# Ep. 2577 terminado en 1021 pasos con pago -21.0
# Ep. 2578 terminado en 1425 pasos con pago -20.0
# Ep. 2579 terminado en 1262 pasos con pago -19.0
# Ep. 2580 terminado en 1364 pasos con pago -18.0
# Ep. 2581 terminado en 1174 pasos con pago -21.0
# Ep. 2582 terminado en 1352 pasos con pago -20.0
# Ep. 2583 terminado en 1249 pasos con pago -21.0
# Ep. 2584 terminado en 1365 pasos con pago -19.0
# Ep. 2585 terminado en 1218 pasos con pago -19.0
# Ep. 2586 terminado en 1258 pasos con pago -21.0
# Ep. 2587 terminado en 1046 pasos con pago -21.0
# Ep. 2588 terminado en 1112 pasos con pago -21.0
# Ep. 2589 terminado en 1218 pasos con pago -20.0
# Ep. 2590 terminado en 1316 pasos con pago -21.0
# Ep. 2591 terminado en 1110 pasos con pago -20.0
# Ep. 2592 terminado en 1050 pasos con pago -21.0
# Ep. 2593 terminado en 1182 pasos con pago -20.0
# Ep. 2594 terminado en 1323 pasos con pago -19.0
# Ep. 2595 terminado en 1116 pasos con pago -21.0
# Ep. 2596 terminado en 1268 pasos con pago -20.0
# Ep. 2597 terminado en 1404 pasos con pago -18.0
# Ep. 2598 terminado en 1459 pasos con pago -20.0
# Ep. 2599 terminado en 1449 pasos con pago -18.0
# Ep. 2600 terminado en 1615 pasos con pago -20.0
# Ep. 2601 terminado en 1317 pasos con pago -20.0
# Ep. 2602 terminado en 1249 pasos con pago -21.0
# Ep. 2603 terminado en 1377 pasos con pago -18.0
# Ep. 2604 terminado en 1316 pasos con pago -20.0
# Ep. 2605 terminado en 1187 pasos con pago -21.0
# Ep. 2606 terminado en 1353 pasos con pago -19.0
# Ep. 2607 terminado en 1184 pasos con pago -20.0
# Ep. 2608 terminado en 1315 pasos con pago -20.0
# Ep. 2609 terminado en 1242 pasos con pago -20.0
# Ep. 2610 terminado en 1164 pasos con pago -20.0
# Ep. 2611 terminado en 1423 pasos con pago -19.0
# Ep. 2612 terminado en 1220 pasos con pago -20.0
# Ep. 2613 terminado en 1119 pasos con pago -21.0
# Ep. 2614 terminado en 1524 pasos con pago -20.0
# Ep. 2615 terminado en 1365 pasos con pago -20.0
# Ep. 2616 terminado en 1280 pasos con pago -21.0
# Ep. 2617 terminado en 1153 pasos con pago -21.0
# Ep. 2618 terminado en 1195 pasos con pago -20.0
# Ep. 2619 terminado en 1516 pasos con pago -18.0
# Ep. 2620 terminado en 1078 pasos con pago -21.0
# Ep. 2621 terminado en 1493 pasos con pago -18.0
# Ep. 2622 terminado en 1056 pasos con pago -21.0
# Ep. 2623 terminado en 1106 pasos con pago -20.0
# Ep. 2624 terminado en 1336 pasos con pago -19.0
# Ep. 2625 terminado en 1140 pasos con pago -21.0
# Ep. 2626 terminado en 1106 pasos con pago -21.0
# Ep. 2627 terminado en 1222 pasos con pago -20.0
# Ep. 2628 terminado en 1206 pasos con pago -21.0
# Ep. 2629 terminado en 1394 pasos con pago -19.0
# Ep. 2630 terminado en 1283 pasos con pago -20.0
# Ep. 2631 terminado en 1164 pasos con pago -20.0
# Ep. 2632 terminado en 1099 pasos con pago -21.0
# Ep. 2633 terminado en 1088 pasos con pago -21.0
# Ep. 2634 terminado en 1334 pasos con pago -21.0
# Ep. 2635 terminado en 1436 pasos con pago -21.0
# Ep. 2636 terminado en 1477 pasos con pago -19.0
# Ep. 2637 terminado en 1239 pasos con pago -20.0
# Ep. 2638 terminado en 1251 pasos con pago -20.0
# Ep. 2639 terminado en 1059 pasos con pago -21.0
# Ep. 2640 terminado en 1374 pasos con pago -19.0
# Ep. 2641 terminado en 1522 pasos con pago -18.0
# Ep. 2642 terminado en 1013 pasos con pago -21.0
# Ep. 2643 terminado en 1205 pasos con pago -21.0
# Ep. 2644 terminado en 1219 pasos con pago -21.0
# Ep. 2645 terminado en 1396 pasos con pago -20.0
# Ep. 2646 terminado en 1176 pasos con pago -21.0
# Ep. 2647 terminado en 1081 pasos con pago -21.0
# Ep. 2648 terminado en 1172 pasos con pago -20.0
# Ep. 2649 terminado en 1315 pasos con pago -20.0
# Ep. 2650 terminado en 1186 pasos con pago -21.0
# Ep. 2651 terminado en 1187 pasos con pago -20.0
# Ep. 2652 terminado en 1523 pasos con pago -20.0
# Ep. 2653 terminado en 1184 pasos con pago -21.0
# Ep. 2654 terminado en 1289 pasos con pago -21.0
# Ep. 2655 terminado en 1300 pasos con pago -20.0
# Ep. 2656 terminado en 1278 pasos con pago -20.0
# Ep. 2657 terminado en 1165 pasos con pago -21.0
# Ep. 2658 terminado en 1283 pasos con pago -19.0
# Ep. 2659 terminado en 1185 pasos con pago -20.0
# Ep. 2660 terminado en 1262 pasos con pago -21.0
# Ep. 2661 terminado en 1126 pasos con pago -21.0
# Ep. 2662 terminado en 1403 pasos con pago -19.0
# Ep. 2663 terminado en 1218 pasos con pago -21.0
# Ep. 2664 terminado en 1373 pasos con pago -20.0
# Ep. 2665 terminado en 1089 pasos con pago -21.0
# Ep. 2666 terminado en 1162 pasos con pago -20.0
# Ep. 2667 terminado en 1083 pasos con pago -21.0
# Ep. 2668 terminado en 1271 pasos con pago -20.0
# Ep. 2669 terminado en 1138 pasos con pago -21.0
# Ep. 2670 terminado en 1239 pasos con pago -20.0
# Ep. 2671 terminado en 1089 pasos con pago -21.0
# Ep. 2672 terminado en 1296 pasos con pago -21.0
# Ep. 2673 terminado en 1575 pasos con pago -18.0
# Ep. 2674 terminado en 1385 pasos con pago -20.0
# Ep. 2675 terminado en 1425 pasos con pago -21.0
# Ep. 2676 terminado en 1388 pasos con pago -18.0
# Ep. 2677 terminado en 1273 pasos con pago -20.0
# Ep. 2678 terminado en 1240 pasos con pago -20.0
# Ep. 2679 terminado en 1638 pasos con pago -20.0
# Ep. 2680 terminado en 1540 pasos con pago -20.0
# Ep. 2681 terminado en 1197 pasos con pago -20.0
# Ep. 2682 terminado en 1064 pasos con pago -21.0
# Ep. 2683 terminado en 1305 pasos con pago -21.0
# Ep. 2684 terminado en 1145 pasos con pago -21.0
# Ep. 2685 terminado en 1368 pasos con pago -19.0
# Ep. 2686 terminado en 1514 pasos con pago -18.0
# Ep. 2687 terminado en 1245 pasos con pago -20.0
# Ep. 2688 terminado en 1392 pasos con pago -18.0
# Ep. 2689 terminado en 1048 pasos con pago -21.0
# Ep. 2690 terminado en 1217 pasos con pago -20.0
# Ep. 2691 terminado en 1104 pasos con pago -21.0
# Ep. 2692 terminado en 1180 pasos con pago -20.0
# Ep. 2693 terminado en 1227 pasos con pago -20.0
# Ep. 2694 terminado en 1183 pasos con pago -20.0
# Ep. 2695 terminado en 1017 pasos con pago -21.0
# Ep. 2696 terminado en 1029 pasos con pago -21.0
# Ep. 2697 terminado en 1174 pasos con pago -20.0
# Ep. 2698 terminado en 1303 pasos con pago -21.0
# Ep. 2699 terminado en 1154 pasos con pago -21.0
# Ep. 2700 terminado en 1128 pasos con pago -21.0
# Ep. 2701 terminado en 1647 pasos con pago -18.0
# Ep. 2702 terminado en 1350 pasos con pago -20.0
# Ep. 2703 terminado en 1373 pasos con pago -18.0
# Ep. 2704 terminado en 1175 pasos con pago -21.0
# Ep. 2705 terminado en 1214 pasos con pago -20.0
# Ep. 2706 terminado en 1398 pasos con pago -18.0
# Ep. 2707 terminado en 1544 pasos con pago -19.0
# Ep. 2708 terminado en 1165 pasos con pago -20.0
# Ep. 2709 terminado en 1347 pasos con pago -19.0
# Ep. 2710 terminado en 1272 pasos con pago -21.0
# Ep. 2711 terminado en 1231 pasos con pago -20.0
# Ep. 2712 terminado en 1093 pasos con pago -21.0
# Ep. 2713 terminado en 1177 pasos con pago -20.0
# Ep. 2714 terminado en 1110 pasos con pago -21.0
# Ep. 2715 terminado en 1163 pasos con pago -20.0
# Ep. 2716 terminado en 1141 pasos con pago -21.0
# Ep. 2717 terminado en 1264 pasos con pago -19.0
# Ep. 2718 terminado en 1285 pasos con pago -21.0
# Ep. 2719 terminado en 1106 pasos con pago -21.0
# Ep. 2720 terminado en 1092 pasos con pago -21.0
# Ep. 2721 terminado en 1053 pasos con pago -21.0
# Ep. 2722 terminado en 1011 pasos con pago -21.0
# Ep. 2723 terminado en 1104 pasos con pago -21.0
# Ep. 2724 terminado en 1172 pasos con pago -21.0
# Ep. 2725 terminado en 1266 pasos con pago -21.0
# Ep. 2726 terminado en 1117 pasos con pago -20.0
# Ep. 2727 terminado en 1116 pasos con pago -21.0
# Ep. 2728 terminado en 1251 pasos con pago -20.0
# Ep. 2729 terminado en 1083 pasos con pago -21.0
# Ep. 2730 terminado en 1437 pasos con pago -20.0
# Ep. 2731 terminado en 1265 pasos con pago -20.0
# Ep. 2732 terminado en 1384 pasos con pago -19.0
# Ep. 2733 terminado en 1396 pasos con pago -18.0
# Ep. 2734 terminado en 1092 pasos con pago -21.0
# Ep. 2735 terminado en 1162 pasos con pago -21.0
# Ep. 2736 terminado en 1299 pasos con pago -20.0
# Ep. 2737 terminado en 1393 pasos con pago -19.0
# Ep. 2738 terminado en 1295 pasos con pago -20.0
# Ep. 2739 terminado en 1368 pasos con pago -20.0
# Ep. 2740 terminado en 1138 pasos con pago -21.0
# Ep. 2741 terminado en 1261 pasos con pago -20.0
# Ep. 2742 terminado en 1170 pasos con pago -20.0
# Ep. 2743 terminado en 1181 pasos con pago -20.0
# Ep. 2744 terminado en 1322 pasos con pago -20.0
# Ep. 2745 terminado en 1208 pasos con pago -20.0
# Ep. 2746 terminado en 1009 pasos con pago -21.0
# Ep. 2747 terminado en 1410 pasos con pago -20.0
# Ep. 2748 terminado en 1388 pasos con pago -19.0
# Ep. 2749 terminado en 1166 pasos con pago -20.0
# Ep. 2750 terminado en 1392 pasos con pago -20.0
# Ep. 2751 terminado en 1175 pasos con pago -21.0
# Ep. 2752 terminado en 1144 pasos con pago -20.0
# Ep. 2753 terminado en 1426 pasos con pago -19.0
# Ep. 2754 terminado en 1329 pasos con pago -21.0
# Ep. 2755 terminado en 1336 pasos con pago -19.0
# Ep. 2756 terminado en 1403 pasos con pago -20.0
# Ep. 2757 terminado en 1227 pasos con pago -20.0
# Ep. 2758 terminado en 1059 pasos con pago -21.0
# Ep. 2759 terminado en 1565 pasos con pago -18.0
# Ep. 2760 terminado en 1039 pasos con pago -21.0
# Ep. 2761 terminado en 1123 pasos con pago -20.0
# Ep. 2762 terminado en 1396 pasos con pago -20.0
# Ep. 2763 terminado en 1539 pasos con pago -18.0
# Ep. 2764 terminado en 1156 pasos con pago -20.0
# Ep. 2765 terminado en 1161 pasos con pago -20.0
# Ep. 2766 terminado en 1155 pasos con pago -20.0
# Ep. 2767 terminado en 1037 pasos con pago -21.0
# Ep. 2768 terminado en 1016 pasos con pago -21.0
# Ep. 2769 terminado en 1295 pasos con pago -20.0
# Ep. 2770 terminado en 1324 pasos con pago -21.0
# Ep. 2771 terminado en 1311 pasos con pago -19.0
# Ep. 2772 terminado en 1225 pasos con pago -21.0
# Ep. 2773 terminado en 1474 pasos con pago -18.0
# Ep. 2774 terminado en 1190 pasos con pago -21.0
# Ep. 2775 terminado en 1250 pasos con pago -20.0
# Ep. 2776 terminado en 1263 pasos con pago -21.0
# Ep. 2777 terminado en 1048 pasos con pago -21.0
# Ep. 2778 terminado en 1496 pasos con pago -19.0
# Ep. 2779 terminado en 1378 pasos con pago -20.0
# Ep. 2780 terminado en 1485 pasos con pago -20.0
# Ep. 2781 terminado en 1049 pasos con pago -21.0
# Ep. 2782 terminado en 1139 pasos con pago -21.0
# Ep. 2783 terminado en 1291 pasos con pago -19.0
# Ep. 2784 terminado en 1213 pasos con pago -21.0
# Ep. 2785 terminado en 1520 pasos con pago -19.0
# Ep. 2786 terminado en 1056 pasos con pago -21.0
# Ep. 2787 terminado en 1160 pasos con pago -20.0
# Ep. 2788 terminado en 1289 pasos con pago -21.0
# Ep. 2789 terminado en 1517 pasos con pago -19.0
# Ep. 2790 terminado en 1457 pasos con pago -19.0
# Ep. 2791 terminado en 1357 pasos con pago -20.0
# Ep. 2792 terminado en 1385 pasos con pago -20.0
# Ep. 2793 terminado en 1430 pasos con pago -20.0
# Ep. 2794 terminado en 1343 pasos con pago -21.0
# Ep. 2795 terminado en 1444 pasos con pago -20.0
# Ep. 2796 terminado en 1261 pasos con pago -20.0
# Ep. 2797 terminado en 1044 pasos con pago -21.0
# Ep. 2798 terminado en 1137 pasos con pago -21.0

# %%
using JLD
save(joinpath(dirname(@__FILE__), "Q.jld"), "Q", Q)
