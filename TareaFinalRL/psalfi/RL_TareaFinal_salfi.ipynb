# %% [markdown]
# # Jugando Atari con Julia y Reinforcement Learning
#
# No nos emocionemos aun, todavia hay un largo camino por recorrer... Entrenar un programa (agente) que aprenda a jugar a nivel humano toma mucha paciencia y horas de entrenamiento; un solo paso equivocado y no lo vamos a lograr.
#
# Para aprender a resolver problemas complejos, lo primero que tenemos que hacer es comprender las complicaciones detras de cada parte de esta tarea. Para esto, necesitamos comenzar con problemas sencillos y escalarlos poco a poco. Necesitamos comenzar haciendo un pequeño viaje en el tiempo a la historia reciente de la Inteligencia Artificial y el Reinforcement Learning.

# %% [markdown]
# ## 1. MDPs
#
# Nuestra historia comienza con Richard Bellman (*A Markovian Decission Process* 1957) y Ronald Howard (*Dynamic Programming and Markov Processes* 1960), que extendio la teoria de Bellman.
#
#  <center><table><tr>
#   <td><img src="Images/bellman.jpg" alt="Richard Bellman" width="150">
#   <figcaption>Fig1.a - El es Bellman.</figcaption></td>
#   <td><img src="Images/howard.jpg" alt="Ronald Markov" width="150">
#   <figcaption>Fig1.b - El es Howard.</figcaption></td>
#   <td><img src="Images/markov.jpg" alt="Andrey Markov" width="150">
#   <figcaption>Fig1.c - El es Markov.</figcaption></td>
# </table></center>
#
# Bellman tuvo una idea muy simple de como modelar un proceso de aprendizaje. En cada momento del tiempo $t$, un agente debe tomar una decision (accion) $A_t$ dependiendo del estado del ambiente $S_t$; en el momento que el agente toma su decision, interactua con el ambiente y lo transforma, llevando al sistema a un nuevo estado $S_{t+1}$. ¿Como puede saber el agente si actuo correcta o incorrectamente? Para eso necesita una señal de reforzamiento o pago. Por esta razon, suponemos ademas que el agente recibe un pago $R_{t+1}$ en el momento que el sistema se transforma.
#
#  <center>
#  <img src="Images/mdp_process.png" alt="MDP Representation" width="400" height="225">
#  <figcaption>Fig2. - Este es el ciclo de una tarea de aprendizaje.</figcaption>
# </center>
#
# ¿Y que tiene que ver con Markov? Bellman es uno de los desarrolladores de la *Programacion Dinamica*, que es una tecnica para resolver problemas matematicos en los que las variables que queremos encontrar dependen del tiempo y la solucion en un momento $t$ se puede expresar en terminos de la solucion al tiempo $t-1$. La idea central del trabajo de Bellman consiste en que para encontrar las decisiones optimas $A_t, A_{t+1},...$ de forma que maximicen el total de pagos recibidos en el tiempo $R_{t+1}, R_{t+2}, ...$ tenemos que suponer que el estado futuro del sistema es independiente del pasado condicionado a su estado actual y de las decisiones del agente. Esta propiedad se conoce como la propiedad de Markov. En terminos matematicos, la implicacion de esta condicion es
# $$
# P(S_{t+1}, R_{t+1} \mid S_0, A_0, R_0, ..., S_t, A_t, R_t) = P(S_{t+1}, R_{t+1} \mid S_t, A_t).
# $$
# En otras palabras, las probabilidades de transicion $(S_t,A_t) \to (S_{t+1}, R_{t+1})$ y las decisiones del agente determinan todo el comportamiento del sistema. Un problema reforzamiento con la propiedad de Markov se conoce como un *Markov Decission Process* o MDP.

# %% [markdown]
# ## Un juego de Atari como un MDP
#
# <center>
#  <img src="Images/pong.jpg" alt="Pong" width="150">
#  <figcaption>Fig3. - El juego de de Atari Pong.</figcaption>
# </center>
#
# Este tutorial es acerca de como resolver juegos de Atari en Julia. Para promover el desarollo de algoritmos de Inteligencia Artificial y Reinforcement Learning, la organizacion OpenAI creo la interfaz [Open AI Gym](https://gym.openai.com/) que facilita el desarollo y evaluacion de algoritmos de aprendizaje. La mala noticia es que solo esta disponible para Python y es casi imposible de instalar en Windows. La buena noticia es que Julia tiene una interfaz para interactuar con Python de forma muy sencilla y no sera una limitacion.
#
# Por supuesto que pueden optar por implementar sus algoritmos directamente en Python y no en Julia. Pero este es un tutorial de Julia, que explota la belleza, facilidad y velocidad de Julia.
#
# Por favor vean la pagina de Open AI Gym directamente para instrucciones de como instalar la libreria `gym` de Python. Para poder usar `gym` en Julia, deberan antes tener la paqueteria de Interfaz con Python llamada `PyCall`. Para instalarla, usen el comando `Pkg.add("PyCall")`.
#
# El siguiente codigo muestra como cargar el juego de Pong y hacer unas cuantas simulaciones.

# %%
using PyCall # use Pkg.add("PyCall") to install
@pyimport gym # most have gym installed on your computer's Python distribution
pong = gym.make("Pong-v0") # crea el ambiente de juego Pong en el objeto pong
# Out:
# [2017-06-02 22:00:13,083] Making new env: Pong-v0
# PyObject <TimeLimit<AtariEnv<Pong-v0>>>

# %% [markdown]
# Un MDP tiene estados y acciones disponibles, para saber cuales son con un objeto del tipo Pong, podemos usar las acciones de la paqueteria de Python gym.
#
# ### Conjunto de Estados

# %%
pong[:observation_space] # pong.observation_space en Python
# Out:
# PyObject Box(210, 160, 3)

# %% [markdown]
# El resultado es que el espacio de estados es una "caja" de dimensiones $210 \times 160 \times 3$. Aunque en los metodos de Reinforcement Learning no necesitaremos saber el significado de los estados,  en este caso sabemos de antemano que va el juego va a regresar los componentes RGB de los pixeles del juego. El juego tiene una resolucion de $210 \times 160$ y por cada uno tiene tres componentes de color. Un componente de color es un valor en el rango $0--255$. Si no supieramos esto, pudiese haber usado las siguientes funciones para determinar la frontera del espacio de observaciones
# * `pong[:observation_space][:high]`
# * `pong[:observation_space][:low]`
#
# No las incluimos aqui porque el resultado es muy grande.

# %% [markdown]
# ### Conjunto de Acciones
#
# Determinar el conjunto de acciones es muy similar, para eso podemos usar

# %%
pong[:action_space] # pong.action_space en Python
# Out:
# PyObject Discrete(6)

# %% [markdown]
# En este caso es discreto (el conjunto de acciones siempre es discreto en estas pruebas). Eso quiere decir que solo puede obtener los valores $0-5$. Si! Empieza en cero, es una de las herencias por la interfaz con Python.
#
# Otra manera de encontrar el numero de acciones es simplemente con el comando

# %%
pong[:action_space][:n] # pong.action_space en Python
# Out:
# 6

# %% [markdown]
# Tanto el espacio de observacion y espacio de accion son objetos de Python que pertenecen a la clase "espacios" y tienen implementado un metodo muy util para tomas muestras aleatorias de estos espacios. Eso sera muy util al principio, para poder demostrar algunas simulaciones.

# %%
pong[:action_space][:sample]()
# Out:
# 4

# %% [markdown]
# Afortunadamente para los metodos de Reinforcement Learning, tampoco necesitamos saber el significado de estas acciones.

# %% [markdown]
# ### Simulando transiciones del MDP
#
# Ahora lo mas divertido, veamos primero como simular una transicion usando el metodo `step` de los ambientes de `gym`.

# %%
initial_state = pong[:reset]() # comienza oficialmente el ambiente Pong poniendo en su estado inicial
action = pong[:action_space][:sample]() # escoje una accion al azar, ojo no depende del estado inicial
    # por ser completamente aleatorio, pero en principio deberia...
new_state, reward, done, info = pong[:step](action)
; # para que no imprima el resultado de la celda

# %% [markdown]
# El metodo `step` recibe una accion (en realidad, tambien recibe el estado actual, para ya esta codificado dentro del ambiente) y regresa cuatro cosas
# * `new_state`: El nuevo estado del ambiente
# * `reward` El pago recibido por la accion decididad
# * `done` Una variable booleana que determina si el episodio esta terminado
# * `info` Un diccionario que trae informacion adicional del juego, en teoria nunca deberiamos necesitarla.
#
# La funcion `step` tiene implica las probabilidades de transicion $(S_t, A_t)\to (S_{t+1}, R_{t+1})$ del MDP. No son explicitas porque no regresa toda la distribucion, simplemente un muestreo de esa distribucion. Esta es la dificultad a la que nos enfrentamos.
#
# ### Simulando y visualizando todo un episodio
#
# Veamos ahora como podriamos simular y visualizar un episodio entero. Para visualizar el estado del ambiente necesitaremos el metodo `render`.

# %%
initial_state = pong[:reset]() 
done = false
episode_reward = 0.
while !done # cicla hasta que la funcion step marque el fin del episodio
    pong[:render]() # crea la visualizacion del juego
    action = pong[:action_space][:sample]() 
    state, reward, done, info = pong[:step](action)
    episode_reward += reward
end
println("Episodio terminado con pago total: ", episode_reward)
pong[:render](close = true) # cierra la visualizacion del juego
# Out:
# Episodio terminado con pago total: -

# %% [markdown]
# **Felicidades!!!** Con esta parte del tutorial, ya sabes todo lo que necesitabas de los ambientes de `gym`!
#
# Desafortunadamente, resolver el juego de Pong no es facil pues el espacio de estados viene en terminos de pixeles y eso significa muchas posibilidades (aun cuando no las veamos todas). De momento, trataremos de resolver un problema mas sencillo, primero deberan hacer el siguiente ejercicio.

# %% [markdown]
# ### <span style='color: red'> Ejercicio 1 </span>
#
# Antes de poder juegos de Atari, vamos a utilizar el ambiente "MountainCar-v0" que es una muy sencilla y clasica prueba de algoritmos de Inteligencia Artificial. El problema consiste en un coche que tiene que subir una colina pero su motor no tiene la fuerza necesaria. Para esto tiene que ir de lado en lado construyendo inercia.
#
# <center>
#  <img src="Images/mountainCar.jpg" alt="Mountain Car" width="300" height="225">
#  <figcaption>Fig3. - Problema del coche de la colina.</figcaption>
# </center>
#
# Introduce el codigo para cargar el ambiente "MountainCar-v0" y realiza la simulacion de 10 episodios tomando decisiones completamente aleatorias con la funcion `sample` del espacion del ambiente. Tu codigo debe imprimir
# 1. El pago total acumulado por cada episodio
# 2. El total de pasos por episodio
# 3. El tiempo total por episodio, puedes usar las funciones tic() y toq() de julia para esto.

# %%
using PyCall # use Pkg.add("PyCall") to install
@pyimport gym # most have gym installed on your computer's Python distribution
hill = gym.make("MountainCar-v0") # crea el ambiente de juego Pong en el objeto pong
# Out:
# [2017-06-02 22:00:22,763] Making new env: MountainCar-v0
# PyObject <TimeLimit<MountainCarEnv<MountainCar-v0>>>

# %%
initial_state = hill[:reset]() 
done = false
episode_reward = 0.
step = 0.
time = 0.

for i = 0:9
    initial_state = hill[:reset]() 
    done = false
    episode_reward = 0.
    step = 0.
    time = 0.
    tic()
  while !done # cicla hasta que la funcion step marque el fin del episodio
    timeIni=tic()
    hill[:render]() # crea la visualizacion del juego
    action = hill[:action_space][:sample]() 
    state, reward, done, info = hill[:step](action)
    episode_reward += reward
    step = step + 1
    time += toc()    
end

    
println("Episodio terminado con pago total: ", episode_reward)
println("El total de pasos por episodio: ", step)
println("El tiempo total por episodio: ", time)
hill[:render](close = true) # cierra la visualizacion del juego 
end
# Out:
# elapsed time: 0.130125864 seconds
# elapsed time: 0.0084982 seconds
# elapsed time: 0.002813525 seconds
# elapsed time: 0.002954883 seconds
# elapsed time: 0.010196327 seconds
# elapsed time: 0.002643373 seconds
# elapsed time: 0.003348952 seconds
# elapsed time: 0.010406166 seconds
# elapsed time: 0.002733534 seconds
# elapsed time: 0.009197843 seconds
# elapsed time: 0.006241043 seconds
# elapsed time: 0.003163309 seconds
# elapsed time: 0.007058781 seconds
# elapsed time: 0.006459401 seconds
# elapsed time: 0.013271037 seconds
# elapsed time: 0.014305299 seconds
# elapsed time: 0.004106208 seconds
# elapsed time: 0.007351218 seconds
# elapsed time: 0.010416408 seconds
# elapsed time: 0.012474625 seconds
# elapsed time: 0.00491449 seconds
# elapsed time: 0.012015625 seconds
# elapsed time: 0.006695761 seconds
# elapsed time: 0.009346241 seconds
# elapsed time: 0.007732926 seconds
# elapsed time: 0.005012532 seconds
# elapsed time: 0.0082919 seconds
# elapsed time: 0.004787378 seconds
# elapsed time: 0.014668557 seconds
# elapsed time: 0.005417685 seconds
# elapsed time: 0.010055774 seconds
# elapsed time: 0.004605467 seconds
# elapsed time: 0.007531979 seconds
# elapsed time: 0.005386219 seconds
# elapsed time: 0.01493519 seconds
# elapsed time: 0.010583824 seconds
# elapsed time: 0.011143134 seconds
# elapsed time: 0.0052734 seconds
# elapsed time: 0.01138834 seconds
# elapsed time: 0.01106946 seconds
# elapsed time: 0.008693567 seconds
# elapsed time: 0.007475004 seconds
# elapsed time: 0.008018087 seconds
# elapsed time: 0.003678105 seconds
# elapsed time: 0.002547603 seconds
# elapsed time: 0.008199509 seconds
# elapsed time: 0.005929237 seconds
# elapsed time: 0.006132949 seconds
# elapsed time: 0.003135469 seconds
# elapsed time: 0.005086672 seconds
# elapsed time: 0.003239046 seconds
# elapsed time: 0.004443137 seconds
# elapsed time: 0.005310433 seconds
# elapsed time: 0.009292096 seconds
# elapsed time: 0.003402677 seconds
# elapsed time: 0.004250056 seconds
# elapsed time: 0.008785738 seconds
# elapsed time: 0.007619168 seconds
# elapsed time: 0.00619146 seconds
# elapsed time: 0.004747478 seconds
# elapsed time: 0.003263597 seconds
# elapsed time: 0.004319007 seconds
# elapsed time: 0.00439504 seconds
# elapsed time: 0.004826986 seconds
# elapsed time: 0.003570609 seconds
# elapsed time: 0.003450852 seconds
# elapsed time: 0.00410771 seconds
# elapsed time: 0.004674189 seconds
# elapsed time: 0.003185209 seconds
# elapsed time: 0.002733828 seconds
# elapsed time: 0.002925213 seconds
# elapsed time: 0.006609596 seconds
# elapsed time: 0.007697706 seconds
# elapsed time: 0.007215903 seconds
# elapsed time: 0.005568843 seconds
# elapsed time: 0.009677968 seconds
# elapsed time: 0.004612582 seconds
# elapsed time: 0.002390854 seconds
# elapsed time: 0.003984089 seconds
# elapsed time: 0.004595934 seconds
# elapsed time: 0.004851064 seconds
# elapsed time: 0.002793945 seconds
# elapsed time: 0.004087398 seconds
# elapsed time: 0.003878539 seconds
# elapsed time: 0.004138134 seconds
# elapsed time: 0.003194352 seconds
# elapsed time: 0.003810495 seconds
# elapsed time: 0.002793539 seconds
# elapsed time: 0.002758266 seconds
# elapsed time: 0.004229342 seconds
# elapsed time: 0.013632512 seconds
# elapsed time: 0.007440758 seconds
# elapsed time: 0.008096998 seconds
# elapsed time: 0.008266292 seconds
# elapsed time: 0.002640214 seconds
# elapsed time: 0.004988495 seconds
# elapsed time: 0.006199959 seconds
# elapsed time: 0.00312354 seconds
# elapsed time: 0.002647034 seconds
# elapsed time: 0.004225588 seconds
# elapsed time: 0.004381352 seconds
# elapsed time: 0.002743674 seconds
# elapsed time: 0.002851685 seconds
# elapsed time: 0.004755154 seconds
# elapsed time: 0.004141346 seconds
# elapsed time: 0.002807758 seconds
# elapsed time: 0.002796778 seconds
# elapsed time: 0.005411902 seconds
# elapsed time: 0.00419553 seconds
# elapsed time: 0.012311394 seconds
# elapsed time: 0.002522198 seconds
# elapsed time: 0.010035971 seconds
# elapsed time: 0.002282285 seconds
# elapsed time: 0.004366664 seconds
# elapsed time: 0.00894909 seconds
# elapsed time: 0.002757091 seconds
# elapsed time: 0.002881977 seconds
# elapsed time: 0.004548247 seconds
# elapsed time: 0.005143988 seconds
# elapsed time: 0.003107529 seconds
# elapsed time: 0.002745515 seconds
# elapsed time: 0.00443168 seconds
# elapsed time: 0.005328082 seconds
# elapsed time: 0.00354607 seconds
# elapsed time: 0.002622269 seconds
# elapsed time: 0.002550535 seconds
# elapsed time: 0.007175516 seconds
# elapsed time: 0.005478752 seconds
# elapsed time: 0.009527197 seconds
# elapsed time: 0.005037011 seconds
# elapsed time: 0.011232259 seconds
# elapsed time: 0.002903085 seconds
# elapsed time: 0.002467083 seconds
# elapsed time: 0.006811997 seconds
# elapsed time: 0.003042929 seconds
# elapsed time: 0.002521992 seconds
# elapsed time: 0.005194289 seconds
# elapsed time: 0.003574343 seconds
# elapsed time: 0.005809156 seconds
# elapsed time: 0.002507301 seconds
# elapsed time: 0.006108635 seconds
# elapsed time: 0.003704096 seconds
# elapsed time: 0.002581478 seconds
# elapsed time: 0.002827298 seconds
# elapsed time: 0.004340026 seconds
# elapsed time: 0.004443048 seconds
# elapsed time: 0.008932249 seconds
# elapsed time: 0.00523949 seconds
# elapsed time: 0.009255677 seconds
# elapsed time: 0.009095411 seconds
# elapsed time: 0.002825378 seconds
# elapsed time: 0.00632255 seconds
# elapsed time: 0.003032547 seconds
# elapsed time: 0.002354736 seconds
# elapsed time: 0.006110042 seconds
# elapsed time: 0.004153314 seconds
# elapsed time: 0.004074012 seconds
# elapsed time: 0.003717821 seconds
# elapsed time: 0.003917472 seconds
# elapsed time: 0.003756758 seconds
# elapsed time: 0.004494273 seconds
# elapsed time: 0.00323784 seconds
# elapsed time: 0.00428505 seconds
# elapsed time: 0.004488536 seconds
# elapsed time: 0.006362694 seconds
# elapsed time: 0.006403843 seconds
# elapsed time: 0.009580373 seconds
# elapsed time: 0.008646854 seconds
# elapsed time: 0.003875785 seconds
# elapsed time: 0.005748653 seconds
# elapsed time: 0.005716178 seconds
# elapsed time: 0.002526182 seconds
# elapsed time: 0.005804104 seconds
# elapsed time: 0.003396917 seconds
# elapsed time: 0.004467678 seconds
# elapsed time: 0.003752175 seconds
# elapsed time: 0.002884808 seconds
# elapsed time: 0.004228612 seconds
# elapsed time: 0.004920055 seconds
# elapsed time: 0.003855252 seconds
# elapsed time: 0.002741434 seconds
# elapsed time: 0.004163296 seconds
# elapsed time: 0.006503676 seconds
# elapsed time: 0.007270081 seconds
# elapsed time: 0.008203159 seconds
# elapsed time: 0.006314064 seconds
# elapsed time: 0.006170641 seconds
# elapsed time: 0.005342107 seconds
# elapsed time: 0.006539052 seconds
# elapsed time: 0.006817581 seconds
# elapsed time: 0.002395947 seconds
# elapsed time: 0.005137701 seconds
# elapsed time: 0.004510176 seconds
# elapsed time: 0.003971148 seconds
# elapsed time: 0.002722866 seconds
# elapsed time: 0.005586558 seconds
# elapsed time: 0.004147405 seconds
# elapsed time: 0.003008264 seconds
# elapsed time: 0.002705736 seconds
# elapsed time: 0.004326086 seconds
# Episodio terminado con pago total: -200.0
# El total de pasos por episodio: 200.0
# El tiempo total por episodio: 1.227945099999999
# elapsed time: 0.215543807 seconds
# elapsed time: 0.029468117 seconds
# elapsed time: 0.018531588 seconds
# elapsed time: 0.014258084 seconds
# elapsed time: 0.007614588 seconds
# elapsed time: 0.012781806 seconds
# elapsed time: 0.012000572 seconds
# elapsed time: 0.016481285 seconds
# elapsed time: 0.008138527 seconds
# elapsed time: 0.006474707 seconds
# elapsed time: 0.007717957 seconds
# elapsed time: 0.002630412 seconds
# elapsed time: 0.011958445 seconds
# elapsed time: 0.005225905 seconds
# elapsed time: 0.008473376 seconds
# elapsed time: 0.006756562 seconds
# elapsed time: 0.010274117 seconds
# elapsed time: 0.002224821 seconds
# elapsed time: 0.010940495 seconds
# elapsed time: 0.002704718 seconds
# elapsed time: 0.008196667 seconds
# elapsed time: 0.002332931 seconds
# elapsed time: 0.010151591 seconds
# elapsed time: 0.007346324 seconds
# elapsed time: 0.010452987 seconds
# elapsed time: 0.003648934 seconds
# elapsed time: 0.010592928 seconds
# elapsed time: 0.006598461 seconds
# elapsed time: 0.004120578 seconds
# elapsed time: 0.006087941 seconds
# elapsed time: 0.004853863 seconds
# elapsed time: 0.006592849 seconds
# elapsed time: 0.013966001 seconds
# elapsed time: 0.005055133 seconds
# elapsed time: 0.005479881 seconds
# elapsed time: 0.009391664 seconds
# elapsed time: 0.003831759 seconds
# elapsed time: 0.00495858 seconds
# elapsed time: 0.007416857 seconds
# elapsed time: 0.005245666 seconds
# elapsed time: 0.007723055 seconds
# elapsed time: 0.003559716 seconds
# elapsed time: 0.005388475 seconds
# elapsed time: 0.004086089 seconds
# elapsed time: 0.004394591 seconds
# elapsed time: 0.004207651 seconds
# elapsed time: 0.007289368 seconds
# elapsed time: 0.00662704 seconds
# elapsed time: 0.010961865 seconds
# elapsed time: 0.004471898 seconds
# elapsed time: 0.007809465 seconds
# elapsed time: 0.004217869 seconds
# elapsed time: 0.008223229 seconds
# elapsed time: 0.004651646 seconds
# elapsed time: 0.002617962 seconds
# elapsed time: 0.006473805 seconds
# elapsed time: 0.00487115 seconds
# elapsed time: 0.003411627 seconds
# elapsed time: 0.003071655 seconds
# elapsed time: 0.004852069 seconds
# elapsed time: 0.004533681 seconds
# elapsed time: 0.003293014 seconds
# elapsed time: 0.00667737 seconds
# elapsed time: 0.005406107 seconds
# elapsed time: 0.006940994 seconds
# elapsed time: 0.00254829 seconds
# elapsed time: 0.005618822 seconds
# elapsed time: 0.010475988 seconds
# elapsed time: 0.002993365 seconds
# elapsed time: 0.006971683 seconds
# elapsed time: 0.003157916 seconds
# elapsed time: 0.00447428 seconds
# elapsed time: 0.003207223 seconds
# elapsed time: 0.004480808 seconds
# elapsed time: 0.005022687 seconds
# elapsed time: 0.002690414 seconds
# elapsed time: 0.003067725 seconds
# elapsed time: 0.002428874 seconds
# elapsed time: 0.005921033 seconds
# elapsed time: 0.003796185 seconds
# elapsed time: 0.002509327 seconds
# elapsed time: 0.007697317 seconds
# elapsed time: 0.004528231 seconds
# elapsed time: 0.008070981 seconds
# elapsed time: 0.00657275 seconds
# elapsed time: 0.007471444 seconds
# elapsed time: 0.009079611 seconds
# elapsed time: 0.00219253 seconds
# elapsed time: 0.007960252 seconds
# elapsed time: 0.004472677 seconds
# elapsed time: 0.00259457 seconds
# elapsed time: 0.003869181 seconds
# elapsed time: 0.004326408 seconds
# elapsed time: 0.004776467 seconds
# elapsed time: 0.003281149 seconds
# elapsed time: 0.003476227 seconds
# elapsed time: 0.004474315 seconds
# elapsed time: 0.004026457 seconds
# elapsed time: 0.003116365 seconds
# elapsed time: 0.007667252 seconds
# elapsed time: 0.003541401 seconds
# elapsed time: 0.006617544 seconds
# elapsed time: 0.006657341 seconds
# elapsed time: 0.004552895 seconds
# elapsed time: 0.009858762 seconds
# elapsed time: 0.008170555 seconds
# elapsed time: 0.003367171 seconds
# elapsed time: 0.007231989 seconds
# elapsed time: 0.003261468 seconds
# elapsed time: 0.002906637 seconds
# elapsed time: 0.003712121 seconds
# elapsed time: 0.009532733 seconds
# elapsed time: 0.005823465 seconds
# elapsed time: 0.006012614 seconds
# elapsed time: 0.00595032 seconds
# elapsed time: 0.006252879 seconds
# elapsed time: 0.009642638 seconds
# elapsed time: 0.005730051 seconds
# elapsed time: 0.012232386 seconds
# elapsed time: 0.002912226 seconds
# elapsed time: 0.006366015 seconds
# elapsed time: 0.009050873 seconds
# elapsed time: 0.003378663 seconds
# elapsed time: 0.002839305 seconds
# elapsed time: 0.003753156 seconds
# elapsed time: 0.004980198 seconds
# elapsed time: 0.004018881 seconds
# elapsed time: 0.002784345 seconds
# elapsed time: 0.004198248 seconds
# elapsed time: 0.005276036 seconds
# elapsed time: 0.007997136 seconds
# elapsed time: 0.004317023 seconds
# elapsed time: 0.006698773 seconds
# elapsed time: 0.007055474 seconds
# elapsed time: 0.00735724 seconds
# elapsed time: 0.009914522 seconds
# elapsed time: 0.002307476 seconds
# elapsed time: 0.006461812 seconds
# elapsed time: 0.007431969 seconds
# elapsed time: 0.003155062 seconds
# elapsed time: 0.002517686 seconds
# elapsed time: 0.004141978 seconds
# elapsed time: 0.004992673 seconds
# elapsed time: 0.003139614 seconds
# elapsed time: 0.002794165 seconds
# elapsed time: 0.002553984 seconds
# elapsed time: 0.006094218 seconds
# elapsed time: 0.0022453 seconds
# elapsed time: 0.011274034 seconds
# elapsed time: 0.002316902 seconds
# elapsed time: 0.01164451 seconds
# elapsed time: 0.004597681 seconds
# elapsed time: 0.005554939 seconds
# elapsed time: 0.00854718 seconds
# elapsed time: 0.00265097 seconds
# elapsed time: 0.004291524 seconds
# elapsed time: 0.006981411 seconds
# elapsed time: 0.003132719 seconds
# elapsed time: 0.002891008 seconds
# elapsed time: 0.004632509 seconds
# elapsed time: 0.004463976 seconds
# elapsed time: 0.004393304 seconds
# elapsed time: 0.002799538 seconds
# elapsed time: 0.004357738 seconds
# elapsed time: 0.005579741 seconds
# elapsed time: 0.00832188 seconds
# elapsed time: 0.008057425 seconds
# elapsed time: 0.002204202 seconds
# elapsed time: 0.010399826 seconds
# elapsed time: 0.006589708 seconds
# elapsed time: 0.004612023 seconds
# elapsed time: 0.008694591 seconds
# elapsed time: 0.007660456 seconds
# elapsed time: 0.007315361 seconds
# elapsed time: 0.005519077 seconds
# elapsed time: 0.009504117 seconds
# elapsed time: 0.004433782 seconds
# elapsed time: 0.002484104 seconds
# elapsed time: 0.004883321 seconds
# elapsed time: 0.004575048 seconds
# elapsed time: 0.005099641 seconds
# elapsed time: 0.006800218 seconds
# elapsed time: 0.008281187 seconds
# elapsed time: 0.006013953 seconds
# elapsed time: 0.006301995 seconds
# elapsed time: 0.007923803 seconds
# elapsed time: 0.002423664 seconds
# elapsed time: 0.008069741 seconds
# elapsed time: 0.007933263 seconds
# elapsed time: 0.006497178 seconds
# elapsed time: 0.007166303 seconds
# elapsed time: 0.005693586 seconds
# elapsed time: 0.005619154 seconds
# elapsed time: 0.003228404 seconds
# elapsed time: 0.004549278 seconds
# elapsed time: 0.005507815 seconds
# elapsed time: 0.006007348 seconds
# elapsed time: 0.008275049 seconds
# elapsed time: 0.006625159 seconds
# elapsed time: 0.007629918 seconds
# Episodio terminado con pago total: -200.0
# El total de pasos por episodio: 200.0
# El tiempo total por episodio: 1.4241019619999993
# elapsed time: 0.09749883 seconds
# elapsed time: 0.016953447 seconds
# elapsed time: 0.008429003 seconds
# elapsed time: 0.010158171 seconds
# elapsed time: 0.006412584 seconds
# elapsed time: 0.010613115 seconds
# elapsed time: 0.006683183 seconds
# elapsed time: 0.011012229 seconds
# elapsed time: 0.0110001 seconds
# elapsed time: 0.007313247 seconds
# elapsed time: 0.011493127 seconds
# elapsed time: 0.015501343 seconds
# elapsed time: 0.013026214 seconds
# elapsed time: 0.005713323 seconds
# elapsed time: 0.007248903 seconds
# elapsed time: 0.007129573 seconds
# elapsed time: 0.0132435 seconds
# elapsed time: 0.008621439 seconds
# elapsed time: 0.003053991 seconds
# elapsed time: 0.008967292 seconds
# elapsed time: 0.008163348 seconds
# elapsed time: 0.009916022 seconds
# elapsed time: 0.004170563 seconds
# elapsed time: 0.009009873 seconds
# elapsed time: 0.013339499 seconds
# elapsed time: 0.008128441 seconds
# elapsed time: 0.011967223 seconds
# elapsed time: 0.002435569 seconds
# elapsed time: 0.003629596 seconds
# elapsed time: 0.01018134 seconds
# elapsed time: 0.002399073 seconds
# elapsed time: 0.013130495 seconds
# elapsed time: 0.002796216 seconds
# elapsed time: 0.005567529 seconds
# elapsed time: 0.002726519 seconds
# elapsed time: 0.011506045 seconds
# elapsed time: 0.005508909 seconds
# elapsed time: 0.008404649 seconds
# elapsed time: 0.00858316 seconds
# elapsed time: 0.006757352 seconds
# elapsed time: 0.004751906 seconds
# elapsed time: 0.008618382 seconds
# elapsed time: 0.004005688 seconds
# elapsed time: 0.012358854 seconds
# elapsed time: 0.004319026 seconds
# elapsed time: 0.004636672 seconds
# elapsed time: 0.007524658 seconds
# elapsed time: 0.008019503 seconds
# elapsed time: 0.010097098 seconds
# elapsed time: 0.005669393 seconds
# elapsed time: 0.012052962 seconds
# elapsed time: 0.01892529 seconds
# elapsed time: 0.008030749 seconds
# elapsed time: 0.011063622 seconds
# elapsed time: 0.011398961 seconds
# elapsed time: 0.005308244 seconds
# elapsed time: 0.00874807 seconds
# elapsed time: 0.010896461 seconds
# elapsed time: 0.012476218 seconds
# elapsed time: 0.009602919 seconds
# elapsed time: 0.013984542 seconds
# elapsed time: 0.004117584 seconds
# elapsed time: 0.012132711 seconds
# elapsed time: 0.008824298 seconds
# elapsed time: 0.009260303 seconds
# elapsed time: 0.013512162 seconds
# elapsed time: 0.00803921 seconds
# elapsed time: 0.009365445 seconds
# elapsed time: 0.014834884 seconds
# elapsed time: 0.007234747 seconds
# elapsed time: 0.010965195 seconds
# elapsed time: 0.00214508 seconds
# elapsed time: 0.006102432 seconds
# elapsed time: 0.007636523 seconds
# elapsed time: 0.003500818 seconds
# elapsed time: 0.010486918 seconds
# elapsed time: 0.002747497 seconds
# elapsed time: 0.007684807 seconds
# elapsed time: 0.004185462 seconds
# elapsed time: 0.012082141 seconds
# elapsed time: 0.002500541 seconds
# elapsed time: 0.007674331 seconds
# elapsed time: 0.00943071 seconds
# elapsed time: 0.003609188 seconds
# elapsed time: 0.009486149 seconds
# elapsed time: 0.004002431 seconds
# elapsed time: 0.007436604 seconds
# elapsed time: 0.004489543 seconds
# elapsed time: 0.003587033 seconds
# elapsed time: 0.002554503 seconds
# elapsed time: 0.002613979 seconds
# elapsed time: 0.003945615 seconds
# elapsed time: 0.004387811 seconds
# elapsed time: 0.009351337 seconds
# elapsed time: 0.005471804 seconds
# elapsed time: 0.005045298 seconds
# elapsed time: 0.007196804 seconds
# elapsed time: 0.005339519 seconds
# elapsed time: 0.010338076 seconds
# elapsed time: 0.002373987 seconds
# elapsed time: 0.005426851 seconds
# elapsed time: 0.007504036 seconds
# elapsed time: 0.003433165 seconds
# elapsed time: 0.007897248 seconds
# elapsed time: 0.004383426 seconds
# elapsed time: 0.003584321 seconds
# elapsed time: 0.008940421 seconds
# elapsed time: 0.002691746 seconds
# elapsed time: 0.009663793 seconds
# elapsed time: 0.007205948 seconds
# elapsed time: 0.005631327 seconds
# elapsed time: 0.006641876 seconds
# elapsed time: 0.003753501 seconds
# elapsed time: 0.010091127 seconds
# elapsed time: 0.00667347 seconds
# elapsed time: 0.006149548 seconds
# elapsed time: 0.007607608 seconds
# elapsed time: 0.002754209 seconds
# elapsed time: 0.004196259 seconds
# elapsed time: 0.005264691 seconds
# elapsed time: 0.004850824 seconds
# elapsed time: 0.01843724 seconds
# elapsed time: 0.002880164 seconds
# elapsed time: 0.009640214 seconds
# elapsed time: 0.002818973 seconds
# elapsed time: 0.011079991 seconds
# elapsed time: 0.00692731 seconds
# elapsed time: 0.012301062 seconds
# elapsed time: 0.007989538 seconds
# elapsed time: 0.008515913 seconds
# elapsed time: 0.008986746 seconds
# elapsed time: 0.008350664 seconds
# elapsed time: 0.002501724 seconds
# elapsed time: 0.007818467 seconds
# elapsed time: 0.005392646 seconds
# elapsed time: 0.006207453 seconds
# elapsed time: 0.00708535 seconds
# elapsed time: 0.007651206 seconds
# elapsed time: 0.010426781 seconds
# elapsed time: 0.004839769 seconds
# elapsed time: 0.007505259 seconds
# elapsed time: 0.006350096 seconds
# elapsed time: 0.005669849 seconds
# elapsed time: 0.008998919 seconds
# elapsed time: 0.00649069 seconds
# elapsed time: 0.005708728 seconds
# elapsed time: 0.007074053 seconds
# elapsed time: 0.005291325 seconds
# elapsed time: 0.005015418 seconds
# elapsed time: 0.008312388 seconds
# elapsed time: 0.00658019 seconds
# elapsed time: 0.00968262 seconds
# elapsed time: 0.007183359 seconds
# elapsed time: 0.007939038 seconds
# elapsed time: 0.004262118 seconds
# elapsed time: 0.008952214 seconds
# elapsed time: 0.005309171 seconds
# elapsed time: 0.00492953 seconds
# elapsed time: 0.004276277 seconds
# elapsed time: 0.004660938 seconds
# elapsed time: 0.003784096 seconds
# elapsed time: 0.002672093 seconds
# elapsed time: 0.004267706 seconds
# elapsed time: 0.004989195 seconds
# elapsed time: 0.004721539 seconds
# elapsed time: 0.010426521 seconds
# elapsed time: 0.002836313 seconds
# elapsed time: 0.00856075 seconds
# elapsed time: 0.006591699 seconds
# elapsed time: 0.003158962 seconds
# elapsed time: 0.008590614 seconds
# elapsed time: 0.006854745 seconds
# elapsed time: 0.003859576 seconds
# elapsed time: 0.005827644 seconds
# elapsed time: 0.005833118 seconds
# elapsed time: 0.007412431 seconds
# elapsed time: 0.003454303 seconds
# elapsed time: 0.002668435 seconds
# elapsed time: 0.004345196 seconds
# elapsed time: 0.003495703 seconds
# elapsed time: 0.004917505 seconds
# elapsed time: 0.007874101 seconds
# elapsed time: 0.005939068 seconds
# elapsed time: 0.004883875 seconds
# elapsed time: 0.006514086 seconds
# elapsed time: 0.006667672 seconds
# elapsed time: 0.005308882 seconds
# elapsed time: 0.008342277 seconds
# elapsed time: 0.007324864 seconds
# elapsed time: 0.006934316 seconds
# elapsed time: 0.004675758 seconds
# elapsed time: 0.005662383 seconds
# elapsed time: 0.003606938 seconds
# elapsed time: 0.002979291 seconds
# elapsed time: 0.0024915 seconds
# elapsed time: 0.003301137 seconds
# elapsed time: 0.004478566 seconds
# elapsed time: 0.007780336 seconds
# elapsed time: 0.005853867 seconds
# elapsed time: 0.003934672 seconds
# Episodio terminado con pago total: -200.0
# El total de pasos por episodio: 200.0
# El tiempo total por episodio: 1.5047872520000003
# elapsed time: 0.092936203 seconds
# elapsed time: 0.007096871 seconds
# elapsed time: 0.008966037 seconds
# elapsed time: 0.011285043 seconds
# elapsed time: 0.007232102 seconds
# elapsed time: 0.009327185 seconds
# elapsed time: 0.008889188 seconds
# elapsed time: 0.007864231 seconds
# elapsed time: 0.012387619 seconds
# elapsed time: 0.003879797 seconds
# elapsed time: 0.010798552 seconds
# elapsed time: 0.002837251 seconds
# elapsed time: 0.011741591 seconds
# elapsed time: 0.010357096 seconds
# elapsed time: 0.008233533 seconds
# elapsed time: 0.008142706 seconds
# elapsed time: 0.007291745 seconds
# elapsed time: 0.009319886 seconds
# elapsed time: 0.008475813 seconds
# elapsed time: 0.009718951 seconds
# elapsed time: 0.008785773 seconds
# elapsed time: 0.006322789 seconds
# elapsed time: 0.008021214 seconds
# elapsed time: 0.010811965 seconds
# elapsed time: 0.010632947 seconds
# elapsed time: 0.002996868 seconds
# elapsed time: 0.006192216 seconds
# elapsed time: 0.006914953 seconds
# elapsed time: 0.005080131 seconds
# elapsed time: 0.006241141 seconds
# elapsed time: 0.009188567 seconds
# elapsed time: 0.003934309 seconds
# elapsed time: 0.010347305 seconds
# elapsed time: 0.004290537 seconds
# elapsed time: 0.006404272 seconds
# elapsed time: 0.00365845 seconds
# elapsed time: 0.005303624 seconds
# elapsed time: 0.009468488 seconds
# elapsed time: 0.006102846 seconds
# elapsed time: 0.00662761 seconds
# elapsed time: 0.007990232 seconds
# elapsed time: 0.011355454 seconds
# elapsed time: 0.005491945 seconds
# elapsed time: 0.008265941 seconds
# elapsed time: 0.005432553 seconds
# elapsed time: 0.0070528 seconds
# elapsed time: 0.006198211 seconds
# elapsed time: 0.005834286 seconds
# elapsed time: 0.004943962 seconds
# elapsed time: 0.00653763 seconds
# elapsed time: 0.00504862 seconds
# elapsed time: 0.007640314 seconds
# elapsed time: 0.007104108 seconds
# elapsed time: 0.010587525 seconds
# elapsed time: 0.003984233 seconds
# elapsed time: 0.009321385 seconds
# elapsed time: 0.007662005 seconds
# elapsed time: 0.007248199 seconds
# elapsed time: 0.003565785 seconds
# elapsed time: 0.004827964 seconds
# elapsed time: 0.010968094 seconds
# elapsed time: 0.002444793 seconds
# elapsed time: 0.004107572 seconds
# elapsed time: 0.003075496 seconds
# elapsed time: 0.005592776 seconds
# elapsed time: 0.009138272 seconds
# elapsed time: 0.006013279 seconds
# elapsed time: 0.008578835 seconds
# elapsed time: 0.005253023 seconds
# elapsed time: 0.005039081 seconds
# elapsed time: 0.008245202 seconds
# elapsed time: 0.002516607 seconds
# elapsed time: 0.008693171 seconds
# elapsed time: 0.006420121 seconds
# elapsed time: 0.002332284 seconds
# elapsed time: 0.011136614 seconds
# elapsed time: 0.006176722 seconds
# elapsed time: 0.012262268 seconds
# elapsed time: 0.002769624 seconds
# elapsed time: 0.004676643 seconds
# elapsed time: 0.005462641 seconds
# elapsed time: 0.011465907 seconds
# elapsed time: 0.002635772 seconds
# elapsed time: 0.010951412 seconds
# elapsed time: 0.002496825 seconds
# elapsed time: 0.008007084 seconds
# elapsed time: 0.006688786 seconds
# elapsed time: 0.007220913 seconds
# elapsed time: 0.010545398 seconds
# elapsed time: 0.007197898 seconds
# elapsed time: 0.007807432 seconds
# elapsed time: 0.006251014 seconds
# elapsed time: 0.007362152 seconds
# elapsed time: 0.006711497 seconds
# elapsed time: 0.003611806 seconds
# elapsed time: 0.008088853 seconds
# elapsed time: 0.005341382 seconds
# elapsed time: 0.010915805 seconds
# elapsed time: 0.004655775 seconds
# elapsed time: 0.011144506 seconds
# elapsed time: 0.003042939 seconds
# elapsed time: 0.006806604 seconds
# elapsed time: 0.006776068 seconds
# elapsed time: 0.005803585 seconds
# elapsed time: 0.00224183 seconds
# elapsed time: 0.005782704 seconds
# elapsed time: 0.005104373 seconds
# elapsed time: 0.006991651 seconds
# elapsed time: 0.007293202 seconds
# elapsed time: 0.005811515 seconds
# elapsed time: 0.004499666 seconds
# elapsed time: 0.007098494 seconds
# elapsed time: 0.00726692 seconds
# elapsed time: 0.009250063 seconds
# elapsed time: 0.004328815 seconds
# elapsed time: 0.005661728 seconds
# elapsed time: 0.006560522 seconds
# elapsed time: 0.003961498 seconds
# elapsed time: 0.006806306 seconds
# elapsed time: 0.005199767 seconds
# elapsed time: 0.003176083 seconds
# elapsed time: 0.006665072 seconds
# elapsed time: 0.007171961 seconds
# elapsed time: 0.007199969 seconds
# elapsed time: 0.005560655 seconds
# elapsed time: 0.009485163 seconds
# elapsed time: 0.002788276 seconds
# elapsed time: 0.006458647 seconds
# elapsed time: 0.008222718 seconds
# elapsed time: 0.003480507 seconds
# elapsed time: 0.004863224 seconds
# elapsed time: 0.007626118 seconds
# elapsed time: 0.00252809 seconds
# elapsed time: 0.002742015 seconds
# elapsed time: 0.004127377 seconds
# elapsed time: 0.002795175 seconds
# elapsed time: 0.004612104 seconds
# elapsed time: 0.00287811 seconds
# elapsed time: 0.003111627 seconds
# elapsed time: 0.005513429 seconds
# elapsed time: 0.004866081 seconds
# elapsed time: 0.005313063 seconds
# elapsed time: 0.006707051 seconds
# elapsed time: 0.007548432 seconds
# elapsed time: 0.00758603 seconds
# elapsed time: 0.00227074 seconds
# elapsed time: 0.009847602 seconds
# elapsed time: 0.002258081 seconds
# elapsed time: 0.006887747 seconds
# elapsed time: 0.007554202 seconds
# elapsed time: 0.002303394 seconds
# elapsed time: 0.005147056 seconds
# elapsed time: 0.004644124 seconds
# elapsed time: 0.0044065 seconds
# elapsed time: 0.004580094 seconds
# elapsed time: 0.003219117 seconds
# elapsed time: 0.004062939 seconds
# elapsed time: 0.006919838 seconds
# elapsed time: 0.006960437 seconds
# elapsed time: 0.003896275 seconds
# elapsed time: 0.005724577 seconds
# elapsed time: 0.008363145 seconds
# elapsed time: 0.00690148 seconds
# elapsed time: 0.004658253 seconds
# elapsed time: 0.00775364 seconds
# elapsed time: 0.008421264 seconds
# elapsed time: 0.009687663 seconds
# elapsed time: 0.003026321 seconds
# elapsed time: 0.004875321 seconds
# elapsed time: 0.002474734 seconds
# elapsed time: 0.002823589 seconds
# elapsed time: 0.011370028 seconds
# elapsed time: 0.008890561 seconds
# elapsed time: 0.006176915 seconds
# elapsed time: 0.005752026 seconds
# elapsed time: 0.005518518 seconds
# elapsed time: 0.005704498 seconds
# elapsed time: 0.004577872 seconds
# elapsed time: 0.006133631 seconds
# elapsed time: 0.006103002 seconds
# elapsed time: 0.005826835 seconds
# elapsed time: 0.004598552 seconds
# elapsed time: 0.005520412 seconds
# elapsed time: 0.004015117 seconds
# elapsed time: 0.002531533 seconds
# elapsed time: 0.003872466 seconds
# elapsed time: 0.006818465 seconds
# elapsed time: 0.00356942 seconds
# elapsed time: 0.003342075 seconds
# elapsed time: 0.003796606 seconds
# elapsed time: 0.002441717 seconds
# elapsed time: 0.006248828 seconds
# elapsed time: 0.007607533 seconds
# elapsed time: 0.00365036 seconds
# elapsed time: 0.011650041 seconds
# elapsed time: 0.002460352 seconds
# elapsed time: 0.005496262 seconds
# elapsed time: 0.007774479 seconds
# elapsed time: 0.002773249 seconds
# elapsed time: 0.00536701 seconds
# Episodio terminado con pago total: -200.0
# El total de pasos por episodio: 200.0
# El tiempo total por episodio: 1.3487756149999997
# elapsed time: 0.102536756 seconds
# elapsed time: 0.005403676 seconds
# elapsed time: 0.011061134 seconds
# elapsed time: 0.011333659 seconds
# elapsed time: 0.013764879 seconds
# elapsed time: 0.014729191 seconds
# elapsed time: 0.003950984 seconds
# elapsed time: 0.012143699 seconds
# elapsed time: 0.01638369 seconds
# elapsed time: 0.007613788 seconds
# elapsed time: 0.007655045 seconds
# elapsed time: 0.011614453 seconds
# elapsed time: 0.008516622 seconds
# elapsed time: 0.009359455 seconds
# elapsed time: 0.007232733 seconds
# elapsed time: 0.009122913 seconds
# elapsed time: 0.006193449 seconds
# elapsed time: 0.002382369 seconds
# elapsed time: 0.010179011 seconds
# elapsed time: 0.004211392 seconds
# elapsed time: 0.006906812 seconds
# elapsed time: 0.007332789 seconds
# elapsed time: 0.008088406 seconds
# elapsed time: 0.004689371 seconds
# elapsed time: 0.009616629 seconds
# elapsed time: 0.002716501 seconds
# elapsed time: 0.002348127 seconds
# elapsed time: 0.010239462 seconds
# elapsed time: 0.002330555 seconds
# elapsed time: 0.008361107 seconds
# elapsed time: 0.007239937 seconds
# elapsed time: 0.007371722 seconds
# elapsed time: 0.007265299 seconds
# elapsed time: 0.005159368 seconds
# elapsed time: 0.005562172 seconds
# elapsed time: 0.006398094 seconds
# elapsed time: 0.008527915 seconds
# elapsed time: 0.002268646 seconds
# elapsed time: 0.004729691 seconds
# elapsed time: 0.006124145 seconds
# elapsed time: 0.007003172 seconds
# elapsed time: 0.009952237 seconds
# elapsed time: 0.005479997 seconds
# elapsed time: 0.00898436 seconds
# elapsed time: 0.009726898 seconds
# elapsed time: 0.004279009 seconds
# elapsed time: 0.008459843 seconds
# elapsed time: 0.00360364 seconds
# elapsed time: 0.007006331 seconds
# elapsed time: 0.009198907 seconds
# elapsed time: 0.002288722 seconds
# elapsed time: 0.014721753 seconds
# elapsed time: 0.002374996 seconds
# elapsed time: 0.006125785 seconds
# elapsed time: 0.007248768 seconds
# elapsed time: 0.007173978 seconds
# elapsed time: 0.00617889 seconds
# elapsed time: 0.004813231 seconds
# elapsed time: 0.008017017 seconds
# elapsed time: 0.005164674 seconds
# elapsed time: 0.005321049 seconds
# elapsed time: 0.010266648 seconds
# elapsed time: 0.007206558 seconds
# elapsed time: 0.008115033 seconds
# elapsed time: 0.007649171 seconds
# elapsed time: 0.008654653 seconds
# elapsed time: 0.004997612 seconds
# elapsed time: 0.00828187 seconds
# elapsed time: 0.005346742 seconds
# elapsed time: 0.006066989 seconds
# elapsed time: 0.007330533 seconds
# elapsed time: 0.005315504 seconds
# elapsed time: 0.005334224 seconds
# elapsed time: 0.006911078 seconds
# elapsed time: 0.004206923 seconds
# elapsed time: 0.008676684 seconds
# elapsed time: 0.005853435 seconds
# elapsed time: 0.012093564 seconds
# elapsed time: 0.004704354 seconds
# elapsed time: 0.006692542 seconds
# elapsed time: 0.00717021 seconds
# elapsed time: 0.007902755 seconds
# elapsed time: 0.009418244 seconds
# elapsed time: 0.009518227 seconds
# elapsed time: 0.007135955 seconds
# elapsed time: 0.006316524 seconds
# elapsed time: 0.008355664 seconds
# elapsed time: 0.002784995 seconds
# elapsed time: 0.003790005 seconds
# elapsed time: 0.003940524 seconds
# elapsed time: 0.00608323 seconds
# elapsed time: 0.005702015 seconds
# elapsed time: 0.006226648 seconds
# elapsed time: 0.004477914 seconds
# elapsed time: 0.007681267 seconds
# elapsed time: 0.004675525 seconds
# elapsed time: 0.010155872 seconds
# elapsed time: 0.004065105 seconds
# elapsed time: 0.007526481 seconds
# elapsed time: 0.008434478 seconds
# elapsed time: 0.002192564 seconds
# elapsed time: 0.00509681 seconds
# elapsed time: 0.007197627 seconds
# elapsed time: 0.003418736 seconds
# elapsed time: 0.003939905 seconds
# elapsed time: 0.003280446 seconds
# elapsed time: 0.005245827 seconds
# elapsed time: 0.008332926 seconds
# elapsed time: 0.002202426 seconds
# elapsed time: 0.009788166 seconds
# elapsed time: 0.00731679 seconds
# elapsed time: 0.002212916 seconds
# elapsed time: 0.008414615 seconds
# elapsed time: 0.00647623 seconds
# elapsed time: 0.007388681 seconds
# elapsed time: 0.006856245 seconds
# elapsed time: 0.002187527 seconds
# elapsed time: 0.00312457 seconds
# elapsed time: 0.00719253 seconds
# elapsed time: 0.003146652 seconds
# elapsed time: 0.003282331 seconds
# elapsed time: 0.003807223 seconds
# elapsed time: 0.004324042 seconds
# elapsed time: 0.003218999 seconds
# elapsed time: 0.008953506 seconds
# elapsed time: 0.003604693 seconds
# elapsed time: 0.004782219 seconds
# elapsed time: 0.008563252 seconds
# elapsed time: 0.003783923 seconds
# elapsed time: 0.005061276 seconds
# elapsed time: 0.005875897 seconds
# elapsed time: 0.006498253 seconds
# elapsed time: 0.007686237 seconds
# elapsed time: 0.002242406 seconds
# elapsed time: 0.005601557 seconds
# elapsed time: 0.008848829 seconds
# elapsed time: 0.002898423 seconds
# elapsed time: 0.002675922 seconds
# elapsed time: 0.002817948 seconds
# elapsed time: 0.004589702 seconds
# elapsed time: 0.005158481 seconds
# elapsed time: 0.004851515 seconds
# elapsed time: 0.009884525 seconds
# elapsed time: 0.011064919 seconds
# elapsed time: 0.002897858 seconds
# elapsed time: 0.003783326 seconds
# elapsed time: 0.007435446 seconds
# elapsed time: 0.007505167 seconds
# elapsed time: 0.008091569 seconds
# elapsed time: 0.00631765 seconds
# elapsed time: 0.004571499 seconds
# elapsed time: 0.007545967 seconds
# elapsed time: 0.003069445 seconds
# elapsed time: 0.002553212 seconds
# elapsed time: 0.006155541 seconds
# elapsed time: 0.002841691 seconds
# elapsed time: 0.008529531 seconds
# elapsed time: 0.002639318 seconds
# elapsed time: 0.00684271 seconds
# elapsed time: 0.007468238 seconds
# elapsed time: 0.007322443 seconds
# elapsed time: 0.009071716 seconds
# elapsed time: 0.010080625 seconds
# elapsed time: 0.009824905 seconds
# elapsed time: 0.004458353 seconds
# elapsed time: 0.007936225 seconds
# elapsed time: 0.006558731 seconds
# elapsed time: 0.007277513 seconds
# elapsed time: 0.004900081 seconds
# elapsed time: 0.002478839 seconds
# elapsed time: 0.004649529 seconds
# elapsed time: 0.002910188 seconds
# elapsed time: 0.006845615 seconds
# elapsed time: 0.006525781 seconds
# elapsed time: 0.004379077 seconds
# elapsed time: 0.007125996 seconds
# elapsed time: 0.007462299 seconds
# elapsed time: 0.0036975 seconds
# elapsed time: 0.00816342 seconds
# elapsed time: 0.007537443 seconds
# elapsed time: 0.00401814 seconds
# elapsed time: 0.009510955 seconds
# elapsed time: 0.002127891 seconds
# elapsed time: 0.006958991 seconds
# elapsed time: 0.003197499 seconds
# elapsed time: 0.004384134 seconds
# elapsed time: 0.003790012 seconds
# elapsed time: 0.008348726 seconds
# elapsed time: 0.00253543 seconds
# elapsed time: 0.009056622 seconds
# elapsed time: 0.010776445 seconds
# elapsed time: 0.005010713 seconds
# elapsed time: 0.007002837 seconds
# elapsed time: 0.008874977 seconds
# elapsed time: 0.006873552 seconds
# elapsed time: 0.003219849 seconds
# elapsed time: 0.008079392 seconds
# elapsed time: 0.003443533 seconds
# elapsed time: 0.002894299 seconds
# elapsed time: 0.004044916 seconds
# Episodio terminado con pago total: -200.0
# El total de pasos por episodio: 200.0
# El tiempo total por episodio: 1.373546284999999
# elapsed time: 0.094826828 seconds
# elapsed time: 0.019248789 seconds
# elapsed time: 0.009029155 seconds
# elapsed time: 0.009220857 seconds
# elapsed time: 0.00969316 seconds
# elapsed time: 0.003264866 seconds
# elapsed time: 0.017746123 seconds
# elapsed time: 0.011059289 seconds
# elapsed time: 0.009699203 seconds
# elapsed time: 0.003484371 seconds
# elapsed time: 0.009920622 seconds
# elapsed time: 0.008776492 seconds
# elapsed time: 0.004286764 seconds
# elapsed time: 0.011250811 seconds
# elapsed time: 0.004063439 seconds
# elapsed time: 0.008212857 seconds
# elapsed time: 0.005509378 seconds
# elapsed time: 0.003135444 seconds
# elapsed time: 0.00794068 seconds
# elapsed time: 0.008468266 seconds
# elapsed time: 0.007990164 seconds
# elapsed time: 0.00762448 seconds
# elapsed time: 0.005709248 seconds
# elapsed time: 0.009916385 seconds
# elapsed time: 0.006589139 seconds
# elapsed time: 0.00773946 seconds
# elapsed time: 0.003402391 seconds
# elapsed time: 0.002495795 seconds
# elapsed time: 0.008393226 seconds
# elapsed time: 0.007358339 seconds
# elapsed time: 0.008514871 seconds
# elapsed time: 0.009285614 seconds
# elapsed time: 0.012347814 seconds
# elapsed time: 0.00770475 seconds
# elapsed time: 0.005737051 seconds
# elapsed time: 0.005129859 seconds
# elapsed time: 0.009857889 seconds
# elapsed time: 0.005827063 seconds
# elapsed time: 0.004947344 seconds
# elapsed time: 0.007545621 seconds
# elapsed time: 0.009822196 seconds
# elapsed time: 0.007647884 seconds
# elapsed time: 0.008042081 seconds
# elapsed time: 0.012318424 seconds
# elapsed time: 0.002257931 seconds
# elapsed time: 0.008406789 seconds
# elapsed time: 0.006662675 seconds
# elapsed time: 0.009501894 seconds
# elapsed time: 0.002196989 seconds
# elapsed time: 0.006623943 seconds
# elapsed time: 0.005734595 seconds
# elapsed time: 0.003706441 seconds
# elapsed time: 0.011441095 seconds
# elapsed time: 0.002379771 seconds
# elapsed time: 0.007921665 seconds
# elapsed time: 0.006573591 seconds
# elapsed time: 0.005074602 seconds
# elapsed time: 0.010108623 seconds
# elapsed time: 0.018644208 seconds
# elapsed time: 0.016798637 seconds
# elapsed time: 0.002681763 seconds
# elapsed time: 0.01081419 seconds
# elapsed time: 0.005538212 seconds
# elapsed time: 0.004690478 seconds
# elapsed time: 0.00827694 seconds
# elapsed time: 0.002691675 seconds
# elapsed time: 0.006323907 seconds
# elapsed time: 0.008059068 seconds
# elapsed time: 0.010129461 seconds
# elapsed time: 0.004452046 seconds
# elapsed time: 0.005641197 seconds
# elapsed time: 0.007168566 seconds
# elapsed time: 0.004576532 seconds
# elapsed time: 0.00735758 seconds
# elapsed time: 0.00749385 seconds
# elapsed time: 0.004675924 seconds
# elapsed time: 0.007970835 seconds
# elapsed time: 0.007778263 seconds
# elapsed time: 0.007325703 seconds
# elapsed time: 0.005045762 seconds
# elapsed time: 0.010040935 seconds
# elapsed time: 0.007650339 seconds
# elapsed time: 0.006469027 seconds
# elapsed time: 0.009598388 seconds
# elapsed time: 0.002158447 seconds
# elapsed time: 0.006048443 seconds
# elapsed time: 0.008057781 seconds
# elapsed time: 0.005005264 seconds
# elapsed time: 0.006959596 seconds
# elapsed time: 0.006247705 seconds
# elapsed time: 0.005824745 seconds
# elapsed time: 0.002641911 seconds
# elapsed time: 0.004162218 seconds
# elapsed time: 0.010221187 seconds
# elapsed time: 0.011217973 seconds
# elapsed time: 0.008451174 seconds
# elapsed time: 0.003112019 seconds
# elapsed time: 0.008596132 seconds
# elapsed time: 0.0073109 seconds
# elapsed time: 0.00628284 seconds
# elapsed time: 0.006411828 seconds
# elapsed time: 0.004856112 seconds
# elapsed time: 0.005738971 seconds
# elapsed time: 0.00749758 seconds
# elapsed time: 0.006878538 seconds
# elapsed time: 0.004986629 seconds
# elapsed time: 0.006449748 seconds
# elapsed time: 0.013491379 seconds
# elapsed time: 0.009378508 seconds
# elapsed time: 0.006676474 seconds
# elapsed time: 0.008743447 seconds
# elapsed time: 0.015114369 seconds
# elapsed time: 0.008296356 seconds
# elapsed time: 0.011582247 seconds
# elapsed time: 0.007271053 seconds
# elapsed time: 0.008882366 seconds
# elapsed time: 0.013155249 seconds
# elapsed time: 0.009718154 seconds
# elapsed time: 0.010962317 seconds
# elapsed time: 0.009602378 seconds
# elapsed time: 0.009425799 seconds
# elapsed time: 0.011696787 seconds
# elapsed time: 0.009964285 seconds
# elapsed time: 0.00773571 seconds
# elapsed time: 0.00986912 seconds
# elapsed time: 0.011332349 seconds
# elapsed time: 0.008287424 seconds
# elapsed time: 0.007667304 seconds
# elapsed time: 0.012702743 seconds
# elapsed time: 0.011585888 seconds
# elapsed time: 0.010950968 seconds
# elapsed time: 0.016053638 seconds
# elapsed time: 0.00669286 seconds
# elapsed time: 0.00708014 seconds
# elapsed time: 0.005508219 seconds
# elapsed time: 0.00690549 seconds
# elapsed time: 0.003491083 seconds
# elapsed time: 0.008797572 seconds
# elapsed time: 0.005088322 seconds
# elapsed time: 0.005762453 seconds
# elapsed time: 0.007888261 seconds
# elapsed time: 0.002248913 seconds
# elapsed time: 0.006486194 seconds
# elapsed time: 0.007461371 seconds
# elapsed time: 0.005104846 seconds
# elapsed time: 0.006653386 seconds
# elapsed time: 0.008206797 seconds
# elapsed time: 0.009301993 seconds
# elapsed time: 0.008442729 seconds
# elapsed time: 0.002463864 seconds
# elapsed time: 0.010692383 seconds
# elapsed time: 0.005212295 seconds
# elapsed time: 0.004652355 seconds
# elapsed time: 0.007514457 seconds
# elapsed time: 0.004784853 seconds
# elapsed time: 0.015101916 seconds
# elapsed time: 0.002246657 seconds
# elapsed time: 0.00729359 seconds
# elapsed time: 0.008534367 seconds
# elapsed time: 0.011454514 seconds
# elapsed time: 0.002329849 seconds
# elapsed time: 0.007112974 seconds
# elapsed time: 0.004953957 seconds
# elapsed time: 0.007556071 seconds
# elapsed time: 0.007747566 seconds
# elapsed time: 0.002450576 seconds
# elapsed time: 0.007474971 seconds
# elapsed time: 0.009017052 seconds
# elapsed time: 0.003199606 seconds
# elapsed time: 0.010202127 seconds
# elapsed time: 0.003830535 seconds
# elapsed time: 0.00889938 seconds
# elapsed time: 0.008025391 seconds
# elapsed time: 0.004298969 seconds
# elapsed time: 0.006443927 seconds
# elapsed time: 0.006819245 seconds
# elapsed time: 0.012565986 seconds
# elapsed time: 0.00361455 seconds
# elapsed time: 0.008450757 seconds
# elapsed time: 0.00611207 seconds
# elapsed time: 0.008446983 seconds
# elapsed time: 0.006939102 seconds
# elapsed time: 0.009173253 seconds
# elapsed time: 0.009686168 seconds
# elapsed time: 0.010788827 seconds
# elapsed time: 0.00601089 seconds
# elapsed time: 0.007640801 seconds
# elapsed time: 0.006649005 seconds
# elapsed time: 0.004848654 seconds
# elapsed time: 0.011095876 seconds
# elapsed time: 0.002386142 seconds
# elapsed time: 0.010367485 seconds
# elapsed time: 0.006845555 seconds
# elapsed time: 0.005784802 seconds
# elapsed time: 0.009544979 seconds
# elapsed time: 0.008409459 seconds
# elapsed time: 0.00833535 seconds
# elapsed time: 0.007769947 seconds
# elapsed time: 0.007378057 seconds
# elapsed time: 0.008865944 seconds
# Episodio terminado con pago total: -200.0
# El total de pasos por episodio: 200.0
# El tiempo total por episodio: 1.611677342999999
# elapsed time: 0.077564324 seconds
# elapsed time: 0.015384274 seconds
# elapsed time: 0.012069065 seconds
# elapsed time: 0.011063424 seconds
# elapsed time: 0.004675182 seconds
# elapsed time: 0.008372763 seconds
# elapsed time: 0.014029568 seconds
# elapsed time: 0.006655449 seconds
# elapsed time: 0.008582364 seconds
# elapsed time: 0.006933108 seconds
# elapsed time: 0.006853725 seconds
# elapsed time: 0.015773874 seconds
# elapsed time: 0.011072356 seconds
# elapsed time: 0.006621435 seconds
# elapsed time: 0.010383642 seconds
# elapsed time: 0.006068731 seconds
# elapsed time: 0.009913743 seconds
# elapsed time: 0.012027037 seconds
# elapsed time: 0.008225169 seconds
# elapsed time: 0.004611196 seconds
# elapsed time: 0.007742851 seconds
# elapsed time: 0.008395697 seconds
# elapsed time: 0.002302226 seconds
# elapsed time: 0.004971319 seconds
# elapsed time: 0.009765266 seconds
# elapsed time: 0.011582281 seconds
# elapsed time: 0.005009365 seconds
# elapsed time: 0.005100089 seconds
# elapsed time: 0.005698414 seconds
# elapsed time: 0.008202327 seconds
# elapsed time: 0.007820265 seconds
# elapsed time: 0.009564916 seconds
# elapsed time: 0.003437573 seconds
# elapsed time: 0.010772037 seconds
# elapsed time: 0.004035286 seconds
# elapsed time: 0.007579343 seconds
# elapsed time: 0.009341421 seconds
# elapsed time: 0.002784899 seconds
# elapsed time: 0.014958028 seconds
# elapsed time: 0.002694305 seconds
# elapsed time: 0.008726739 seconds
# elapsed time: 0.011321838 seconds
# elapsed time: 0.01239798 seconds
# elapsed time: 0.003826393 seconds
# elapsed time: 0.009068098 seconds
# elapsed time: 0.007657558 seconds
# elapsed time: 0.007826744 seconds
# elapsed time: 0.007919207 seconds
# elapsed time: 0.002069427 seconds
# elapsed time: 0.007795759 seconds
# elapsed time: 0.004593885 seconds
# elapsed time: 0.003904718 seconds
# elapsed time: 0.006890184 seconds
# elapsed time: 0.002474502 seconds
# elapsed time: 0.005438939 seconds
# elapsed time: 0.012176857 seconds
# elapsed time: 0.006568669 seconds
# elapsed time: 0.007145174 seconds
# elapsed time: 0.006650658 seconds
# elapsed time: 0.007523921 seconds
# elapsed time: 0.002603016 seconds
# elapsed time: 0.005069297 seconds
# elapsed time: 0.009281842 seconds
# elapsed time: 0.005598891 seconds
# elapsed time: 0.008086795 seconds
# elapsed time: 0.006421467 seconds
# elapsed time: 0.004818276 seconds
# elapsed time: 0.007079832 seconds
# elapsed time: 0.007017888 seconds
# elapsed time: 0.005688621 seconds
# elapsed time: 0.010490508 seconds
# elapsed time: 0.003372411 seconds
# elapsed time: 0.006149567 seconds
# elapsed time: 0.005132543 seconds
# elapsed time: 0.005196536 seconds
# elapsed time: 0.006569973 seconds
# elapsed time: 0.006267189 seconds
# elapsed time: 0.010162406 seconds
# elapsed time: 0.004746182 seconds
# elapsed time: 0.007493695 seconds
# elapsed time: 0.007088471 seconds
# elapsed time: 0.006866576 seconds
# elapsed time: 0.012355639 seconds
# elapsed time: 0.002530077 seconds
# elapsed time: 0.00775699 seconds
# elapsed time: 0.006760481 seconds
# elapsed time: 0.003983994 seconds
# elapsed time: 0.008776207 seconds
# elapsed time: 0.004150997 seconds
# elapsed time: 0.009732823 seconds
# elapsed time: 0.005041226 seconds
# elapsed time: 0.006724187 seconds
# elapsed time: 0.006727419 seconds
# elapsed time: 0.005881871 seconds
# elapsed time: 0.017482018 seconds
# elapsed time: 0.008013548 seconds
# elapsed time: 0.002826702 seconds
# elapsed time: 0.011768322 seconds
# elapsed time: 0.002379098 seconds
# elapsed time: 0.008204189 seconds
# elapsed time: 0.010401518 seconds
# elapsed time: 0.00227151 seconds
# elapsed time: 0.009553138 seconds
# elapsed time: 0.002106189 seconds
# elapsed time: 0.005029223 seconds
# elapsed time: 0.013279454 seconds
# elapsed time: 0.002337617 seconds
# elapsed time: 0.011630164 seconds
# elapsed time: 0.009757026 seconds
# elapsed time: 0.009087066 seconds
# elapsed time: 0.002449577 seconds
# elapsed time: 0.01382468 seconds
# elapsed time: 0.002287478 seconds
# elapsed time: 0.005022323 seconds
# elapsed time: 0.002270893 seconds
# elapsed time: 0.00361245 seconds
# elapsed time: 0.006780578 seconds
# elapsed time: 0.007443935 seconds
# elapsed time: 0.00222819 seconds
# elapsed time: 0.011068978 seconds
# elapsed time: 0.002273793 seconds
# elapsed time: 0.002614948 seconds
# elapsed time: 0.009394735 seconds
# elapsed time: 0.00449258 seconds
# elapsed time: 0.007371427 seconds
# elapsed time: 0.007651534 seconds
# elapsed time: 0.005231965 seconds
# elapsed time: 0.007399001 seconds
# elapsed time: 0.00642558 seconds
# elapsed time: 0.006875925 seconds
# elapsed time: 0.002668783 seconds
# elapsed time: 0.00671158 seconds
# elapsed time: 0.007952892 seconds
# elapsed time: 0.006667889 seconds
# elapsed time: 0.008731085 seconds
# elapsed time: 0.006725574 seconds
# elapsed time: 0.010281947 seconds
# elapsed time: 0.003477673 seconds
# elapsed time: 0.011294998 seconds
# elapsed time: 0.00232533 seconds
# elapsed time: 0.008013006 seconds
# elapsed time: 0.005249872 seconds
# elapsed time: 0.008291468 seconds
# elapsed time: 0.009964635 seconds
# elapsed time: 0.004439992 seconds
# elapsed time: 0.005120834 seconds
# elapsed time: 0.010597956 seconds
# elapsed time: 0.006464605 seconds
# elapsed time: 0.003581501 seconds
# elapsed time: 0.009771449 seconds
# elapsed time: 0.009720073 seconds
# elapsed time: 0.009125648 seconds
# elapsed time: 0.002353476 seconds
# elapsed time: 0.006040401 seconds
# elapsed time: 0.008585824 seconds
# elapsed time: 0.004100821 seconds
# elapsed time: 0.010715789 seconds
# elapsed time: 0.002468303 seconds
# elapsed time: 0.005926742 seconds
# elapsed time: 0.00806919 seconds
# elapsed time: 0.00907883 seconds
# elapsed time: 0.006954036 seconds
# elapsed time: 0.006199816 seconds
# elapsed time: 0.010483766 seconds
# elapsed time: 0.005278181 seconds
# elapsed time: 0.005968089 seconds
# elapsed time: 0.007635003 seconds
# elapsed time: 0.003475425 seconds
# elapsed time: 0.009580397 seconds
# elapsed time: 0.002216965 seconds
# elapsed time: 0.008338967 seconds
# elapsed time: 0.009241361 seconds
# elapsed time: 0.007754701 seconds
# elapsed time: 0.008056627 seconds
# elapsed time: 0.002296206 seconds
# elapsed time: 0.011956785 seconds
# elapsed time: 0.005681107 seconds
# elapsed time: 0.01122349 seconds
# elapsed time: 0.005851163 seconds
# elapsed time: 0.007085547 seconds
# elapsed time: 0.005466489 seconds
# elapsed time: 0.008206748 seconds
# elapsed time: 0.0045767 seconds
# elapsed time: 0.010468111 seconds
# elapsed time: 0.006598998 seconds
# elapsed time: 0.002172373 seconds
# elapsed time: 0.00807267 seconds
# elapsed time: 0.006946585 seconds
# elapsed time: 0.00628136 seconds
# elapsed time: 0.01071478 seconds
# elapsed time: 0.002347338 seconds
# elapsed time: 0.006812716 seconds
# elapsed time: 0.007242355 seconds
# ...
# elapsed time: 0.012768899 seconds
# elapsed time: 0.005245044 seconds
# elapsed time: 0.009810177 seconds
# elapsed time: 0.008379618 seconds
# elapsed time: 0.007893757 seconds
# elapsed time: 0.003644162 seconds
# elapsed time: 0.011783659 seconds
# elapsed time: 0.002226064 seconds
# elapsed time: 0.008551664 seconds
# elapsed time: 0.002449298 seconds
# elapsed time: 0.008413973 seconds
# elapsed time: 0.006773988 seconds
# elapsed time: 0.004453446 seconds
# elapsed time: 0.007754508 seconds
# elapsed time: 0.006715704 seconds
# elapsed time: 0.005039622 seconds
# elapsed time: 0.008042498 seconds
# elapsed time: 0.007030227 seconds
# elapsed time: 0.006459372 seconds
# elapsed time: 0.005848606 seconds
# elapsed time: 0.00570362 seconds
# elapsed time: 0.010825647 seconds
# elapsed time: 0.004975112 seconds
# elapsed time: 0.004738599 seconds
# elapsed time: 0.005908132 seconds
# elapsed time: 0.007921019 seconds
# elapsed time: 0.004078191 seconds
# elapsed time: 0.006828355 seconds
# elapsed time: 0.005356453 seconds
# elapsed time: 0.007206932 seconds
# elapsed time: 0.004139727 seconds
# elapsed time: 0.006486743 seconds
# elapsed time: 0.006929695 seconds
# elapsed time: 0.0078626 seconds
# elapsed time: 0.003882943 seconds
# elapsed time: 0.007111223 seconds
# elapsed time: 0.008712841 seconds
# elapsed time: 0.003422835 seconds
# elapsed time: 0.00608182 seconds
# elapsed time: 0.008397579 seconds
# elapsed time: 0.007542183 seconds
# elapsed time: 0.007224182 seconds
# elapsed time: 0.00697236 seconds
# elapsed time: 0.008579979 seconds
# elapsed time: 0.003879482 seconds
# elapsed time: 0.008897568 seconds
# elapsed time: 0.002774826 seconds
# elapsed time: 0.005175748 seconds
# elapsed time: 0.011250024 seconds
# elapsed time: 0.002182207 seconds
# elapsed time: 0.006045598 seconds
# elapsed time: 0.008415832 seconds
# elapsed time: 0.002190831 seconds
# elapsed time: 0.006836202 seconds
# elapsed time: 0.00800539 seconds
# elapsed time: 0.007208323 seconds
# elapsed time: 0.006944701 seconds
# elapsed time: 0.002994154 seconds
# elapsed time: 0.011366565 seconds
# elapsed time: 0.002243323 seconds
# Episodio terminado con pago total: -200.0
# El total de pasos por episodio: 200.0
# El tiempo total por episodio: 1.4258933130000015
# elapsed time: 0.094525342 seconds
# elapsed time: 0.006297363 seconds
# elapsed time: 0.013640984 seconds
# elapsed time: 0.002848918 seconds
# elapsed time: 0.0065559 seconds
# elapsed time: 0.01186184 seconds
# elapsed time: 0.005410422 seconds
# elapsed time: 0.016049717 seconds
# elapsed time: 0.008784812 seconds
# elapsed time: 0.00909992 seconds
# elapsed time: 0.01178326 seconds
# elapsed time: 0.003097146 seconds
# elapsed time: 0.011755446 seconds
# elapsed time: 0.007158868 seconds
# elapsed time: 0.00997308 seconds
# elapsed time: 0.006415278 seconds
# elapsed time: 0.009643241 seconds
# elapsed time: 0.007302897 seconds
# elapsed time: 0.009141896 seconds
# elapsed time: 0.004665222 seconds
# elapsed time: 0.002268365 seconds
# elapsed time: 0.011119661 seconds
# elapsed time: 0.005957675 seconds
# elapsed time: 0.007968378 seconds
# elapsed time: 0.002041648 seconds
# elapsed time: 0.006227994 seconds
# elapsed time: 0.008831691 seconds
# elapsed time: 0.005640677 seconds
# elapsed time: 0.002060676 seconds
# elapsed time: 0.009791841 seconds
# elapsed time: 0.004046755 seconds
# elapsed time: 0.006438825 seconds
# elapsed time: 0.009510498 seconds
# elapsed time: 0.002133776 seconds
# elapsed time: 0.005468697 seconds
# elapsed time: 0.010052295 seconds
# elapsed time: 0.005902094 seconds
# elapsed time: 0.008055842 seconds
# elapsed time: 0.003837939 seconds
# elapsed time: 0.009012939 seconds
# elapsed time: 0.007939822 seconds
# elapsed time: 0.004338019 seconds
# elapsed time: 0.006239747 seconds
# elapsed time: 0.006010087 seconds
# elapsed time: 0.005447465 seconds
# elapsed time: 0.007322642 seconds
# elapsed time: 0.007290184 seconds
# elapsed time: 0.006860898 seconds
# elapsed time: 0.005914063 seconds
# elapsed time: 0.007778097 seconds
# elapsed time: 0.005324655 seconds
# elapsed time: 0.007161566 seconds
# elapsed time: 0.007961164 seconds
# elapsed time: 0.00572947 seconds
# elapsed time: 0.005135008 seconds
# elapsed time: 0.006781838 seconds
# elapsed time: 0.007988239 seconds
# elapsed time: 0.005677845 seconds
# elapsed time: 0.005033748 seconds
# elapsed time: 0.008677748 seconds
# elapsed time: 0.010052702 seconds
# elapsed time: 0.011360558 seconds
# elapsed time: 0.009713082 seconds
# elapsed time: 0.005713007 seconds
# elapsed time: 0.005178414 seconds
# elapsed time: 0.007308068 seconds
# elapsed time: 0.003765156 seconds
# elapsed time: 0.007316406 seconds
# elapsed time: 0.002269321 seconds
# elapsed time: 0.005156525 seconds
# elapsed time: 0.006158858 seconds
# elapsed time: 0.007988403 seconds
# elapsed time: 0.005743178 seconds
# elapsed time: 0.005361518 seconds
# elapsed time: 0.006657676 seconds
# elapsed time: 0.010587749 seconds
# elapsed time: 0.002304796 seconds
# elapsed time: 0.007807018 seconds
# elapsed time: 0.006734183 seconds
# elapsed time: 0.002498258 seconds
# elapsed time: 0.009123335 seconds
# elapsed time: 0.004603421 seconds
# elapsed time: 0.006358954 seconds
# elapsed time: 0.008159466 seconds
# elapsed time: 0.00701715 seconds
# elapsed time: 0.008635735 seconds
# elapsed time: 0.003345933 seconds
# elapsed time: 0.011117563 seconds
# elapsed time: 0.002900742 seconds
# elapsed time: 0.004567866 seconds
# elapsed time: 0.010372877 seconds
# elapsed time: 0.006509939 seconds
# elapsed time: 0.006740583 seconds
# elapsed time: 0.005833105 seconds
# elapsed time: 0.006454658 seconds
# elapsed time: 0.007852374 seconds
# elapsed time: 0.004128876 seconds
# elapsed time: 0.011380376 seconds
# elapsed time: 0.002104494 seconds
# elapsed time: 0.007884237 seconds
# elapsed time: 0.005036519 seconds
# elapsed time: 0.00461273 seconds
# elapsed time: 0.007016941 seconds
# elapsed time: 0.008664029 seconds
# elapsed time: 0.002358452 seconds
# elapsed time: 0.009815851 seconds
# elapsed time: 0.006614051 seconds
# elapsed time: 0.007870519 seconds
# elapsed time: 0.002911632 seconds
# elapsed time: 0.005451383 seconds
# elapsed time: 0.005791266 seconds
# elapsed time: 0.009186789 seconds
# elapsed time: 0.005113737 seconds
# elapsed time: 0.006874485 seconds
# elapsed time: 0.004836491 seconds
# elapsed time: 0.006984882 seconds
# elapsed time: 0.004630463 seconds
# elapsed time: 0.004018692 seconds
# elapsed time: 0.010449534 seconds
# elapsed time: 0.0052233 seconds
# elapsed time: 0.01119913 seconds
# elapsed time: 0.003092478 seconds
# elapsed time: 0.004137847 seconds
# elapsed time: 0.008570945 seconds
# elapsed time: 0.004254913 seconds
# elapsed time: 0.003803727 seconds
# elapsed time: 0.009011395 seconds
# elapsed time: 0.006670899 seconds
# elapsed time: 0.003464854 seconds
# elapsed time: 0.005148303 seconds
# elapsed time: 0.002259006 seconds
# elapsed time: 0.009703904 seconds
# elapsed time: 0.005557282 seconds
# elapsed time: 0.007063478 seconds
# elapsed time: 0.005114221 seconds
# elapsed time: 0.00884712 seconds
# elapsed time: 0.007146566 seconds
# elapsed time: 0.004967127 seconds
# elapsed time: 0.005430892 seconds
# elapsed time: 0.007169588 seconds
# elapsed time: 0.005152381 seconds
# elapsed time: 0.006585639 seconds
# elapsed time: 0.005221617 seconds
# elapsed time: 0.005514957 seconds
# elapsed time: 0.008556123 seconds
# elapsed time: 0.002210178 seconds
# elapsed time: 0.005800933 seconds
# elapsed time: 0.008096558 seconds
# elapsed time: 0.002248469 seconds
# elapsed time: 0.010447213 seconds
# elapsed time: 0.004778216 seconds
# elapsed time: 0.00815253 seconds
# elapsed time: 0.006511665 seconds
# elapsed time: 0.011275214 seconds
# elapsed time: 0.002307224 seconds
# elapsed time: 0.009041494 seconds
# elapsed time: 0.00689729 seconds
# elapsed time: 0.002259637 seconds
# elapsed time: 0.010062251 seconds
# elapsed time: 0.005889355 seconds
# elapsed time: 0.009708997 seconds
# elapsed time: 0.007949883 seconds
# elapsed time: 0.01386766 seconds
# elapsed time: 0.015073736 seconds
# elapsed time: 0.003886092 seconds
# elapsed time: 0.012056389 seconds
# elapsed time: 0.008183584 seconds
# elapsed time: 0.010396168 seconds
# elapsed time: 0.006382571 seconds
# elapsed time: 0.008128963 seconds
# elapsed time: 0.01233837 seconds
# elapsed time: 0.005740948 seconds
# elapsed time: 0.014273755 seconds
# elapsed time: 0.009249317 seconds
# elapsed time: 0.006027061 seconds
# elapsed time: 0.017872432 seconds
# elapsed time: 0.009876147 seconds
# elapsed time: 0.013657227 seconds
# elapsed time: 0.007813223 seconds
# elapsed time: 0.011668687 seconds
# elapsed time: 0.011204208 seconds
# elapsed time: 0.008280253 seconds
# elapsed time: 0.00526758 seconds
# elapsed time: 0.011736792 seconds
# elapsed time: 0.010752783 seconds
# elapsed time: 0.006817401 seconds
# elapsed time: 0.00705937 seconds
# elapsed time: 0.006207591 seconds
# elapsed time: 0.003616301 seconds
# elapsed time: 0.006683708 seconds
# elapsed time: 0.006016228 seconds
# elapsed time: 0.007152712 seconds
# elapsed time: 0.007424883 seconds
# elapsed time: 0.003467326 seconds
# elapsed time: 0.007315123 seconds
# elapsed time: 0.015749625 seconds
# elapsed time: 0.005011179 seconds
# elapsed time: 0.007403186 seconds
# elapsed time: 0.003497229 seconds
# elapsed time: 0.004978122 seconds
# Episodio terminado con pago total: -200.0
# El total de pasos por episodio: 200.0
# El tiempo total por episodio: 1.5006358579999997
# elapsed time: 0.093309057 seconds
# elapsed time: 0.013822756 seconds
# elapsed time: 0.005719278 seconds
# elapsed time: 0.011471498 seconds
# elapsed time: 0.007914923 seconds
# elapsed time: 0.005015543 seconds
# elapsed time: 0.00985499 seconds
# elapsed time: 0.005443149 seconds
# elapsed time: 0.015955555 seconds
# elapsed time: 0.003160128 seconds
# elapsed time: 0.012105242 seconds
# elapsed time: 0.007495785 seconds
# elapsed time: 0.005442365 seconds
# elapsed time: 0.010922215 seconds
# elapsed time: 0.003785012 seconds
# elapsed time: 0.009381336 seconds
# elapsed time: 0.007324576 seconds
# elapsed time: 0.007608146 seconds
# elapsed time: 0.007189129 seconds
# elapsed time: 0.008489896 seconds
# elapsed time: 0.007727112 seconds
# elapsed time: 0.005432953 seconds
# elapsed time: 0.007771556 seconds
# elapsed time: 0.010268495 seconds
# elapsed time: 0.002401043 seconds
# elapsed time: 0.00660815 seconds
# elapsed time: 0.005392037 seconds
# elapsed time: 0.008005089 seconds
# elapsed time: 0.003742482 seconds
# elapsed time: 0.004179382 seconds
# elapsed time: 0.006107604 seconds
# elapsed time: 0.010170769 seconds
# elapsed time: 0.002464814 seconds
# elapsed time: 0.008340404 seconds
# elapsed time: 0.005228382 seconds
# elapsed time: 0.00391516 seconds
# elapsed time: 0.008585011 seconds
# elapsed time: 0.00443444 seconds
# elapsed time: 0.008289643 seconds
# elapsed time: 0.006529675 seconds
# elapsed time: 0.010073966 seconds
# elapsed time: 0.002395051 seconds
# elapsed time: 0.010605702 seconds
# elapsed time: 0.006592051 seconds
# elapsed time: 0.004786274 seconds
# elapsed time: 0.00729129 seconds
# elapsed time: 0.003745385 seconds
# elapsed time: 0.009244444 seconds
# elapsed time: 0.005648515 seconds
# elapsed time: 0.006343404 seconds
# elapsed time: 0.009582923 seconds
# elapsed time: 0.002254195 seconds
# elapsed time: 0.007583022 seconds
# elapsed time: 0.009852325 seconds
# elapsed time: 0.008331078 seconds
# elapsed time: 0.00333668 seconds
# elapsed time: 0.004823725 seconds
# elapsed time: 0.011303694 seconds
# elapsed time: 0.008365203 seconds
# elapsed time: 0.007214389 seconds
# elapsed time: 0.00432979 seconds
# elapsed time: 0.008423971 seconds
# elapsed time: 0.003469224 seconds
# elapsed time: 0.008206105 seconds
# elapsed time: 0.008783477 seconds
# elapsed time: 0.003435395 seconds
# elapsed time: 0.008553702 seconds
# elapsed time: 0.004464748 seconds
# elapsed time: 0.005142515 seconds
# elapsed time: 0.006394952 seconds
# elapsed time: 0.005538703 seconds
# elapsed time: 0.009761126 seconds
# elapsed time: 0.00438562 seconds
# elapsed time: 0.005722481 seconds
# elapsed time: 0.008190345 seconds
# elapsed time: 0.002210166 seconds
# elapsed time: 0.007939948 seconds
# elapsed time: 0.007460096 seconds
# elapsed time: 0.007799468 seconds
# elapsed time: 0.00839012 seconds
# elapsed time: 0.002029828 seconds
# elapsed time: 0.007759263 seconds
# elapsed time: 0.007407023 seconds
# elapsed time: 0.00690503 seconds
# elapsed time: 0.006507323 seconds
# elapsed time: 0.007081966 seconds
# elapsed time: 0.007101694 seconds
# elapsed time: 0.002427654 seconds
# elapsed time: 0.004783053 seconds
# elapsed time: 0.006678685 seconds
# elapsed time: 0.003291733 seconds
# elapsed time: 0.008767808 seconds
# elapsed time: 0.00490524 seconds
# elapsed time: 0.008523616 seconds
# elapsed time: 0.005651325 seconds
# elapsed time: 0.008484148 seconds
# elapsed time: 0.00677572 seconds
# elapsed time: 0.004959417 seconds
# elapsed time: 0.010231313 seconds
# elapsed time: 0.00977795 seconds
# elapsed time: 0.006669002 seconds
# elapsed time: 0.002250339 seconds
# elapsed time: 0.005275939 seconds
# elapsed time: 0.010453203 seconds
# elapsed time: 0.003844952 seconds
# elapsed time: 0.008579747 seconds
# elapsed time: 0.007361013 seconds
# elapsed time: 0.002122987 seconds
# elapsed time: 0.010125773 seconds
# elapsed time: 0.00659489 seconds
# elapsed time: 0.003653757 seconds
# elapsed time: 0.010710755 seconds
# elapsed time: 0.002493734 seconds
# elapsed time: 0.014633894 seconds
# elapsed time: 0.004270135 seconds
# elapsed time: 0.011850777 seconds
# elapsed time: 0.003914293 seconds
# elapsed time: 0.007209579 seconds
# elapsed time: 0.005352546 seconds
# elapsed time: 0.008087221 seconds
# elapsed time: 0.002327392 seconds
# elapsed time: 0.002705363 seconds
# elapsed time: 0.009751892 seconds
# elapsed time: 0.005286007 seconds
# elapsed time: 0.005803381 seconds
# elapsed time: 0.005126968 seconds
# elapsed time: 0.009183053 seconds
# elapsed time: 0.006594849 seconds
# elapsed time: 0.007634528 seconds
# elapsed time: 0.006625007 seconds
# elapsed time: 0.002201435 seconds
# elapsed time: 0.008564077 seconds
# elapsed time: 0.006134545 seconds
# elapsed time: 0.006300435 seconds
# elapsed time: 0.009067094 seconds
# elapsed time: 0.002525601 seconds
# elapsed time: 0.008417784 seconds
# elapsed time: 0.008300685 seconds
# elapsed time: 0.002424268 seconds
# elapsed time: 0.009345907 seconds
# elapsed time: 0.002221869 seconds
# elapsed time: 0.008319549 seconds
# elapsed time: 0.009573202 seconds
# elapsed time: 0.005404083 seconds
# elapsed time: 0.002236593 seconds
# elapsed time: 0.00649919 seconds
# elapsed time: 0.007502578 seconds
# elapsed time: 0.005540484 seconds
# elapsed time: 0.003866207 seconds
# elapsed time: 0.007052893 seconds
# elapsed time: 0.006414254 seconds
# elapsed time: 0.007942197 seconds
# elapsed time: 0.003358824 seconds
# elapsed time: 0.005144728 seconds
# elapsed time: 0.008233394 seconds
# elapsed time: 0.00609517 seconds
# elapsed time: 0.002201524 seconds
# elapsed time: 0.009579604 seconds
# elapsed time: 0.004253605 seconds
# elapsed time: 0.003323753 seconds
# elapsed time: 0.012053122 seconds
# elapsed time: 0.005305911 seconds
# elapsed time: 0.007010672 seconds
# elapsed time: 0.006652131 seconds
# elapsed time: 0.004013951 seconds
# elapsed time: 0.007361706 seconds
# elapsed time: 0.004317329 seconds
# elapsed time: 0.006887704 seconds
# elapsed time: 0.008340557 seconds
# elapsed time: 0.002229264 seconds
# elapsed time: 0.00719839 seconds
# elapsed time: 0.006986688 seconds
# elapsed time: 0.011155835 seconds
# elapsed time: 0.002612782 seconds
# elapsed time: 0.00544158 seconds
# elapsed time: 0.008556223 seconds
# elapsed time: 0.006642821 seconds
# elapsed time: 0.007801302 seconds
# elapsed time: 0.007310064 seconds
# elapsed time: 0.004014688 seconds
# elapsed time: 0.006566181 seconds
# elapsed time: 0.005755962 seconds
# elapsed time: 0.007334292 seconds
# elapsed time: 0.006994778 seconds
# elapsed time: 0.002231433 seconds
# elapsed time: 0.009728582 seconds
# elapsed time: 0.003619727 seconds
# elapsed time: 0.005383125 seconds
# elapsed time: 0.008650315 seconds
# elapsed time: 0.002633579 seconds
# elapsed time: 0.008881937 seconds
# elapsed time: 0.002887122 seconds
# elapsed time: 0.004585943 seconds
# elapsed time: 0.008327782 seconds
# elapsed time: 0.005765932 seconds
# elapsed time: 0.002526095 seconds
# elapsed time: 0.003453288 seconds
# elapsed time: 0.006386538 seconds
# elapsed time: 0.006935554 seconds
# elapsed time: 0.00714306 seconds
# Episodio terminado con pago total: -200.0
# El total de pasos por episodio: 200.0
# El tiempo total por episodio: 1.3972522899999993

# %% [markdown]
# # 2. Control optimo
#
# La regla de toma de decision del agente se conoce como *politica*. La regla no tiene porque ser deterministica, y de hecho, matematicamente conviente pensar esta regla como una distribucion de probabilidad sobre todas las posibles acciones. Para ser mas preciso, una politica es una forma de convertir el estado actual $S_t$ en un accion $A_t$, es decir, es una familia de distribuciones condicionales $\pi(A_t \mid S_t) := P(A_t \mid S_t)$.
#
# El problema del control optimo es el de encontrar una politica $\pi^*$ para un MDP que maximice la ganancia total
# $$
# \pi^* = \mathrm{argmax}_\pi E \left[ R_{t+1} + \gamma R_{t+2} + \gamma^2 R_{t+3} \cdots  \gamma^{T-1} R_T\right].
# $$
# En esta formula, necesitamos una esperanza porque la suma total de ganancias es aleatoria. El simbolo $\gamma$ es una constante $0<\gamma\leq 1$ que representa la preferencia intertemporal. Cuando $\gamma < 1$, se valora mas un retorno en el presente que en el futuro; nosotros supondremos $\gamma = 1$ por simplicidad.
#
# Teoricamente, el trabajo de Bellman y Howard de Programacion Dinamica para MDPs mostro que siempre es posible encontrar la politica optima si se conoce completamente las probabilidades de transicion $P(S_{t+1}, R_{t+1}| S_t, A_t)$ del MDP. En la practica, enfrentamos un problema adicional: normalmente el agente intentando aprender no conoce las probabilidades de transicion del MDP y por lo tanto no puede recurrir a los metodos exactos de la programacion dinamica para encontrar una politica optima; mas aun, aun cuando si pueda conocer estas probabilidades, en ocasiones la cantidad de estados del sistema es tan grande que los metodos analiticos de la programacion dinamica no son suficiente (por ejemplo, se estima que una partida de ajedrez puede tener hasta $10^{45}$ configuraciones distintas, totalmente intratable para los metodos exactos).

# %% [markdown]
# ## Las Ecuaciones de Bellman
#
# Aunque los metodos de Programacion Dinamica son frecuentemente impracticos para buscar politicas optimas, son la piedra angular para entender las estrategias exitosas de solucion. Si un sistema se encuentra en un estado $S_t$, el valor esperado que recibira el agente al tomar la decision $A_t$ es
# $$
# Q_\pi(S_t,A_t) := E_\pi\left[ R_{t+1} + \gamma R_{t+2} + \gamma^2 R_{t+3} \cdots  \gamma^{T-1} R_T \mid S_t, A_t \right]
# $$
# Las ecuaciones de Bellman son ecuaciones recursivas en terminos de la *la funcion de valor estado-accion $Q$*. La propiedad de Markov garantiza que en cualquier momento del tiempo, el futuro del sistema depende solo de su estado actual y de la decision del agente. Como consecuencia de esta "perdida de memoria", despues de una transicion $(S_t, A_t) \to (S_{t+1}, R_{t+1})$ y una proxima accion $A_{t+1}$ del agente, el sistema vuelve a empezar, por lo que se tiene la identidad
# $$
# Q_\pi(S_t,A_t) = E_\pi\left[R_{t+1} + \gamma Q_\pi(S_{t+1}, A_{t+1})]\right] \quad\quad \text{(Ecuacion de Bellman 1)}
# $$
# La ecuacion anterior debe una historia:
#
# <blockquote> El agente (con politica) $\pi$ se encuentra en el estado $S_t$ y decide la accion $A_t$. Justo en este momento tiene una promesa de pago futuro de $Q_\pi(S_t, A_t)$. Tras decidir, el sistema transiciona al estado $S_{t+1}$ recibiendo un pago recibe un pago de $R_{t+1}$ por su decision. Ahora tendra que decidir nuevamente una accion $A_{t+1}$ y tendra una promesa de pago futuro de $Q_\pi(S_{t+1}, A_{t+1})$. El pago $R_{t+1}$ que recibio mas la esperanza de pago futuro $Q_\pi(S_{t+1}, A_{t+1})$ deben de ser igual a la promesa de pago $Q_\pi(S_t, A_t)$ que tenia entes de la transicion.
# </blockquote>
#
# Esta ecuacion es la primera de las ecuaciones de Bellman y se cumple para todas las politicas $\pi$. La utilidad de esta ecuacion es evaluar la politica actual $\pi$.
#
# Aunque existen formar de mejorar la politica $\pi$ una vez que se conoce $Q_\pi$, Bellman tambien encontro una ecuacion recursiva que se cumple unicamente por la politica optima $\pi^*$ y que puede ser usada para encontrar la politica optima directamente. La segunda ecuacion o *ecuacion de optimalidad de Bellman* dice
#
# $$
# Q_{\pi^*}(S_t,A_t) = E_{\pi^*}\left[ R_{t+1} + \gamma \max_A Q_{\pi^*}(S_{t+1}, A)]\right] \quad\quad \text{(Ecuacion de Bellman 2)}.
# $$
#
# El mecanismo detras de esta expresion recursiva descubierta por Bellman se basa en que un individuo racional siempre escoge la accion que maximiza su utilidad esperada, que en terminos de la funcion $Q_{\pi^*}$ implica
# $$
# \pi^*(S_t) = \mathrm{argmax}_A Q_{\pi^*}(S_t,A).
# $$

# %% [markdown]
# ## Reinforcement Learning
#
# El *Reinforcement Learning* (RL) busca resolver las limitaciones que de la programacion Dinamica tradicional para resolver MDPs. En RL tener un modelo del ambiente (probabilidades de transicion) es optativo y sirve para hacer planeacion y mejorar los algoritmos, pero no es necesario. Las estrategias de Reinforcement Learning evaluan una politica y la mejoran siguiendo estrategias iterativas.
#
# Podriamos agrupar a los diversos metodos del RL en tres grupos dependiendo de su grado de "supervision":
#
# 1. **Metodos de Programacion Dinamica**: Utilizan de forma directa las ecuaciones de Bellman y necesitan de un conocimiento de las probabilidades de transicion $P(S_{t+1},A_{t+1}\mid S_t, A_t)$, de lo contrario, pueden intentar estimarlas estadisticamente a traves de simulacion. Aunque son muy precisos, son altamente demandantes en terminos de memoria y poder computacional, y requieren de un conocimiento de las probabilidades de transicion del ambiente que rara vez se tienen completamente disponibles.
# 2. **Metodos de Funciones de Valor**: En vez de intentar conocer las probabilidades de transicion, estos metodos buscan estimar la funcion de valor $Q$ de la politica optima usando la ley de los grandes numeros (LGN). Una vez estimada la funcion Q optima, podemos recuperar la politica optima poniendo $\pi^*(S_t) = \mathrm{argmax}_A Q_{\pi^*}(S_t,A)$. Mas adelante veremos en que formas las Ecuaciones de Bellman y la LGN permiten conocer $Q$.
# 3. **Metodos de Gradientes de Politica**: Este ultimo grupo es el menos supervisado y trata directamente  de encontrar unas distribuciones de probabilidad $\pi(A \ S)$ para cada pareja estado-accion $(S,A)$, sin pasar por la funcion $Q$, y tratando de maximizar la utilidad acumulada $R_{t+1} + \gamma R_{t+2} + \cdots + \gamma^{T-1}$. Es es el metodo buscar patrones en los estados $S_t$ que directamente se correlacionen con mayores pagos.
#
# Ambos enfoque 2 y 3 son muy populares actualmente. La ventaja de los ultimos es que tienen menos supuestos al ser menos estructrados. Su desventaja es que tambien son mayores cajas negras y en la practica pueden ser tan o mas dificiles de implementar. Aun no queda claro cual es el mejor enfoque, si es que hay alguno, pueden leer una comparacion en [este link](http://www.mcgovern-fagg.org/amy/pubs/tr-06-001.pdf).
#
# **Nosotros vamos a utilizar el el enfoque de funciones de valor**, pues da un equilibrio entre estructura y practicidad.
#
# ## Politcas optimas y $\epsilon$-greegy
#
# En la realidad, nuestros algoritmos no escogeran siempre la decision optima $\pi^*(S_t)$, pero si con una probabilidad $(1-\epsilon)$ donde $\epsilon$ ira decreciendo con el tiempo. El problema de escoger siempre la decision optima es que en la practica no sabemos a la perfeccion los parametros del MDP, y un agente que no explore, tiene el riesgo de llegar a conclusiones equivocadas prematuramente y nunca encontrar la politica optima. Este tipo de politicas se conocen como $\epsilon$-greedy.
#
# ## Implementacion en Julia de la funcion de valor Q

# %% [markdown]
# <span style="color: blue">**Advertencia!**  **Hasta nuevo aviso, supondremos que el conjunto de estados es discreto, pues aun no estamos en facultad de desarollar teoria para conjuntos de estados continuos.**.</span>
#
# La forma mas tentadora de almacenar la informacion de $Q$ es utilizando una matriz o un vector. Pero usualmente es mucho mas conveniente usar *tablas hash*, que en Julia (y Python) son llamadas *diccionarios*. Una tabla hash es una estructura de datos que consiste de *claves* y *valores*, asignando a cada clave un valor. Es una estructura no ordenada, a diferencia de un vector. Estas son algunas ventajas
#
# * Usualmente iniciamos los diccionarios vacios y agregamos claves la primera vez que ocurren. En problemas de reinforcement learning hay muchisimos estados que nunca son visitados y que resulta ineficiente o imposible almacenar un valor para cada estado (como en el ajedrez). Las tablas has permite solo asignar valores a las tuplas (estado, accion) observadas, mas similar a como aprendemos en la realidad.
# * Con un diccionario los estados pueden ser claves aunque en si mismos sean arrays o objetos compuestos. Muchas otras estructuras necesitan de "nombres" en los estados, y por lo tanto solo pueden ser strings.
#
# Para inicializar un diccionaro vacio en Julia usamos la funcion `Dict`

# %%
Q = Dict()
# Out:
# Dict{Any,Any} with 0 entries

# %% [markdown]
# Las parejas estado-accion se pueden modelar como tuplas, representadas en Julia con parentesis $(s,a)$. El siguiente ejemplo muestra como manipular $Q$ como un diccionario que tiene como claves las tuplas $(s,a)$. Se pueden usar brackets [ ] para acceder el valor de las claves del diccionario y para signar nuevos valores.

# %%
estado = "Some state"
accion = "Some action"
Q[(estado, accion)] = 1.
Q[(estado, accion)]
# Out:
# 1.0

# %% [markdown]
# Para acceder a las claves actualmente guardadas se puede usar el comando

# %%
keys(Q)
# Out:
# Base.KeyIterator for a Dict{Any,Any} with 1 entry. Keys:
#   ("Some state","Some action")

# %% [markdown]
# Tambien podemos consultar si el diccionario tiene una clave

# %%
haskey(Q, (estado, accion))
# Out:
# true

# %% [markdown]
# Una funcion implementada comunmente es las tablas Hash es el metodo `get` que busca una clave y si no la encuentra regresa un valor *default*

# %%
default_value = 0.
get(Q, "I am not a key", default_value)
# Out:
# 0.0

# %% [markdown]
# ## Implementacion en Julia de una politica $\epsilon$-greedy en Julia
#
# La implementacion de la politica de un agente puede ser implica o explicita
# * Es *explicita* si dado un estado devuelve la distribucion de probabilidad de la politica
# * Es *implicita* si dado un estado devuelve una observacion de la distribucion de la politica
# Aunque matematicamente modelamos una politica como una distribucion de probabilidad para cada estado. En la practica es muchas veces conveniente modelarla implicitamente. Una de las ventajas de los metodos de funciones de valor es que funcionan muy bien con politicas implicitas, que no necesitan almacenar una gran cantidad de valores por cada combinacion de estado accion, si no que reciben directamente a la funcion de valor $Q$ como argumento una accion.
#
# La politica debe consistir en los siguientes ingredientes:
#
# > ### Ingredientes de una politica de tipo $\epsilon$-greedy:
# > * **Inputs**
# >    1. `state`: el estado actual en el cual se tiene que tomar una accion
# >    2. `actions`: las acciones disponibles al estado `state`
# >    3. `Q`: la mejor estimacion hasta el momento de la matriz `Q`, que se usara para tomar la decision greedy $$\mathrm{greedy}(\text{state}) = \mathrm{argmax}_{a\in\text{actions}} Q(\text{state}, a)$$
# >    4. $\epsilon$: la probabilidad de tomar una decision completamente al azar y no greedy
# > * **Output**
# >    + La accion $\mathrm{policy}(\text{state})$ decidida por
# >        - aleatoriamente entre cualquier accion con probabilidad $\epsilon$
# >        - aleatoriamente entre las acciones que maximicen $Q(\text{state}, \cdot)$ con probabilidad $1-\epsilon$.

# %%
"""
Returns an action according to an ϵ-greedy policy given an estimate of the action value function Q.
"""
function policy(state::Any, action_space::Any, Q::Dict, ϵ::Float64)
    random_number = rand()
    if random_number < ϵ
        return rand(action_space) #  totalmente aletorio
    else
        max_Q = maximum([get(Q, (state, a), 0.) for a in action_space]) # max_a Q(state, a)
        greedy_actions = [a for a in action_space if get(Q, (state, a), 0.) == max_Q] # argmax_a Q(state, a)
        return rand(greedy_actions) # aleatorio entre las mejores acciones solamente
    end
end
# Out:
# policy

# %% [markdown]
# **EJEMPLO DE USO**

# %%
Q = Dict()
ϵ = 0.25 # 25% de aleatoriedad total
state = "Some state"
action_space = 0:3
Q[(state, 0)] = Q[(state, 3)] = 1. # Las mejores acciones son 0 y 3
Q[(state, 1)] = Q[(state, 2)] = 0. # Las peores acciones son 1 y 2
for i in 1:30 # Imprime 30 simulaciones de acciones
    print(policy(state, action_space, Q, 0.1), " ")
end
# Out:
# 3 0 3 3 0 0 0 0 0 3 3 0 3 0 0 3 1 0 3 0 3 0 0 3 0 3 0 3 3 0

# %% [markdown]
# ### <span style='color: red'> Ejercicio 2 </span>
#
# 1. Para el juego de MountainCar describe en una o dos oraciones lo que consideres es una politica optima
# 2. Para el juego de Pong describe en una o dos oraciones que consideres es una politica optima
# 3. Describe  en una o dos oraciones los potenciales peligros de tener una politica $\epsilon$-greedy en la que $\epsilon$ sea demasiado baja.
# 4. Resume en una o dos oraciones las diferencias entre las dos ecuaciones de Bellman.
# 5. Porque decimos que las ecuaciones de Bellman son recursivas?

# %% [markdown]
# ### <span style='color: red'> Respuestas ejercicio 2 </span>
#
# 1. Para el juego de MountainCar describe en una o dos oraciones lo que consideres es una politica optima,
#
#     R. Sabemos que el Reward es -1 para cada paso en el tiempo, hasta alcanzar la posición objetivo de 0,5
#     y el conjunto de acciones y el espacio de acciones es A={[0,push left],[1,no push],[2, push right]}. La política óptima que se puede plantear sería por ejemplo que se incrementara el reward cuando el carro alcance la parte superior de la montaña, al tomar la acción de empujar hacia adelante,considerando los menos pasos posibles.
#
#
# 2. Para el juego de Pong describe en una o dos oraciones que consideres es una politica optima
#
# R.  Sabemos que el espacio de estados es una caja de dimensiones 210x160x3; el conjuno de acciones en este caso es discreto, solo puede obtener los valores 0−5.  Una política óptima podría ser aquella que en que la distancia entre pixeles sea pequeña. La idea es que la política pueda captar que la distancia de la pelotita con el pile sea mínima y optener mayor recompenza.
#
#
# 3. Describe en una o dos oraciones los potenciales peligros de tener una política ϵϵ-greedy en la que ϵϵ sea demasiado baja.
#
# R. Que un agente no explore y que no se pueda obtener una política óptima. Mientras más pequeña sea ϵϵ puede que no se explore todo el espacio.
#
# 4. Resume en una o dos oraciones las diferencias entre las dos ecuaciones de Bellman.
#
# R. La primera ecuación se cumple para todas las políticas, mientras que la segunda solo se cumple para aquella
# que es una política óptima.
#
# 5. ¿Por qué decimos que las ecuaciones de Bellman son recursivas?
#
# Debido a que las variables que queremos encontrar dependen del tiempo y la solucion en un momento $t$ se puede
# expresar en términos de la solución al tiempo $t-1$. La idea central del trabajo de Bellman consiste en que para
# encontrar las decisiones óptimas $A_t, A_{t+1},...$ de forma que maximicen el total de pagos recibidos en el tiempo
# $R_{t+1},R_{t+2}, ...$ tenemos que suponer que el estado futuro del sistema es independiente del pasado (pérdida de
# memoria) condicionado a su estado actual y de las decisiones del agente. Esta propiedad se conoce como la propiedad
# de Markov.
#
# En otras palabras, las ecuaciones de Bellman son recursivas en términos de la función de valor estado accion $Q$. La propiedad de Marcov garantiza que en cualquier momento del tiempo el futuro del sistema depende de su estado actual y de la decisión del agente.

# %% [markdown]
# ## 3. Metodos tabulares de control optimo: Q-Learning y Sarsa
#
# Como mencionamos antes, los metodos de control optimo de Reinforcement Learning que vamos a usar se basan en la estimacion de la funcion de valor $Q$ y para eso usan las Ecuaciones de Bellman y la Ley de los Grandes Numeros (LGN). Vamos a tratar de clarificar un poco mas la razon.
#
# ***Ley de los Grandes Numeros:* ** si se tiene una muestra de variables aleatorias independientes e identicas $X_1,...,X_n$ (con esperenza finita) entonces
# $$
# \frac{1}{n}\sum_{i=1}^nX_i \stackrel{n\to\infty}{\to} E[X_i].
# $$
#
# Las exposiciones formales de los metodos de RL por funciones de valor y sus propiedades de convergencia puede ser muy extensa, pero la intuicion es increiblemente simple. Por ejemplo, para utilizar la LGN junto con la primera ecuacion de Bellman podemos hacer lo siguiente:
#
# <blockquote>
# <h3> Derivacion intuitiva de SARSA </h3>
# <oi>
# <li> Denotemos $Q_t$ la estimacion de $Q$ disponible al tiempo $t$.
# <li> Como
# $$E \left[ R_{t+1} + \gamma Q(S_{t+1}, A_{t+1}) \right] - Q(S_t, A_t) = 0$$
# segun la primera ecuacion de Bellman, entonces las diferencia
# $$
# \delta_t(S_t, A_t) = R_{t+1} + \gamma Q_t(S_{t+1}, A_{t+1})  - Q_t(S_t, A_t)
# $$
# nos da informacion de que tan bien o que tan mal esta la estimacion actual $Q_t(S_t, A_t)$.
# <li>  Como las cantidades $\delta_t(S_t, A_t)$ son "en promedio" cero segun la LGN, entonces podemos dar pequeños pasas en la direccion $\delta_t(S_t, A_t)$ para mejorar nuestra estimacion. Conforme los estados $(S_t, A_t)$ sigan aparenciendo en el futuro, tendremos una buena estimacion de $Q(S_t, A_t)$. Matematicamente
# $$
# Q_t(S_t, A_t) + \alpha \delta_t \stackrel{t\to \infty}{ \to} Q(S_t, A_t).
# $$
# <li> La constante $0 < \alpha < 1$ se conoce como **velocidad de aprendizaje**. Valores tipicos son $\alpha \approx 0.025, 0.05, 0.1$ pero puede variar mucho de aplicacion en aplicacion.
# <li>  Una interpretacion intuitiva de $\alpha$ es que define una nueva estimacion $Q_{t+1}(S_t, A_t)$, dandole un peso $(1-\alpha)$ a la estimacion actual $Q_t(S_t, A_t)$ y un peso $\alpha$ a la estimacion $R_{t+1} + \gamma Q_t(S_{t+1}, A_{t+1}) $.
# </oi>
# </blockquote>
#
# La idea anterior se convierte en un metodo de control para encontrar una politica "optima" (ver el ejercicio debajo) llamado SARSA. El nombre SARSA se deriva de la regla de actualizacion de $Q$ que utiliza las variables $S_t, A_t, R_{t+1}, S_{t+1}, A_{t+1}$. La convergencia de este metodo (y tambien los casos en los que podria fallar) esta explicada por las teoria de *Aproximacion Estocastica*.
#
#
# > ### SARSA
# >
# > **Inputs**:
#   * Velocidad de aprendizaje $0 < \alpha < 1$
#   * Tasa de descuento de la utilidad en el futuro $0 < \gamma \leq 1$
#   * Una politica, tipicamente $\epsilon$-greedy.
# >
# > **Outputs**
# > * Una estimacion de la funcion de valor $Q$ bajo la politica $\epsilon$-greedy
# >
# > **Algoritmo**
# > * **Inicializar** $Q$.
# > * **Para cada episodio** con estado-accion inicial $(s_0, a_0)$:
# >    + Para cada $t$ mientras el episodio no haya terminado:
# >        - **Hacer una transicion** a un nuevo estado-accion $(s_{t+1}, a_{t+1})$ obteniendo un pago $r_{t+1}$.
# >        - <span style='color: blue'>**Calcular la diferencia en utilidad segun la regla SARSA**</span>
# >          $$ \delta_t = r_{t+1} + \gamma Q(s_{t+1}, a_{t+1}) - Q(s_t,a_t) $$
# >        - **Actualizar el valor de $Q$**:
# >            $$ Q(s,a) = Q(s,a) + \alpha\delta_t$$
#
# Cada vez que el algoritmo encuentre una pareja $(s,a)$ le debe asignar un valor por *default* a $Q(s,a)$. Lo tradicional es asignarle el valor $0$. Las propiedades de convergencia estocastico hacen que no importe este valor inicial.
#
# SARSA es un metodo **tabular** porque Q se calcular para cada posible tupla estado-accion. En la proxima tarea veran metodos aproximados que reducen el espacio de estados a un numero selecto de *features*.

# %% [markdown]
# ### <span style='color: red'> Ejercicio 3 </span>
#
# 1. Con SARSA se obtiene un estimacion de la funcion de valor $Q$ de la politica optima? Si no se obtiene la politica optima, que politica se obtiene? Es necesariamente malo una politica suboptima durante el proceso de aprendizaje?
# 2. **(Q-LEARNING)** El famoso algoritmo Q-Learning (Watkins 1989) es identico al de SARSA salvo en una linea, reemplazamos la regla SARSA para $\delta_t$ por
# $$ \delta_t = r_{t+1} + \gamma \max_a Q_{\pi^*}(s_{t+1}, a) - Q(s_t,a_t) $$
# Imitando la derivacion intuitiva de SARSA, explica intuitivamente el algoritmo Q-Learning usando la ecuacion de optimalidad de Bellman.
# 3. SARSA se clasifica como un metodo de control *on-policy* y Q-Learning como *off-policy*. La razon es que no estiman la misma Q: uno de los metodos estima la optima y el otro no, incluso si ambos se implementan usando la misma politica $\epsilon$-greedy. Investiga en maximo un parrafo mas sobre la diferencia entre SARSA y Q-Learning (o entre control *on-policy* y *off-policy*) y contesta: Es mejor un metodo off-policy que un metodo on-policy?
# 4. Hay diferencia entre SARSA y Q-Learning conforme $\epsilon \to 0$?

# %% [markdown]
# ### <span style='color: red'>Respuestas Ejercicio 3 </span>
#
# 1. Con SARSA se obtiene un estimacion de la funcion de valor $Q$ de la politica optima? Si no se obtiene la politica optima, que politica se obtiene? Es necesariamente malo una politica suboptima durante el proceso de aprendizaje?
#
# R. No, SARSA compara el estado actual vs el estato actual siguiente.Se optine la mejor política dado epsilon. No es malo, pero usarla depende del problema del que estemos hablando.
#
#
#
# 2. **(Q-LEARNING)** El famoso algoritmo Q-Learning (Watkins 1989) es identico al de SARSA salvo en una linea, reemplazamos la regla SARSA para $\delta_t$ por
# $$ \delta_t = r_{t+1} + \gamma \max_a Q_{\pi^*}(s_{t+1}, a) - Q(s_t,a_t) $$
# Imitando la derivacion intuitiva de SARSA, explica intuitivamente el algoritmo Q-Learning usando la ecuacion de optimalidad de Bellman.
#
# <blockquote>
# <h3> Derivacion intuitiva de Q-Learning </h3>
# <oi>
# <li> Denotemos $Q_t$ la estimacion de $Q$ disponible al tiempo $t$.
# <li> Como
# $$E \left[ R_{t+1} + \gamma \max_a Q_{\pi^*}(S_{t+1}, A)) \right] - Q(S_t, A_t) = 0$$
# segun la segunda ecuacion de Bellman, entonces las diferencia
# $$
# \delta_t(S_t, A_t) = R_{t+1} + \gamma max(Q_t(S_{t+1}, A))  - Q_t(S_t, A_t)
# $$
# nos da informacion de que tan bien o que tan mal esta la estimacion actual $Q_t(S_t, A_t)$ de $Q_*$
# <li>  Como las cantidades $\delta_t(S_t, A_t)$ son "en promedio" cero segun la LGN, entonces podemos dar pequeños pasas en la direccion $\delta_t(S_t, A_t)$ para mejorar nuestra estimacion. Conforme los estados $(S_t, A_t)$ sigan aparenciendo en el futuro, tendremos una buena estimacion de $Q(S_t, A_t)$. Matematicamente
# $$
# Q_t(S_t, A_t) + \alpha \delta_t \stackrel{t\to \infty}{ \to} Q_*(S_t, A_t).
# $$
#
# </oi>
# </blockquote>
#
#
# 3. SARSA se clasifica como un metodo de control on-policy y Q-Learning como off-policy. La razon es que no estiman la misma Q: uno de los metodos estima la optima y el otro no, incluso si ambos se implementan usando la misma politica ϵϵ-greedy. Investiga en maximo un parrafo mas sobre la diferencia entre SARSA y Q-Learning (o entre control on-policy y off-policy) y contesta: Es mejor un metodo off-policy que un metodo on-policy?
#
#
# La mayor diferencia entre SARSA y Q-Learning, es que la máxima recompensa para el siguiente estado, no necesariemente es usada para actualizar el valor de Q. En vez de ello, una nueva acción y su recompensa, es seleccinada usando la misma política que fue determinada en la acción original. Q-learning primero actualiza Q y selecciona la siguiente acción basada en la actualización de la política (la óptima). Mientras que SARSA elige la acción y despues actualza Q.
#
# No creo que un método sea mejor que otro, depende del caso que se desea aprender, en el ejemplo del agente en el acantilado, Q-learning aprende el camino más rápido hacia la salida, sin preocuparse por los riesgos de caerse al acantilado. SARSA es como una persona escrupulosa que evita las zonas peligrosas que están cerca del acantilado tanto como sea posible.
#
#
# 4. Hay diferencia entre SARSA y Q-Learning conforme $\epsilon \to 0$?
#
# No, si epsilon gradualmente tiende a cero. Ambos métodos asintóticamente tiende a la política óptima

# %% [markdown]
# ## 4. Let's play
#
# Vamos a implementar el algoritmo SARSA para resolver el problema del coche en la colina. Cual es el primer problema que enfrentaremos? Preprocesar los estados.
#
# ### Preprocesamiento de estados
#
# Este es el paso que en practicamente ninguna aplicacion de RL podemos escapar. Ademas, los distintos retos dependen del tipo de problema. Algunos puntos comunes que puede surgir son
# * **El espacio de estados es demasiado grande?**. Un ejemplo tipico es querer aprender juegos de Atari a traves de observar pixeles, pues muchos pixeles pueden hacer el conjunto de estados inmanejable. En la proxima tarea veremos metodos aproximados que ayudan a resolver el problema de un conjunto de estados muy grande creando features. En metodos tabulares hay que reducir el tamano del conjunto de estados, por ejemplo, en el caso de imagenes de Atari, comprimiendo el tamano de las imagenes y solo guardando la informacion mas importante de los pixeles.
# * **El espacio de estados es continuo?**. Si vamos a usar un metodo tabular como SARSA o Q-Learning sera necesario discretizar en un numero finito de valores. Debajo hacemos una demostracion. Nuevamente, los metodos aproximados pueden evitar la necesidad de discretizar.
# * **El espacio de estados es markoviano?**. Checar esta condicion es vital y usualmente ignorada. El funcionamiento correcto de los metodos depende del supuesto de Markov, i.e., que el futuro rendimiento dependa unicamente del estado actual y de la decision tomada. De manera practica podemos preguntar: conocer el ultimo estado es suficiente para tomar una decision optima?
#
# La siguiente funcion hace una discretizacion simple de un conjunto de estados de dimension $k$, seleccionando el valor minomo, maximo y el numero de puntos en cada dimension, asumiendo una discretizacion uniforme. Se pueden hacer funciones de discretizacion mucho mas sofisticadas.

# %%
"""
For each index `k` of the array `state`, it creates an even grid of length npoints[`k`] 
going from `lower[k]` to `upper[k]`, and returns the closest value of `state[k]` on that grid. 
All the arguments must be of the same length.
"""
function discretize(state::Array, lower::Array, upper::Array, npoints::Array) 
    discretized = Array{Float32}(length(state)) # preallocating is faster (but not necessary)
    for k in 1:length(state)
        grid = linspace(lower[k], upper[k], npoints[k]) # even space
        discretized[k] = grid[indmin(abs(grid - state[k]))] # closest point
    end
    return discretized
end
;

# %% [markdown]
# **EJEMPLO DE USO**

# %%
function preprocess(state::Array)
    lower = [-1.2, -0.07]
    upper = [0.6, 0.07]
    npoints = [16, 8]
    discretize(state, lower, upper, npoints)
end

mountain_car = gym.make("MountainCar-v0")
state = mountain_car[:reset]()
println(state, " becomes ", preprocess(state))
# Out:
# [-
# [2017-06-02 22:00:41,411] Making new env: MountainCar-v0
# 0.485954,0.0] becomes Float32[-0.48,-0.01]

# %% [markdown]
# ### Funcion de entrenamiento
#
# Necesitamos una funcion que reciba una estimacion actual de la tabla $Q$ y que devuelva una estimacion mejorada. Notemos que la funcion depende del preprocesamiento que definimos anteriormente.

# %% [markdown]
# **APRENDIENDO UN EPISODIO**

# %%
"""
The following function plays a gym_episode and learns using SARSA. It receives a current estimate of Q and 
returns an improved estimate Q, the episode reward and the number of steps.
"""
function learn_episode_with_sarsa(
        gym_env, # an openai gym environment
        current_Q = Dict() # current estimation of Q
        ; # the rest are keyword argument, not positional arguments
        preprocess_state = x -> x, # state preprocessing, identity by default
        learning_rate = 0.1,
        discount_rate = 0.999,
        exploration_rate = 0.1,
        render = false, # show game visualization (slower when rendering...)
    )
    # Rename variables for formula simplicity following Sutton
    ϵ, α, γ = exploration_rate, learning_rate, discount_rate
    action_space = 0:(gym_env[:action_space][:n] - 1)
    Q = deepcopy(current_Q) # Q will store the improved Q estimate
    # Reset environment
    state = gym_env[:reset]() # regresa el ambiente al comienzo de un episodio
    state = preprocess_state(state)
    render && gym_env[:render]() # si render es true, crea la visualizacion del estado del juego
    # Get initial action
    action = policy(state, action_space, Q, ϵ) # selecionar accion con politica
    !haskey(Q, (state, action)) && (Q[(state, action)] = 0.) # add key if missing
    # Episode iteration information
    done = false # sera true cuando termine el episodio
    ep_reward = 0. # iniciar pago total en el episodio
    ep_steps = 0 # iniciar pasos totales en el episodio
    while !done 
        # Simulate transition
        new_state, reward, done, info = gym_env[:step](action) # simula una transicion
        new_state = preprocess_state(new_state)
        new_action = policy(new_state, action_space, Q, ϵ) # selecionar accion con politica
        !haskey(Q, (new_state, new_action)) && (Q[(new_state, new_action)] = 0.) # add key if missing
        # Compute δ
        δ = reward + γ*Q[(new_state, new_action)]  - Q[(state, action)] 
        # Update Q 
        Q[(state, action)] = Q[(state, action)] + α*δ
        # Change new states to old states for next step
        state = new_state
        action = new_action
        # Save step information and render if needed
        render && gym_env[:render]()
        ep_reward += reward # agrega el pago de la transicion al pago del ep.
        ep_steps += 1 # agrega un paso al total de pasos en el episodio
    end
    render && gym_env[:render](close = true)
    return Q, ep_reward, ep_steps
end

# %% [markdown]
# **EJEMPLO DE USO**

# %%
Q = Dict()
Q, reward, steps = learn_episode_with_sarsa(mountain_car, Q, preprocess_state = preprocess, render = true)
# Out:
# (Dict{Any,Any}(Pair{Any,Any}((Float32[-0.6,0.01],0),-1.35244),Pair{Any,Any}((Float32[-0.6,-0.01],2),-1.32793),Pair{Any,Any}((Float32[-0.48,0.01],1),-1.94155),Pair{Any,Any}((Float32[-0.6,-0.01],0),-1.30374),Pair{Any,Any}((Float32[-0.48,-0.01],1),-1.90202),Pair{Any,Any}((Float32[-0.6,-0.01],1),-1.45297),Pair{Any,Any}((Float32[-0.48,0.01],0),-1.83468),Pair{Any,Any}((Float32[-0.48,-0.01],0),-1.89826),Pair{Any,Any}((Float32[-0.6,0.01],1),-1.22577),Pair{Any,Any}((Float32[-0.48,0.01],2),-1.85748)…),-200.0,200)

# %% [markdown]
# **APRENDIENDO DE MUCHOS EPISODIOS Y REDUCIENDO TASA DE EXPLORACION**

# %%
"""
This function will train a gym environment for many episodes using sarsa and a preprocess
function given by the user, defaults to identity.
"""
function learn_episodes_with_sarsa(
        n_episodes, # number of episodes
        gym_env, # an openai gym environment
        current_Q = Dict() # current estimation of Q
        ; # the rest are keyword argument, not positional arguments
        preprocess_state = x -> x, # state preprocessing, identity by default
        learning_rate = 0.1,
        discount_rate = 0.999,
        exploration_rate = 0.1,
        exploration_decay =  1 - log(2) / n_episodes, # se reducira a la mitad al final del episodio
        render = false, # show game visualization (slower when rendering...)
        verbose = true
    )
    Q = deepcopy(current_Q)
    # Iterate episodes
    reward_history = []
    steps_history = []
    for i in 1:n_episodes
        # learn from episode
        Q, reward, steps = learn_episode_with_sarsa(gym_env, Q, 
                                                    learning_rate = learning_rate, 
                                                    discount_rate = discount_rate, 
                                                    exploration_rate = exploration_rate, 
                                                    render = render,
                                                    preprocess_state = preprocess_state)
        verbose && println("Episodio ", i, " con pago ", reward)
        # reduce exploration_rate
        exploration_rate *= exploration_decay
        # save episode information
        push!(reward_history, reward)
        push!(steps_history, steps)
    end
    return Q, reward_history, steps_history
end

# %%
Q, reward_history, steps_history = learn_episodes_with_sarsa(
    2000, mountain_car, Dict(), 
    preprocess_state = preprocess,
    learning_rate = 0.05,
    exploration_rate = 0.25,
    exploration_decay = 1 - log(25) / 2000, # will reduce to 0.01 at the end of training
    render = true # be patient, enjoy watching, switch to false for speed
)
# Out:
# Episodio 1 con pago -200.0
# Episodio 2 con pago -200.0
# Episodio 3 con pago -200.0
# Episodio 4 con pago -200.0
# Episodio 5 con pago -200.0
# Episodio 6 con pago -200.0
# Episodio 7 con pago -200.0
# Episodio 8 con pago -200.0
# Episodio 9 con pago -200.0
# Episodio 10 con pago -200.0
# Episodio 11 con pago -200.0
# Episodio 12 con pago -200.0
# Episodio 13 con pago -200.0
# Episodio 14 con pago -200.0
# Episodio 15 con pago -200.0
# Episodio 16 con pago -200.0
# Episodio 17 con pago -200.0
# Episodio 18 con pago -200.0
# Episodio 19 con pago -200.0
# Episodio 20 con pago -200.0
# Episodio 21 con pago -200.0
# Episodio 22 con pago -200.0
# Episodio 23 con pago -200.0
# Episodio 24 con pago -200.0
# Episodio 25 con pago -200.0
# Episodio 26 con pago -200.0
# Episodio 27 con pago -200.0
# Episodio 28 con pago -200.0
# Episodio 29 con pago -200.0
# Episodio 30 con pago -200.0
# Episodio 31 con pago -200.0
# Episodio 32 con pago -200.0
# Episodio 33 con pago -200.0
# Episodio 34 con pago -200.0
# Episodio 35 con pago -200.0
# Episodio 36 con pago -200.0
# Episodio 37 con pago -200.0
# Episodio 38 con pago -200.0
# Episodio 39 con pago -200.0
# Episodio 40 con pago -200.0
# Episodio 41 con pago -200.0
# Episodio 42 con pago -200.0
# Episodio 43 con pago -200.0
# Episodio 44 con pago -200.0
# Episodio 45 con pago -200.0
# Episodio 46 con pago -200.0
# Episodio 47 con pago -200.0
# Episodio 48 con pago -200.0
# Episodio 49 con pago -200.0
# Episodio 50 con pago -200.0
# Episodio 51 con pago -200.0
# Episodio 52 con pago -200.0
# Episodio 53 con pago -200.0
# Episodio 54 con pago -200.0
# Episodio 55 con pago -200.0
# Episodio 56 con pago -200.0
# Episodio 57 con pago -200.0
# Episodio 58 con pago -200.0
# Episodio 59 con pago -200.0
# Episodio 60 con pago -200.0
# Episodio 61 con pago -200.0
# Episodio 62 con pago -200.0
# Episodio 63 con pago -200.0
# Episodio 64 con pago -200.0
# Episodio 65 con pago -200.0
# Episodio 66 con pago -200.0
# Episodio 67 con pago -200.0
# Episodio 68 con pago -200.0
# Episodio 69 con pago -200.0
# Episodio 70 con pago -200.0
# Episodio 71 con pago -200.0
# Episodio 72 con pago -200.0
# Episodio 73 con pago -200.0
# Episodio 74 con pago -200.0
# Episodio 75 con pago -200.0
# Episodio 76 con pago -200.0
# Episodio 77 con pago -200.0
# Episodio 78 con pago -200.0
# Episodio 79 con pago -200.0
# Episodio 80 con pago -200.0
# Episodio 81 con pago -200.0
# Episodio 82 con pago -200.0
# Episodio 83 con pago -200.0
# Episodio 84 con pago -200.0
# Episodio 85 con pago -200.0
# Episodio 86 con pago -200.0
# Episodio 87 con pago -200.0
# Episodio 88 con pago -200.0
# Episodio 89 con pago -200.0
# Episodio 90 con pago -200.0
# Episodio 91 con pago -200.0
# Episodio 92 con pago -200.0
# Episodio 93 con pago -200.0
# Episodio 94 con pago -200.0
# Episodio 95 con pago -200.0
# Episodio 96 con pago -200.0
# Episodio 97 con pago -200.0
# Episodio 98 con pago -200.0
# Episodio 99 con pago -200.0
# Episodio 100 con pago -200.0
# Episodio 101 con pago -200.0
# Episodio 102 con pago -200.0
# Episodio 103 con pago -200.0
# Episodio 104 con pago -200.0
# Episodio 105 con pago -200.0
# Episodio 106 con pago -200.0
# Episodio 107 con pago -200.0
# Episodio 108 con pago -200.0
# Episodio 109 con pago -200.0
# Episodio 110 con pago -200.0
# Episodio 111 con pago -200.0
# Episodio 112 con pago -200.0
# Episodio 113 con pago -200.0
# Episodio 114 con pago -200.0
# Episodio 115 con pago -200.0
# Episodio 116 con pago -200.0
# Episodio 117 con pago -200.0
# Episodio 118 con pago -200.0
# Episodio 119 con pago -200.0
# Episodio 120 con pago -200.0
# Episodio 121 con pago -200.0
# Episodio 122 con pago -200.0
# Episodio 123 con pago -200.0
# Episodio 124 con pago -200.0
# Episodio 125 con pago -200.0
# Episodio 126 con pago -200.0
# Episodio 127 con pago -200.0
# Episodio 128 con pago -200.0
# Episodio 129 con pago -200.0
# Episodio 130 con pago -200.0
# Episodio 131 con pago -200.0
# Episodio 132 con pago -200.0
# Episodio 133 con pago -200.0
# Episodio 134 con pago -200.0
# Episodio 135 con pago -200.0
# Episodio 136 con pago -200.0
# Episodio 137 con pago -200.0
# Episodio 138 con pago -200.0
# Episodio 139 con pago -200.0
# Episodio 140 con pago -200.0
# Episodio 141 con pago -200.0
# Episodio 142 con pago -200.0
# Episodio 143 con pago -200.0
# Episodio 144 con pago -200.0
# Episodio 145 con pago -200.0
# Episodio 146 con pago -200.0
# Episodio 147 con pago -200.0
# Episodio 148 con pago -200.0
# Episodio 149 con pago -200.0
# Episodio 150 con pago -200.0
# Episodio 151 con pago -200.0
# Episodio 152 con pago -200.0
# Episodio 153 con pago -200.0
# Episodio 154 con pago -200.0
# Episodio 155 con pago -200.0
# Episodio 156 con pago -200.0
# Episodio 157 con pago -200.0
# Episodio 158 con pago -200.0
# Episodio 159 con pago -200.0
# Episodio 160 con pago -200.0
# Episodio 161 con pago -200.0
# Episodio 162 con pago -200.0
# Episodio 163 con pago -200.0
# Episodio 164 con pago -200.0
# Episodio 165 con pago -200.0
# Episodio 166 con pago -200.0
# Episodio 167 con pago -200.0
# Episodio 168 con pago -200.0
# Episodio 169 con pago -200.0
# Episodio 170 con pago -200.0
# Episodio 171 con pago -200.0
# Episodio 172 con pago -200.0
# Episodio 173 con pago -200.0
# Episodio 174 con pago -200.0
# Episodio 175 con pago -200.0
# Episodio 176 con pago -200.0
# Episodio 177 con pago -200.0
# Episodio 178 con pago -200.0
# Episodio 179 con pago -200.0
# Episodio 180 con pago -200.0
# Episodio 181 con pago -200.0
# Episodio 182 con pago -200.0
# Episodio 183 con pago -200.0
# Episodio 184 con pago -200.0
# Episodio 185 con pago -200.0
# Episodio 186 con pago -200.0
# Episodio 187 con pago -200.0
# Episodio 188 con pago -200.0
# Episodio 189 con pago -200.0
# Episodio 190 con pago -200.0
# Episodio 191 con pago -200.0
# Episodio 192 con pago -200.0
# Episodio 193 con pago -200.0
# Episodio 194 con pago -200.0
# Episodio 195 con pago -200.0
# Episodio 196 con pago -200.0
# Episodio 197 con pago -200.0
# Episodio 198 con pago -200.0
# Episodio 199 con pago -200.0
# Episodio 200 con pago -200.0
# Episodio 201 con pago -200.0
# Episodio 202 con pago -200.0
# Episodio 203 con pago -200.0
# Episodio 204 con pago -200.0
# Episodio 205 con pago -200.0
# Episodio 206 con pago -200.0
# Episodio 207 con pago -200.0
# Episodio 208 con pago -200.0
# Episodio 209 con pago -200.0
# Episodio 210 con pago -200.0
# Episodio 211 con pago -200.0
# Episodio 212 con pago -200.0
# Episodio 213 con pago -200.0
# Episodio 214 con pago -200.0
# Episodio 215 con pago -200.0
# Episodio 216 con pago -200.0
# Episodio 217 con pago -200.0
# Episodio 218 con pago -200.0
# Episodio 219 con pago -200.0
# Episodio 220 con pago -200.0
# Episodio 221 con pago -200.0
# Episodio 222 con pago -200.0
# Episodio 223 con pago -200.0
# Episodio 224 con pago -200.0
# Episodio 225 con pago -200.0
# Episodio 226 con pago -200.0
# Episodio 227 con pago -200.0
# Episodio 228 con pago -200.0
# Episodio 229 con pago -200.0
# Episodio 230 con pago -200.0
# Episodio 231 con pago -200.0
# Episodio 232 con pago -200.0
# Episodio 233 con pago -200.0
# Episodio 234 con pago -200.0
# Episodio 235 con pago -200.0
# Episodio 236 con pago -200.0
# Episodio 237 con pago -200.0
# Episodio 238 con pago -200.0
# Episodio 239 con pago -200.0
# Episodio 240 con pago -200.0
# Episodio 241 con pago -200.0
# Episodio 242 con pago -200.0
# Episodio 243 con pago -200.0
# Episodio 244 con pago -200.0
# Episodio 245 con pago -200.0
# Episodio 246 con pago -200.0
# Episodio 247 con pago -200.0
# Episodio 248 con pago -200.0
# Episodio 249 con pago -200.0
# Episodio 250 con pago -200.0
# Episodio 251 con pago -200.0
# Episodio 252 con pago -200.0
# Episodio 253 con pago -200.0
# Episodio 254 con pago -200.0
# Episodio 255 con pago -200.0
# Episodio 256 con pago -200.0
# Episodio 257 con pago -200.0
# Episodio 258 con pago -200.0
# Episodio 259 con pago -200.0
# Episodio 260 con pago -200.0
# Episodio 261 con pago -200.0
# Episodio 262 con pago -200.0
# Episodio 263 con pago -200.0
# Episodio 264 con pago -200.0
# Episodio 265 con pago -200.0
# Episodio 266 con pago -200.0
# Episodio 267 con pago -200.0
# Episodio 268 con pago -200.0
# Episodio 269 con pago -200.0
# Episodio 270 con pago -200.0
# Episodio 271 con pago -200.0
# Episodio 272 con pago -200.0
# Episodio 273 con pago -200.0
# Episodio 274 con pago -200.0
# Episodio 275 con pago -200.0
# Episodio 276 con pago -200.0
# Episodio 277 con pago -200.0
# Episodio 278 con pago -200.0
# Episodio 279 con pago -200.0
# Episodio 280 con pago -200.0
# Episodio 281 con pago -200.0
# Episodio 282 con pago -200.0
# Episodio 283 con pago -200.0
# Episodio 284 con pago -200.0
# Episodio 285 con pago -200.0
# Episodio 286 con pago -200.0
# Episodio 287 con pago -200.0
# Episodio 288 con pago -200.0
# Episodio 289 con pago -200.0
# Episodio 290 con pago -200.0
# Episodio 291 con pago -200.0
# Episodio 292 con pago -200.0
# Episodio 293 con pago -200.0
# Episodio 294 con pago -200.0
# Episodio 295 con pago -200.0
# Episodio 296 con pago -200.0
# Episodio 297 con pago -200.0
# Episodio 298 con pago -200.0
# Episodio 299 con pago -200.0
# Episodio 300 con pago -200.0
# Episodio 301 con pago -200.0
# Episodio 302 con pago -200.0
# Episodio 303 con pago -200.0
# Episodio 304 con pago -200.0
# Episodio 305 con pago -200.0
# Episodio 306 con pago -200.0
# Episodio 307 con pago -200.0
# Episodio 308 con pago -200.0
# Episodio 309 con pago -200.0
# Episodio 310 con pago -200.0
# Episodio 311 con pago -200.0
# Episodio 312 con pago -200.0
# Episodio 313 con pago -200.0
# Episodio 314 con pago -200.0
# Episodio 315 con pago -200.0
# Episodio 316 con pago -196.0
# Episodio 317 con pago -200.0
# Episodio 318 con pago -200.0
# Episodio 319 con pago -200.0
# Episodio 320 con pago -200.0
# Episodio 321 con pago -200.0
# Episodio 322 con pago -200.0
# Episodio 323 con pago -200.0
# Episodio 324 con pago -200.0
# Episodio 325 con pago -200.0
# Episodio 326 con pago -200.0
# Episodio 327 con pago -200.0
# Episodio 328 con pago -200.0
# Episodio 329 con pago -200.0
# Episodio 330 con pago -200.0
# Episodio 331 con pago -200.0
# Episodio 332 con pago -200.0
# Episodio 333 con pago -200.0
# Episodio 334 con pago -200.0
# Episodio 335 con pago -200.0
# Episodio 336 con pago -200.0
# Episodio 337 con pago -200.0
# Episodio 338 con pago -200.0
# Episodio 339 con pago -200.0
# Episodio 340 con pago -200.0
# Episodio 341 con pago -200.0
# Episodio 342 con pago -200.0
# Episodio 343 con pago -200.0
# Episodio 344 con pago -200.0
# Episodio 345 con pago -200.0
# Episodio 346 con pago -200.0
# Episodio 347 con pago -200.0
# Episodio 348 con pago -200.0
# Episodio 349 con pago -200.0
# Episodio 350 con pago -200.0
# Episodio 351 con pago -200.0
# Episodio 352 con pago -200.0
# Episodio 353 con pago -200.0
# Episodio 354 con pago -200.0
# Episodio 355 con pago -200.0
# Episodio 356 con pago -200.0
# Episodio 357 con pago -200.0
# Episodio 358 con pago -200.0
# Episodio 359 con pago -200.0
# Episodio 360 con pago -200.0
# Episodio 361 con pago -200.0
# Episodio 362 con pago -200.0
# Episodio 363 con pago -200.0
# Episodio 364 con pago -200.0
# Episodio 365 con pago -200.0
# Episodio 366 con pago -200.0
# Episodio 367 con pago -200.0
# Episodio 368 con pago -200.0
# Episodio 369 con pago -200.0
# Episodio 370 con pago -200.0
# Episodio 371 con pago -200.0
# Episodio 372 con pago -200.0
# Episodio 373 con pago -200.0
# Episodio 374 con pago -200.0
# Episodio 375 con pago -200.0
# Episodio 376 con pago -200.0
# Episodio 377 con pago -200.0
# Episodio 378 con pago -200.0
# Episodio 379 con pago -200.0
# Episodio 380 con pago -200.0
# Episodio 381 con pago -200.0
# Episodio 382 con pago -200.0
# Episodio 383 con pago -200.0
# Episodio 384 con pago -200.0
# Episodio 385 con pago -200.0
# Episodio 386 con pago -200.0
# Episodio 387 con pago -200.0
# Episodio 388 con pago -200.0
# Episodio 389 con pago -200.0
# Episodio 390 con pago -200.0
# Episodio 391 con pago -200.0
# Episodio 392 con pago -200.0
# Episodio 393 con pago -200.0
# Episodio 394 con pago -200.0
# Episodio 395 con pago -200.0
# Episodio 396 con pago -200.0
# Episodio 397 con pago -200.0
# Episodio 398 con pago -200.0
# Episodio 399 con pago -200.0
# Episodio 400 con pago -200.0
# Episodio 401 con pago -200.0
# Episodio 402 con pago -200.0
# Episodio 403 con pago -200.0
# Episodio 404 con pago -200.0
# Episodio 405 con pago -200.0
# Episodio 406 con pago -200.0
# Episodio 407 con pago -200.0
# Episodio 408 con pago -200.0
# Episodio 409 con pago -200.0
# Episodio 410 con pago -200.0
# Episodio 411 con pago -200.0
# Episodio 412 con pago -200.0
# Episodio 413 con pago -200.0
# Episodio 414 con pago -200.0
# Episodio 415 con pago -200.0
# Episodio 416 con pago -200.0
# Episodio 417 con pago -200.0
# Episodio 418 con pago -200.0
# Episodio 419 con pago -200.0
# Episodio 420 con pago -188.0
# Episodio 421 con pago -200.0
# Episodio 422 con pago -200.0
# Episodio 423 con pago -200.0
# Episodio 424 con pago -200.0
# Episodio 425 con pago -200.0
# Episodio 426 con pago -200.0
# Episodio 427 con pago -200.0
# Episodio 428 con pago -200.0
# Episodio 429 con pago -200.0
# Episodio 430 con pago -200.0
# Episodio 431 con pago -200.0
# Episodio 432 con pago -200.0
# Episodio 433 con pago -200.0
# Episodio 434 con pago -200.0
# Episodio 435 con pago -200.0
# Episodio 436 con pago -200.0
# Episodio 437 con pago -200.0
# Episodio 438 con pago -200.0
# Episodio 439 con pago -200.0
# Episodio 440 con pago -200.0
# Episodio 441 con pago -200.0
# Episodio 442 con pago -200.0
# Episodio 443 con pago -200.0
# Episodio 444 con pago -200.0
# Episodio 445 con pago -200.0
# Episodio 446 con pago -200.0
# Episodio 447 con pago -200.0
# Episodio 448 con pago -200.0
# Episodio 449 con pago -200.0
# Episodio 450 con pago -200.0
# Episodio 451 con pago -164.0
# Episodio 452 con pago -200.0
# Episodio 453 con pago -200.0
# Episodio 454 con pago -200.0
# Episodio 455 con pago -200.0
# Episodio 456 con pago -200.0
# Episodio 457 con pago -200.0
# Episodio 458 con pago -200.0
# Episodio 459 con pago -200.0
# Episodio 460 con pago -200.0
# Episodio 461 con pago -200.0
# Episodio 462 con pago -200.0
# Episodio 463 con pago -200.0
# Episodio 464 con pago -200.0
# Episodio 465 con pago -200.0
# Episodio 466 con pago -200.0
# Episodio 467 con pago -200.0
# Episodio 468 con pago -200.0
# Episodio 469 con pago -200.0
# Episodio 470 con pago -200.0
# Episodio 471 con pago -200.0
# Episodio 472 con pago -200.0
# Episodio 473 con pago -200.0
# Episodio 474 con pago -200.0
# Episodio 475 con pago -200.0
# Episodio 476 con pago -200.0
# Episodio 477 con pago -200.0
# Episodio 478 con pago -200.0
# Episodio 479 con pago -200.0
# Episodio 480 con pago -200.0
# Episodio 481 con pago -200.0
# Episodio 482 con pago -200.0
# Episodio 483 con pago -200.0
# Episodio 484 con pago -200.0
# Episodio 485 con pago -200.0
# Episodio 486 con pago -200.0
# Episodio 487 con pago -200.0
# Episodio 488 con pago -200.0
# Episodio 489 con pago -200.0
# Episodio 490 con pago -200.0
# Episodio 491 con pago -200.0
# Episodio 492 con pago -200.0
# Episodio 493 con pago -200.0
# Episodio 494 con pago -200.0
# Episodio 495 con pago -200.0
# Episodio 496 con pago -200.0
# Episodio 497 con pago -200.0
# Episodio 498 con pago -200.0
# Episodio 499 con pago -200.0
# Episodio 500 con pago -200.0
# Episodio 501 con pago -200.0
# Episodio 502 con pago -200.0
# Episodio 503 con pago -200.0
# Episodio 504 con pago -200.0
# Episodio 505 con pago -200.0
# Episodio 506 con pago -200.0
# Episodio 507 con pago -200.0
# Episodio 508 con pago -200.0
# Episodio 509 con pago -200.0
# Episodio 510 con pago -200.0
# Episodio 511 con pago -200.0
# Episodio 512 con pago -200.0
# Episodio 513 con pago -200.0
# Episodio 514 con pago -200.0
# Episodio 515 con pago -200.0
# Episodio 516 con pago -200.0
# Episodio 517 con pago -200.0
# Episodio 518 con pago -200.0
# Episodio 519 con pago -200.0
# Episodio 520 con pago -200.0
# Episodio 521 con pago -200.0
# Episodio 522 con pago -200.0
# Episodio 523 con pago -200.0
# Episodio 524 con pago -200.0
# Episodio 525 con pago -200.0
# Episodio 526 con pago -200.0
# Episodio 527 con pago -200.0
# Episodio 528 con pago -190.0
# Episodio 529 con pago -200.0
# Episodio 530 con pago -200.0
# Episodio 531 con pago -200.0
# Episodio 532 con pago -200.0
# Episodio 533 con pago -200.0
# Episodio 534 con pago -200.0
# Episodio 535 con pago -200.0
# Episodio 536 con pago -200.0
# Episodio 537 con pago -200.0
# Episodio 538 con pago -200.0
# Episodio 539 con pago -200.0
# Episodio 540 con pago -200.0
# Episodio 541 con pago -200.0
# Episodio 542 con pago -200.0
# Episodio 543 con pago -200.0
# Episodio 544 con pago -200.0
# Episodio 545 con pago -200.0
# Episodio 546 con pago -200.0
# Episodio 547 con pago -200.0
# Episodio 548 con pago -200.0
# Episodio 549 con pago -200.0
# Episodio 550 con pago -200.0
# Episodio 551 con pago -200.0
# Episodio 552 con pago -200.0
# Episodio 553 con pago -200.0
# Episodio 554 con pago -200.0
# Episodio 555 con pago -200.0
# Episodio 556 con pago -200.0
# Episodio 557 con pago -200.0
# Episodio 558 con pago -200.0
# Episodio 559 con pago -172.0
# Episodio 560 con pago -200.0
# Episodio 561 con pago -200.0
# Episodio 562 con pago -200.0
# Episodio 563 con pago -200.0
# Episodio 564 con pago -167.0
# Episodio 565 con pago -166.0
# Episodio 566 con pago -171.0
# Episodio 567 con pago -200.0
# Episodio 568 con pago -200.0
# Episodio 569 con pago -200.0
# Episodio 570 con pago -200.0
# Episodio 571 con pago -200.0
# Episodio 572 con pago -200.0
# Episodio 573 con pago -200.0
# Episodio 574 con pago -183.0
# Episodio 575 con pago -200.0
# Episodio 576 con pago -200.0
# Episodio 577 con pago -200.0
# Episodio 578 con pago -200.0
# Episodio 579 con pago -200.0
# Episodio 580 con pago -200.0
# Episodio 581 con pago -200.0
# Episodio 582 con pago -200.0
# Episodio 583 con pago -200.0
# Episodio 584 con pago -200.0
# Episodio 585 con pago -200.0
# Episodio 586 con pago -200.0
# Episodio 587 con pago -200.0
# Episodio 588 con pago -200.0
# Episodio 589 con pago -200.0
# Episodio 590 con pago -200.0
# Episodio 591 con pago -200.0
# Episodio 592 con pago -200.0
# Episodio 593 con pago -200.0
# Episodio 594 con pago -200.0
# Episodio 595 con pago -200.0
# Episodio 596 con pago -200.0
# Episodio 597 con pago -200.0
# Episodio 598 con pago -200.0
# Episodio 599 con pago -200.0
# Episodio 600 con pago -200.0
# Episodio 601 con pago -200.0
# Episodio 602 con pago -200.0
# Episodio 603 con pago -200.0
# Episodio 604 con pago -200.0
# Episodio 605 con pago -200.0
# Episodio 606 con pago -200.0
# Episodio 607 con pago -200.0
# Episodio 608 con pago -200.0
# Episodio 609 con pago -200.0
# Episodio 610 con pago -200.0
# Episodio 611 con pago -200.0
# Episodio 612 con pago -200.0
# Episodio 613 con pago -200.0
# Episodio 614 con pago -200.0
# Episodio 615 con pago -200.0
# Episodio 616 con pago -156.0
# Episodio 617 con pago -200.0
# Episodio 618 con pago -177.0
# Episodio 619 con pago -166.0
# Episodio 620 con pago -200.0
# Episodio 621 con pago -200.0
# Episodio 622 con pago -200.0
# Episodio 623 con pago -200.0
# Episodio 624 con pago -200.0
# Episodio 625 con pago -200.0
# Episodio 626 con pago -200.0
# Episodio 627 con pago -159.0
# Episodio 628 con pago -200.0
# Episodio 629 con pago -153.0
# Episodio 630 con pago -168.0
# Episodio 631 con pago -182.0
# Episodio 632 con pago -200.0
# Episodio 633 con pago -200.0
# Episodio 634 con pago -174.0
# Episodio 635 con pago -172.0
# Episodio 636 con pago -200.0
# Episodio 637 con pago -200.0
# Episodio 638 con pago -200.0
# Episodio 639 con pago -152.0
# Episodio 640 con pago -200.0
# Episodio 641 con pago -200.0
# Episodio 642 con pago -164.0
# Episodio 643 con pago -200.0
# Episodio 644 con pago -200.0
# Episodio 645 con pago -200.0
# Episodio 646 con pago -168.0
# Episodio 647 con pago -200.0
# Episodio 648 con pago -200.0
# Episodio 649 con pago -200.0
# Episodio 650 con pago -200.0
# Episodio 651 con pago -200.0
# Episodio 652 con pago -200.0
# Episodio 653 con pago -200.0
# Episodio 654 con pago -200.0
# Episodio 655 con pago -200.0
# Episodio 656 con pago -200.0
# Episodio 657 con pago -200.0
# Episodio 658 con pago -200.0
# Episodio 659 con pago -200.0
# Episodio 660 con pago -200.0
# Episodio 661 con pago -200.0
# Episodio 662 con pago -159.0
# Episodio 663 con pago -170.0
# Episodio 664 con pago -161.0
# Episodio 665 con pago -200.0
# Episodio 666 con pago -200.0
# Episodio 667 con pago -200.0
# Episodio 668 con pago -200.0
# Episodio 669 con pago -200.0
# Episodio 670 con pago -200.0
# Episodio 671 con pago -200.0
# Episodio 672 con pago -200.0
# Episodio 673 con pago -200.0
# Episodio 674 con pago -200.0
# Episodio 675 con pago -200.0
# Episodio 676 con pago -200.0
# Episodio 677 con pago -197.0
# Episodio 678 con pago -200.0
# Episodio 679 con pago -200.0
# Episodio 680 con pago -165.0
# Episodio 681 con pago -200.0
# Episodio 682 con pago -200.0
# Episodio 683 con pago -175.0
# Episodio 684 con pago -200.0
# Episodio 685 con pago -200.0
# Episodio 686 con pago -200.0
# Episodio 687 con pago -200.0
# Episodio 688 con pago -200.0
# Episodio 689 con pago -200.0
# Episodio 690 con pago -200.0
# Episodio 691 con pago -200.0
# Episodio 692 con pago -200.0
# Episodio 693 con pago -200.0
# Episodio 694 con pago -200.0
# Episodio 695 con pago -200.0
# Episodio 696 con pago -200.0
# Episodio 697 con pago -200.0
# Episodio 698 con pago -200.0
# Episodio 699 con pago -155.0
# Episodio 700 con pago -200.0
# Episodio 701 con pago -200.0
# Episodio 702 con pago -200.0
# Episodio 703 con pago -200.0
# Episodio 704 con pago -200.0
# Episodio 705 con pago -200.0
# Episodio 706 con pago -200.0
# Episodio 707 con pago -200.0
# Episodio 708 con pago -171.0
# Episodio 709 con pago -159.0
# Episodio 710 con pago -200.0
# Episodio 711 con pago -159.0
# Episodio 712 con pago -173.0
# Episodio 713 con pago -200.0
# Episodio 714 con pago -191.0
# Episodio 715 con pago -163.0
# Episodio 716 con pago -200.0
# Episodio 717 con pago -200.0
# Episodio 718 con pago -157.0
# Episodio 719 con pago -165.0
# Episodio 720 con pago -163.0
# Episodio 721 con pago -156.0
# Episodio 722 con pago -162.0
# Episodio 723 con pago -160.0
# Episodio 724 con pago -200.0
# Episodio 725 con pago -200.0
# Episodio 726 con pago -200.0
# Episodio 727 con pago -200.0
# Episodio 728 con pago -200.0
# Episodio 729 con pago -200.0
# Episodio 730 con pago -200.0
# Episodio 731 con pago -200.0
# Episodio 732 con pago -200.0
# Episodio 733 con pago -200.0
# Episodio 734 con pago -200.0
# Episodio 735 con pago -200.0
# Episodio 736 con pago -200.0
# Episodio 737 con pago -200.0
# Episodio 738 con pago -200.0
# Episodio 739 con pago -200.0
# Episodio 740 con pago -200.0
# Episodio 741 con pago -200.0
# Episodio 742 con pago -200.0
# Episodio 743 con pago -200.0
# Episodio 744 con pago -200.0
# Episodio 745 con pago -200.0
# Episodio 746 con pago -200.0
# Episodio 747 con pago -200.0
# Episodio 748 con pago -190.0
# Episodio 749 con pago -200.0
# Episodio 750 con pago -200.0
# Episodio 751 con pago -200.0
# Episodio 752 con pago -200.0
# Episodio 753 con pago -200.0
# Episodio 754 con pago -200.0
# Episodio 755 con pago -200.0
# Episodio 756 con pago -200.0
# Episodio 757 con pago -200.0
# Episodio 758 con pago -200.0
# Episodio 759 con pago -200.0
# Episodio 760 con pago -200.0
# Episodio 761 con pago -200.0
# Episodio 762 con pago -200.0
# Episodio 763 con pago -200.0
# Episodio 764 con pago -158.0
# Episodio 765 con pago -200.0
# Episodio 766 con pago -200.0
# Episodio 767 con pago -200.0
# Episodio 768 con pago -200.0
# Episodio 769 con pago -200.0
# Episodio 770 con pago -200.0
# Episodio 771 con pago -200.0
# Episodio 772 con pago -200.0
# Episodio 773 con pago -200.0
# Episodio 774 con pago -200.0
# Episodio 775 con pago -200.0
# Episodio 776 con pago -200.0
# Episodio 777 con pago -200.0
# Episodio 778 con pago -200.0
# Episodio 779 con pago -200.0
# Episodio 780 con pago -160.0
# Episodio 781 con pago -200.0
# Episodio 782 con pago -172.0
# Episodio 783 con pago -200.0
# Episodio 784 con pago -200.0
# Episodio 785 con pago -200.0
# Episodio 786 con pago -200.0
# Episodio 787 con pago -200.0
# Episodio 788 con pago -200.0
# Episodio 789 con pago -200.0
# Episodio 790 con pago -200.0
# Episodio 791 con pago -200.0
# Episodio 792 con pago -200.0
# Episodio 793 con pago -200.0
# Episodio 794 con pago -200.0
# Episodio 795 con pago -200.0
# Episodio 796 con pago -200.0
# Episodio 797 con pago -191.0
# Episodio 798 con pago -200.0
# Episodio 799 con pago -200.0
# Episodio 800 con pago -200.0
# Episodio 801 con pago -200.0
# Episodio 802 con pago -200.0
# Episodio 803 con pago -200.0
# Episodio 804 con pago -200.0
# Episodio 805 con pago -200.0
# Episodio 806 con pago -200.0
# Episodio 807 con pago -199.0
# Episodio 808 con pago -200.0
# Episodio 809 con pago -200.0
# Episodio 810 con pago -200.0
# Episodio 811 con pago -159.0
# Episodio 812 con pago -200.0
# Episodio 813 con pago -183.0
# Episodio 814 con pago -200.0
# Episodio 815 con pago -200.0
# Episodio 816 con pago -200.0
# Episodio 817 con pago -200.0
# Episodio 818 con pago -200.0
# Episodio 819 con pago -200.0
# Episodio 820 con pago -200.0
# Episodio 821 con pago -200.0
# Episodio 822 con pago -200.0
# Episodio 823 con pago -200.0
# Episodio 824 con pago -200.0
# Episodio 825 con pago -200.0
# Episodio 826 con pago -200.0
# Episodio 827 con pago -200.0
# Episodio 828 con pago -200.0
# Episodio 829 con pago -200.0
# Episodio 830 con pago -200.0
# Episodio 831 con pago -200.0
# Episodio 832 con pago -200.0
# Episodio 833 con pago -200.0
# Episodio 834 con pago -200.0
# Episodio 835 con pago -200.0
# Episodio 836 con pago -200.0
# Episodio 837 con pago -200.0
# Episodio 838 con pago -200.0
# Episodio 839 con pago -200.0
# Episodio 840 con pago -200.0
# Episodio 841 con pago -200.0
# Episodio 842 con pago -200.0
# Episodio 843 con pago -200.0
# Episodio 844 con pago -200.0
# Episodio 845 con pago -200.0
# Episodio 846 con pago -200.0
# Episodio 847 con pago -200.0
# Episodio 848 con pago -200.0
# Episodio 849 con pago -200.0
# Episodio 850 con pago -200.0
# Episodio 851 con pago -200.0
# Episodio 852 con pago -200.0
# Episodio 853 con pago -200.0
# Episodio 854 con pago -200.0
# Episodio 855 con pago -162.0
# Episodio 856 con pago -200.0
# Episodio 857 con pago -200.0
# Episodio 858 con pago -200.0
# Episodio 859 con pago -200.0
# Episodio 860 con pago -200.0
# Episodio 861 con pago -200.0
# Episodio 862 con pago -200.0
# Episodio 863 con pago -200.0
# Episodio 864 con pago -200.0
# Episodio 865 con pago -200.0
# Episodio 866 con pago -200.0
# Episodio 867 con pago -200.0
# Episodio 868 con pago -200.0
# Episodio 869 con pago -200.0
# Episodio 870 con pago -200.0
# Episodio 871 con pago -200.0
# Episodio 872 con pago -200.0
# Episodio 873 con pago -200.0
# Episodio 874 con pago -200.0
# Episodio 875 con pago -200.0
# Episodio 876 con pago -200.0
# Episodio 877 con pago -200.0
# Episodio 878 con pago -200.0
# Episodio 879 con pago -200.0
# Episodio 880 con pago -200.0
# Episodio 881 con pago -200.0
# Episodio 882 con pago -200.0
# Episodio 883 con pago -200.0
# Episodio 884 con pago -200.0
# Episodio 885 con pago -200.0
# Episodio 886 con pago -200.0
# Episodio 887 con pago -200.0
# Episodio 888 con pago -200.0
# Episodio 889 con pago -200.0
# Episodio 890 con pago -200.0
# Episodio 891 con pago -200.0
# Episodio 892 con pago -200.0
# Episodio 893 con pago -200.0
# Episodio 894 con pago -200.0
# Episodio 895 con pago -161.0
# Episodio 896 con pago -200.0
# Episodio 897 con pago -175.0
# Episodio 898 con pago -200.0
# Episodio 899 con pago -173.0
# Episodio 900 con pago -162.0
# Episodio 901 con pago -200.0
# Episodio 902 con pago -200.0
# Episodio 903 con pago -200.0
# Episodio 904 con pago -166.0
# Episodio 905 con pago -200.0
# Episodio 906 con pago -200.0
# Episodio 907 con pago -169.0
# Episodio 908 con pago -200.0
# Episodio 909 con pago -171.0
# Episodio 910 con pago -162.0
# Episodio 911 con pago -198.0
# Episodio 912 con pago -200.0
# Episodio 913 con pago -200.0
# Episodio 914 con pago -185.0
# Episodio 915 con pago -200.0
# Episodio 916 con pago -200.0
# Episodio 917 con pago -200.0
# Episodio 918 con pago -200.0
# Episodio 919 con pago -200.0
# Episodio 920 con pago -200.0
# Episodio 921 con pago -200.0
# Episodio 922 con pago -178.0
# Episodio 923 con pago -200.0
# Episodio 924 con pago -181.0
# Episodio 925 con pago -200.0
# Episodio 926 con pago -200.0
# Episodio 927 con pago -200.0
# Episodio 928 con pago -167.0
# Episodio 929 con pago -200.0
# Episodio 930 con pago -163.0
# Episodio 931 con pago -186.0
# Episodio 932 con pago -200.0
# Episodio 933 con pago -200.0
# Episodio 934 con pago -175.0
# Episodio 935 con pago -162.0
# Episodio 936 con pago -200.0
# Episodio 937 con pago -200.0
# Episodio 938 con pago -200.0
# Episodio 939 con pago -200.0
# Episodio 940 con pago -200.0
# Episodio 941 con pago -200.0
# Episodio 942 con pago -200.0
# Episodio 943 con pago -200.0
# Episodio 944 con pago -200.0
# Episodio 945 con pago -200.0
# Episodio 946 con pago -200.0
# Episodio 947 con pago -200.0
# Episodio 948 con pago -200.0
# Episodio 949 con pago -200.0
# Episodio 950 con pago -200.0
# Episodio 951 con pago -200.0
# Episodio 952 con pago -200.0
# Episodio 953 con pago -200.0
# Episodio 954 con pago -200.0
# Episodio 955 con pago -192.0
# Episodio 956 con pago -200.0
# Episodio 957 con pago -200.0
# Episodio 958 con pago -200.0
# Episodio 959 con pago -200.0
# Episodio 960 con pago -200.0
# Episodio 961 con pago -200.0
# Episodio 962 con pago -200.0
# Episodio 963 con pago -164.0
# Episodio 964 con pago -200.0
# Episodio 965 con pago -200.0
# Episodio 966 con pago -200.0
# Episodio 967 con pago -200.0
# Episodio 968 con pago -200.0
# Episodio 969 con pago -164.0
# Episodio 970 con pago -200.0
# Episodio 971 con pago -200.0
# Episodio 972 con pago -200.0
# Episodio 973 con pago -200.0
# Episodio 974 con pago -200.0
# Episodio 975 con pago -200.0
# Episodio 976 con pago -200.0
# Episodio 977 con pago -200.0
# Episodio 978 con pago -200.0
# Episodio 979 con pago -200.0
# Episodio 980 con pago -200.0
# Episodio 981 con pago -167.0
# Episodio 982 con pago -200.0
# Episodio 983 con pago -168.0
# Episodio 984 con pago -200.0
# Episodio 985 con pago -165.0
# Episodio 986 con pago -200.0
# Episodio 987 con pago -159.0
# Episodio 988 con pago -200.0
# Episodio 989 con pago -200.0
# Episodio 990 con pago -200.0
# Episodio 991 con pago -200.0
# Episodio 992 con pago -200.0
# Episodio 993 con pago -165.0
# Episodio 994 con pago -200.0
# Episodio 995 con pago -200.0
# Episodio 996 con pago -200.0
# Episodio 997 con pago -200.0
# Episodio 998 con pago -200.0
# Episodio 999 con pago -200.0
# Episodio 1000 con pago -200.0
# Episodio 1001 con pago -200.0
# Episodio 1002 con pago -200.0
# Episodio 1003 con pago -200.0
# Episodio 1004 con pago -200.0
# Episodio 1005 con pago -200.0
# Episodio 1006 con pago -200.0
# Episodio 1007 con pago -200.0
# Episodio 1008 con pago -200.0
# Episodio 1009 con pago -200.0
# Episodio 1010 con pago -200.0
# Episodio 1011 con pago -200.0
# Episodio 1012 con pago -200.0
# Episodio 1013 con pago -200.0
# Episodio 1014 con pago -200.0
# Episodio 1015 con pago -200.0
# Episodio 1016 con pago -200.0
# Episodio 1017 con pago -200.0
# Episodio 1018 con pago -200.0
# Episodio 1019 con pago -200.0
# Episodio 1020 con pago -200.0
# Episodio 1021 con pago -200.0
# Episodio 1022 con pago -200.0
# Episodio 1023 con pago -200.0
# Episodio 1024 con pago -200.0
# Episodio 1025 con pago -200.0
# Episodio 1026 con pago -200.0
# Episodio 1027 con pago -200.0
# Episodio 1028 con pago -200.0
# Episodio 1029 con pago -167.0
# Episodio 1030 con pago -181.0
# Episodio 1031 con pago -200.0
# Episodio 1032 con pago -140.0
# Episodio 1033 con pago -200.0
# Episodio 1034 con pago -200.0
# Episodio 1035 con pago -149.0
# Episodio 1036 con pago -200.0
# Episodio 1037 con pago -200.0
# Episodio 1038 con pago -165.0
# Episodio 1039 con pago -200.0
# Episodio 1040 con pago -179.0
# Episodio 1041 con pago -149.0
# Episodio 1042 con pago -200.0
# Episodio 1043 con pago -200.0
# Episodio 1044 con pago -200.0
# Episodio 1045 con pago -200.0
# Episodio 1046 con pago -200.0
# Episodio 1047 con pago -200.0
# Episodio 1048 con pago -200.0
# Episodio 1049 con pago -200.0
# Episodio 1050 con pago -200.0
# Episodio 1051 con pago -200.0
# Episodio 1052 con pago -200.0
# Episodio 1053 con pago -196.0
# Episodio 1054 con pago -200.0
# Episodio 1055 con pago -200.0
# Episodio 1056 con pago -200.0
# Episodio 1057 con pago -200.0
# Episodio 1058 con pago -200.0
# Episodio 1059 con pago -200.0
# Episodio 1060 con pago -200.0
# Episodio 1061 con pago -200.0
# Episodio 1062 con pago -200.0
# Episodio 1063 con pago -200.0
# Episodio 1064 con pago -200.0
# Episodio 1065 con pago -200.0
# Episodio 1066 con pago -200.0
# Episodio 1067 con pago -200.0
# Episodio 1068 con pago -200.0
# Episodio 1069 con pago -163.0
# Episodio 1070 con pago -156.0
# Episodio 1071 con pago -152.0
# Episodio 1072 con pago -142.0
# Episodio 1073 con pago -151.0
# Episodio 1074 con pago -167.0
# Episodio 1075 con pago -175.0
# Episodio 1076 con pago -200.0
# Episodio 1077 con pago -200.0
# Episodio 1078 con pago -123.0
# Episodio 1079 con pago -200.0
# Episodio 1080 con pago -200.0
# Episodio 1081 con pago -200.0
# Episodio 1082 con pago -200.0
# Episodio 1083 con pago -173.0
# Episodio 1084 con pago -200.0
# Episodio 1085 con pago -200.0
# Episodio 1086 con pago -200.0
# Episodio 1087 con pago -200.0
# Episodio 1088 con pago -200.0
# Episodio 1089 con pago -140.0
# Episodio 1090 con pago -200.0
# Episodio 1091 con pago -200.0
# Episodio 1092 con pago -200.0
# Episodio 1093 con pago -200.0
# Episodio 1094 con pago -200.0
# Episodio 1095 con pago -200.0
# Episodio 1096 con pago -200.0
# Episodio 1097 con pago -200.0
# Episodio 1098 con pago -200.0
# Episodio 1099 con pago -200.0
# Episodio 1100 con pago -200.0
# Episodio 1101 con pago -200.0
# Episodio 1102 con pago -160.0
# Episodio 1103 con pago -182.0
# Episodio 1104 con pago -160.0
# Episodio 1105 con pago -200.0
# Episodio 1106 con pago -200.0
# Episodio 1107 con pago -200.0
# Episodio 1108 con pago -200.0
# Episodio 1109 con pago -200.0
# Episodio 1110 con pago -200.0
# Episodio 1111 con pago -200.0
# Episodio 1112 con pago -200.0
# Episodio 1113 con pago -200.0
# Episodio 1114 con pago -200.0
# Episodio 1115 con pago -200.0
# Episodio 1116 con pago -200.0
# Episodio 1117 con pago -200.0
# Episodio 1118 con pago -200.0
# Episodio 1119 con pago -200.0
# Episodio 1120 con pago -200.0
# Episodio 1121 con pago -200.0
# Episodio 1122 con pago -200.0
# Episodio 1123 con pago -200.0
# Episodio 1124 con pago -200.0
# Episodio 1125 con pago -200.0
# Episodio 1126 con pago -200.0
# Episodio 1127 con pago -200.0
# Episodio 1128 con pago -200.0
# Episodio 1129 con pago -200.0
# Episodio 1130 con pago -200.0
# Episodio 1131 con pago -195.0
# Episodio 1132 con pago -200.0
# Episodio 1133 con pago -200.0
# Episodio 1134 con pago -200.0
# Episodio 1135 con pago -200.0
# Episodio 1136 con pago -200.0
# Episodio 1137 con pago -200.0
# Episodio 1138 con pago -200.0
# Episodio 1139 con pago -200.0
# Episodio 1140 con pago -200.0
# Episodio 1141 con pago -200.0
# Episodio 1142 con pago -200.0
# Episodio 1143 con pago -200.0
# Episodio 1144 con pago -173.0
# Episodio 1145 con pago -200.0
# Episodio 1146 con pago -200.0
# Episodio 1147 con pago -200.0
# Episodio 1148 con pago -200.0
# Episodio 1149 con pago -200.0
# Episodio 1150 con pago -200.0
# Episodio 1151 con pago -200.0
# Episodio 1152 con pago -200.0
# Episodio 1153 con pago -200.0
# Episodio 1154 con pago -200.0
# Episodio 1155 con pago -200.0
# Episodio 1156 con pago -200.0
# Episodio 1157 con pago -200.0
# Episodio 1158 con pago -200.0
# Episodio 1159 con pago -200.0
# Episodio 1160 con pago -200.0
# Episodio 1161 con pago -200.0
# Episodio 1162 con pago -200.0
# Episodio 1163 con pago -200.0
# Episodio 1164 con pago -200.0
# Episodio 1165 con pago -200.0
# Episodio 1166 con pago -200.0
# Episodio 1167 con pago -200.0
# Episodio 1168 con pago -200.0
# Episodio 1169 con pago -200.0
# Episodio 1170 con pago -200.0
# Episodio 1171 con pago -200.0
# Episodio 1172 con pago -200.0
# Episodio 1173 con pago -200.0
# Episodio 1174 con pago -200.0
# Episodio 1175 con pago -200.0
# Episodio 1176 con pago -167.0
# Episodio 1177 con pago -200.0
# Episodio 1178 con pago -200.0
# Episodio 1179 con pago -200.0
# Episodio 1180 con pago -200.0
# Episodio 1181 con pago -200.0
# Episodio 1182 con pago -200.0
# Episodio 1183 con pago -200.0
# Episodio 1184 con pago -200.0
# Episodio 1185 con pago -200.0
# Episodio 1186 con pago -200.0
# Episodio 1187 con pago -200.0
# Episodio 1188 con pago -200.0
# Episodio 1189 con pago -200.0
# Episodio 1190 con pago -200.0
# Episodio 1191 con pago -200.0
# Episodio 1192 con pago -200.0
# Episodio 1193 con pago -200.0
# Episodio 1194 con pago -200.0
# Episodio 1195 con pago -200.0
# Episodio 1196 con pago -153.0
# Episodio 1197 con pago -200.0
# Episodio 1198 con pago -200.0
# Episodio 1199 con pago -200.0
# Episodio 1200 con pago -200.0
# Episodio 1201 con pago -196.0
# Episodio 1202 con pago -200.0
# Episodio 1203 con pago -188.0
# Episodio 1204 con pago -200.0
# Episodio 1205 con pago -200.0
# Episodio 1206 con pago -200.0
# Episodio 1207 con pago -200.0
# Episodio 1208 con pago -200.0
# Episodio 1209 con pago -162.0
# Episodio 1210 con pago -200.0
# Episodio 1211 con pago -200.0
# Episodio 1212 con pago -200.0
# Episodio 1213 con pago -200.0
# Episodio 1214 con pago -200.0
# Episodio 1215 con pago -177.0
# Episodio 1216 con pago -200.0
# Episodio 1217 con pago -200.0
# Episodio 1218 con pago -200.0
# Episodio 1219 con pago -200.0
# Episodio 1220 con pago -164.0
# Episodio 1221 con pago -200.0
# Episodio 1222 con pago -162.0
# Episodio 1223 con pago -200.0
# Episodio 1224 con pago -200.0
# Episodio 1225 con pago -200.0
# Episodio 1226 con pago -193.0
# Episodio 1227 con pago -200.0
# Episodio 1228 con pago -200.0
# Episodio 1229 con pago -200.0
# Episodio 1230 con pago -200.0
# Episodio 1231 con pago -200.0
# Episodio 1232 con pago -200.0
# Episodio 1233 con pago -200.0
# Episodio 1234 con pago -188.0
# Episodio 1235 con pago -200.0
# Episodio 1236 con pago -200.0
# Episodio 1237 con pago -200.0
# Episodio 1238 con pago -200.0
# Episodio 1239 con pago -200.0
# Episodio 1240 con pago -200.0
# Episodio 1241 con pago -175.0
# Episodio 1242 con pago -200.0
# Episodio 1243 con pago -200.0
# Episodio 1244 con pago -200.0
# Episodio 1245 con pago -158.0
# Episodio 1246 con pago -200.0
# Episodio 1247 con pago -156.0
# Episodio 1248 con pago -200.0
# Episodio 1249 con pago -200.0
# Episodio 1250 con pago -165.0
# Episodio 1251 con pago -172.0
# Episodio 1252 con pago -171.0
# Episodio 1253 con pago -168.0
# Episodio 1254 con pago -168.0
# Episodio 1255 con pago -163.0
# Episodio 1256 con pago -200.0
# Episodio 1257 con pago -160.0
# Episodio 1258 con pago -161.0
# Episodio 1259 con pago -182.0
# Episodio 1260 con pago -200.0
# Episodio 1261 con pago -200.0
# Episodio 1262 con pago -200.0
# Episodio 1263 con pago -200.0
# Episodio 1264 con pago -200.0
# Episodio 1265 con pago -200.0
# Episodio 1266 con pago -200.0
# Episodio 1267 con pago -200.0
# Episodio 1268 con pago -157.0
# Episodio 1269 con pago -160.0
# Episodio 1270 con pago -171.0
# Episodio 1271 con pago -155.0
# Episodio 1272 con pago -192.0
# Episodio 1273 con pago -158.0
# Episodio 1274 con pago -200.0
# Episodio 1275 con pago -152.0
# Episodio 1276 con pago -186.0
# Episodio 1277 con pago -200.0
# Episodio 1278 con pago -200.0
# Episodio 1279 con pago -200.0
# Episodio 1280 con pago -200.0
# Episodio 1281 con pago -200.0
# Episodio 1282 con pago -169.0
# Episodio 1283 con pago -200.0
# Episodio 1284 con pago -200.0
# Episodio 1285 con pago -200.0
# Episodio 1286 con pago -200.0
# Episodio 1287 con pago -200.0
# Episodio 1288 con pago -200.0
# Episodio 1289 con pago -200.0
# Episodio 1290 con pago -150.0
# Episodio 1291 con pago -200.0
# Episodio 1292 con pago -200.0
# Episodio 1293 con pago -200.0
# Episodio 1294 con pago -200.0
# Episodio 1295 con pago -163.0
# Episodio 1296 con pago -159.0
# Episodio 1297 con pago -159.0
# Episodio 1298 con pago -161.0
# Episodio 1299 con pago -161.0
# Episodio 1300 con pago -156.0
# Episodio 1301 con pago -158.0
# Episodio 1302 con pago -165.0
# Episodio 1303 con pago -200.0
# Episodio 1304 con pago -158.0
# Episodio 1305 con pago -166.0
# Episodio 1306 con pago -157.0
# Episodio 1307 con pago -165.0
# Episodio 1308 con pago -149.0
# Episodio 1309 con pago -151.0
# Episodio 1310 con pago -161.0
# Episodio 1311 con pago -152.0
# Episodio 1312 con pago -154.0
# Episodio 1313 con pago -148.0
# Episodio 1314 con pago -145.0
# Episodio 1315 con pago -151.0
# Episodio 1316 con pago -150.0
# Episodio 1317 con pago -158.0
# Episodio 1318 con pago -157.0
# Episodio 1319 con pago -153.0
# Episodio 1320 con pago -191.0
# Episodio 1321 con pago -164.0
# Episodio 1322 con pago -179.0
# Episodio 1323 con pago -163.0
# Episodio 1324 con pago -161.0
# Episodio 1325 con pago -161.0
# Episodio 1326 con pago -176.0
# Episodio 1327 con pago -171.0
# Episodio 1328 con pago -156.0
# Episodio 1329 con pago -187.0
# Episodio 1330 con pago -172.0
# Episodio 1331 con pago -156.0
# Episodio 1332 con pago -200.0
# Episodio 1333 con pago -170.0
# Episodio 1334 con pago -200.0
# Episodio 1335 con pago -200.0
# Episodio 1336 con pago -200.0
# Episodio 1337 con pago -200.0
# Episodio 1338 con pago -200.0
# Episodio 1339 con pago -200.0
# Episodio 1340 con pago -200.0
# Episodio 1341 con pago -200.0
# Episodio 1342 con pago -200.0
# Episodio 1343 con pago -200.0
# Episodio 1344 con pago -200.0
# Episodio 1345 con pago -200.0
# Episodio 1346 con pago -200.0
# Episodio 1347 con pago -200.0
# Episodio 1348 con pago -200.0
# Episodio 1349 con pago -200.0
# Episodio 1350 con pago -200.0
# Episodio 1351 con pago -200.0
# Episodio 1352 con pago -199.0
# Episodio 1353 con pago -195.0
# Episodio 1354 con pago -200.0
# Episodio 1355 con pago -200.0
# Episodio 1356 con pago -200.0
# Episodio 1357 con pago -200.0
# Episodio 1358 con pago -161.0
# Episodio 1359 con pago -200.0
# Episodio 1360 con pago -200.0
# Episodio 1361 con pago -149.0
# Episodio 1362 con pago -200.0
# Episodio 1363 con pago -148.0
# Episodio 1364 con pago -200.0
# Episodio 1365 con pago -200.0
# Episodio 1366 con pago -200.0
# Episodio 1367 con pago -200.0
# Episodio 1368 con pago -200.0
# Episodio 1369 con pago -200.0
# Episodio 1370 con pago -200.0
# Episodio 1371 con pago -187.0
# Episodio 1372 con pago -166.0
# Episodio 1373 con pago -200.0
# Episodio 1374 con pago -200.0
# Episodio 1375 con pago -200.0
# Episodio 1376 con pago -200.0
# Episodio 1377 con pago -200.0
# Episodio 1378 con pago -200.0
# Episodio 1379 con pago -200.0
# Episodio 1380 con pago -200.0
# Episodio 1381 con pago -200.0
# Episodio 1382 con pago -200.0
# Episodio 1383 con pago -200.0
# Episodio 1384 con pago -190.0
# Episodio 1385 con pago -199.0
# Episodio 1386 con pago -194.0
# Episodio 1387 con pago -200.0
# Episodio 1388 con pago -189.0
# Episodio 1389 con pago -200.0
# Episodio 1390 con pago -200.0
# Episodio 1391 con pago -200.0
# Episodio 1392 con pago -184.0
# Episodio 1393 con pago -200.0
# Episodio 1394 con pago -200.0
# Episodio 1395 con pago -152.0
# Episodio 1396 con pago -200.0
# Episodio 1397 con pago -200.0
# Episodio 1398 con pago -200.0
# Episodio 1399 con pago -200.0
# Episodio 1400 con pago -200.0
# Episodio 1401 con pago -200.0
# Episodio 1402 con pago -200.0
# Episodio 1403 con pago -152.0
# Episodio 1404 con pago -200.0
# Episodio 1405 con pago -173.0
# Episodio 1406 con pago -149.0
# Episodio 1407 con pago -156.0
# Episodio 1408 con pago -200.0
# Episodio 1409 con pago -200.0
# Episodio 1410 con pago -156.0
# Episodio 1411 con pago -155.0
# Episodio 1412 con pago -149.0
# Episodio 1413 con pago -164.0
# Episodio 1414 con pago -155.0
# Episodio 1415 con pago -160.0
# Episodio 1416 con pago -155.0
# Episodio 1417 con pago -148.0
# Episodio 1418 con pago -148.0
# Episodio 1419 con pago -160.0
# Episodio 1420 con pago -161.0
# Episodio 1421 con pago -161.0
# Episodio 1422 con pago -162.0
# Episodio 1423 con pago -166.0
# Episodio 1424 con pago -160.0
# Episodio 1425 con pago -161.0
# Episodio 1426 con pago -171.0
# Episodio 1427 con pago -157.0
# Episodio 1428 con pago -165.0
# Episodio 1429 con pago -162.0
# Episodio 1430 con pago -158.0
# Episodio 1431 con pago -161.0
# Episodio 1432 con pago -165.0
# Episodio 1433 con pago -168.0
# Episodio 1434 con pago -166.0
# Episodio 1435 con pago -175.0
# Episodio 1436 con pago -172.0
# Episodio 1437 con pago -176.0
# Episodio 1438 con pago -172.0
# Episodio 1439 con pago -177.0
# Episodio 1440 con pago -158.0
# Episodio 1441 con pago -164.0
# Episodio 1442 con pago -182.0
# Episodio 1443 con pago -200.0
# Episodio 1444 con pago -157.0
# Episodio 1445 con pago -161.0
# Episodio 1446 con pago -160.0
# Episodio 1447 con pago -166.0
# Episodio 1448 con pago -162.0
# Episodio 1449 con pago -164.0
# Episodio 1450 con pago -200.0
# Episodio 1451 con pago -172.0
# Episodio 1452 con pago -167.0
# Episodio 1453 con pago -175.0
# Episodio 1454 con pago -158.0
# Episodio 1455 con pago -158.0
# Episodio 1456 con pago -159.0
# Episodio 1457 con pago -157.0
# Episodio 1458 con pago -162.0
# Episodio 1459 con pago -157.0
# Episodio 1460 con pago -160.0
# Episodio 1461 con pago -156.0
# Episodio 1462 con pago -154.0
# Episodio 1463 con pago -164.0
# Episodio 1464 con pago -200.0
# Episodio 1465 con pago -159.0
# Episodio 1466 con pago -200.0
# Episodio 1467 con pago -159.0
# Episodio 1468 con pago -200.0
# Episodio 1469 con pago -200.0
# Episodio 1470 con pago -200.0
# Episodio 1471 con pago -200.0
# Episodio 1472 con pago -200.0
# Episodio 1473 con pago -200.0
# Episodio 1474 con pago -200.0
# Episodio 1475 con pago -200.0
# Episodio 1476 con pago -200.0
# Episodio 1477 con pago -200.0
# Episodio 1478 con pago -167.0
# Episodio 1479 con pago -200.0
# Episodio 1480 con pago -200.0
# Episodio 1481 con pago -200.0
# Episodio 1482 con pago -200.0
# Episodio 1483 con pago -200.0
# Episodio 1484 con pago -200.0
# Episodio 1485 con pago -200.0
# Episodio 1486 con pago -200.0
# Episodio 1487 con pago -175.0
# Episodio 1488 con pago -162.0
# Episodio 1489 con pago -152.0
# Episodio 1490 con pago -155.0
# Episodio 1491 con pago -159.0
# Episodio 1492 con pago -172.0
# Episodio 1493 con pago -157.0
# Episodio 1494 con pago -155.0
# Episodio 1495 con pago -152.0
# Episodio 1496 con pago -165.0
# Episodio 1497 con pago -156.0
# Episodio 1498 con pago -151.0
# Episodio 1499 con pago -167.0
# Episodio 1500 con pago -200.0
# Episodio 1501 con pago -200.0
# Episodio 1502 con pago -159.0
# Episodio 1503 con pago -162.0
# Episodio 1504 con pago -171.0
# Episodio 1505 con pago -200.0
# Episodio 1506 con pago -200.0
# Episodio 1507 con pago -173.0
# Episodio 1508 con pago -200.0
# Episodio 1509 con pago -200.0
# Episodio 1510 con pago -162.0
# Episodio 1511 con pago -200.0
# Episodio 1512 con pago -200.0
# Episodio 1513 con pago -200.0
# Episodio 1514 con pago -200.0
# Episodio 1515 con pago -161.0
# Episodio 1516 con pago -200.0
# Episodio 1517 con pago -200.0
# Episodio 1518 con pago -200.0
# Episodio 1519 con pago -172.0
# Episodio 1520 con pago -157.0
# Episodio 1521 con pago -200.0
# Episodio 1522 con pago -200.0
# Episodio 1523 con pago -200.0
# Episodio 1524 con pago -200.0
# Episodio 1525 con pago -200.0
# Episodio 1526 con pago -200.0
# Episodio 1527 con pago -164.0
# Episodio 1528 con pago -200.0
# Episodio 1529 con pago -200.0
# Episodio 1530 con pago -146.0
# Episodio 1531 con pago -146.0
# Episodio 1532 con pago -177.0
# Episodio 1533 con pago -152.0
# Episodio 1534 con pago -174.0
# Episodio 1535 con pago -200.0
# Episodio 1536 con pago -200.0
# Episodio 1537 con pago -166.0
# Episodio 1538 con pago -200.0
# Episodio 1539 con pago -153.0
# Episodio 1540 con pago -148.0
# Episodio 1541 con pago -155.0
# Episodio 1542 con pago -164.0
# Episodio 1543 con pago -164.0
# Episodio 1544 con pago -152.0
# Episodio 1545 con pago -149.0
# Episodio 1546 con pago -153.0
# Episodio 1547 con pago -159.0
# Episodio 1548 con pago -149.0
# Episodio 1549 con pago -156.0
# Episodio 1550 con pago -161.0
# Episodio 1551 con pago -149.0
# Episodio 1552 con pago -152.0
# Episodio 1553 con pago -145.0
# Episodio 1554 con pago -155.0
# Episodio 1555 con pago -159.0
# Episodio 1556 con pago -146.0
# Episodio 1557 con pago -200.0
# Episodio 1558 con pago -200.0
# Episodio 1559 con pago -200.0
# Episodio 1560 con pago -200.0
# Episodio 1561 con pago -200.0
# Episodio 1562 con pago -200.0
# Episodio 1563 con pago -200.0
# Episodio 1564 con pago -197.0
# Episodio 1565 con pago -200.0
# Episodio 1566 con pago -200.0
# Episodio 1567 con pago -200.0
# Episodio 1568 con pago -200.0
# Episodio 1569 con pago -200.0
# Episodio 1570 con pago -200.0
# Episodio 1571 con pago -200.0
# Episodio 1572 con pago -200.0
# Episodio 1573 con pago -200.0
# Episodio 1574 con pago -200.0
# Episodio 1575 con pago -200.0
# Episodio 1576 con pago -155.0
# Episodio 1577 con pago -200.0
# Episodio 1578 con pago -200.0
# Episodio 1579 con pago -155.0
# Episodio 1580 con pago -140.0
# Episodio 1581 con pago -200.0
# Episodio 1582 con pago -200.0
# Episodio 1583 con pago -200.0
# Episodio 1584 con pago -200.0
# Episodio 1585 con pago -200.0
# Episodio 1586 con pago -200.0
# Episodio 1587 con pago -200.0
# Episodio 1588 con pago -200.0
# Episodio 1589 con pago -200.0
# Episodio 1590 con pago -200.0
# Episodio 1591 con pago -200.0
# Episodio 1592 con pago -200.0
# Episodio 1593 con pago -200.0
# Episodio 1594 con pago -200.0
# Episodio 1595 con pago -200.0
# Episodio 1596 con pago -200.0
# Episodio 1597 con pago -195.0
# Episodio 1598 con pago -200.0
# Episodio 1599 con pago -186.0
# Episodio 1600 con pago -200.0
# Episodio 1601 con pago -200.0
# Episodio 1602 con pago -155.0
# Episodio 1603 con pago -200.0
# Episodio 1604 con pago -200.0
# Episodio 1605 con pago -200.0
# Episodio 1606 con pago -200.0
# Episodio 1607 con pago -200.0
# Episodio 1608 con pago -200.0
# Episodio 1609 con pago -200.0
# Episodio 1610 con pago -200.0
# Episodio 1611 con pago -200.0
# Episodio 1612 con pago -200.0
# Episodio 1613 con pago -200.0
# Episodio 1614 con pago -164.0
# Episodio 1615 con pago -129.0
# Episodio 1616 con pago -200.0
# Episodio 1617 con pago -200.0
# Episodio 1618 con pago -164.0
# Episodio 1619 con pago -200.0
# Episodio 1620 con pago -200.0
# Episodio 1621 con pago -179.0
# Episodio 1622 con pago -177.0
# Episodio 1623 con pago -159.0
# Episodio 1624 con pago -200.0
# Episodio 1625 con pago -172.0
# Episodio 1626 con pago -200.0
# Episodio 1627 con pago -200.0
# Episodio 1628 con pago -200.0
# Episodio 1629 con pago -167.0
# Episodio 1630 con pago -200.0
# Episodio 1631 con pago -200.0
# Episodio 1632 con pago -160.0
# Episodio 1633 con pago -161.0
# Episodio 1634 con pago -200.0
# Episodio 1635 con pago -162.0
# Episodio 1636 con pago -200.0
# Episodio 1637 con pago -200.0
# Episodio 1638 con pago -154.0
# Episodio 1639 con pago -200.0
# Episodio 1640 con pago -166.0
# Episodio 1641 con pago -160.0
# Episodio 1642 con pago -169.0
# Episodio 1643 con pago -200.0
# Episodio 1644 con pago -200.0
# Episodio 1645 con pago -200.0
# Episodio 1646 con pago -200.0
# Episodio 1647 con pago -200.0
# Episodio 1648 con pago -170.0
# Episodio 1649 con pago -200.0
# Episodio 1650 con pago -200.0
# Episodio 1651 con pago -200.0
# Episodio 1652 con pago -200.0
# Episodio 1653 con pago -200.0
# Episodio 1654 con pago -200.0
# Episodio 1655 con pago -200.0
# Episodio 1656 con pago -200.0
# Episodio 1657 con pago -200.0
# Episodio 1658 con pago -200.0
# Episodio 1659 con pago -200.0
# Episodio 1660 con pago -200.0
# Episodio 1661 con pago -200.0
# Episodio 1662 con pago -200.0
# Episodio 1663 con pago -200.0
# Episodio 1664 con pago -200.0
# Episodio 1665 con pago -200.0
# Episodio 1666 con pago -200.0
# Episodio 1667 con pago -170.0
# Episodio 1668 con pago -200.0
# Episodio 1669 con pago -200.0
# Episodio 1670 con pago -200.0
# Episodio 1671 con pago -200.0
# Episodio 1672 con pago -200.0
# Episodio 1673 con pago -200.0
# Episodio 1674 con pago -200.0
# Episodio 1675 con pago -200.0
# Episodio 1676 con pago -200.0
# Episodio 1677 con pago -200.0
# Episodio 1678 con pago -200.0
# Episodio 1679 con pago -200.0
# Episodio 1680 con pago -154.0
# Episodio 1681 con pago -200.0
# Episodio 1682 con pago -154.0
# Episodio 1683 con pago -200.0
# Episodio 1684 con pago -200.0
# Episodio 1685 con pago -200.0
# Episodio 1686 con pago -158.0
# Episodio 1687 con pago -200.0
# Episodio 1688 con pago -151.0
# Episodio 1689 con pago -159.0
# Episodio 1690 con pago -200.0
# Episodio 1691 con pago -200.0
# Episodio 1692 con pago -200.0
# Episodio 1693 con pago -200.0
# Episodio 1694 con pago -200.0
# Episodio 1695 con pago -200.0
# Episodio 1696 con pago -200.0
# Episodio 1697 con pago -200.0
# Episodio 1698 con pago -200.0
# Episodio 1699 con pago -200.0
# Episodio 1700 con pago -199.0
# Episodio 1701 con pago -200.0
# Episodio 1702 con pago -200.0
# Episodio 1703 con pago -200.0
# Episodio 1704 con pago -200.0
# Episodio 1705 con pago -200.0
# Episodio 1706 con pago -200.0
# Episodio 1707 con pago -200.0
# Episodio 1708 con pago -200.0
# Episodio 1709 con pago -200.0
# Episodio 1710 con pago -200.0
# Episodio 1711 con pago -175.0
# Episodio 1712 con pago -200.0
# Episodio 1713 con pago -161.0
# Episodio 1714 con pago -200.0
# Episodio 1715 con pago -200.0
# Episodio 1716 con pago -200.0
# Episodio 1717 con pago -200.0
# Episodio 1718 con pago -200.0
# Episodio 1719 con pago -200.0
# Episodio 1720 con pago -164.0
# Episodio 1721 con pago -200.0
# Episodio 1722 con pago -200.0
# Episodio 1723 con pago -200.0
# Episodio 1724 con pago -200.0
# Episodio 1725 con pago -200.0
# Episodio 1726 con pago -200.0
# Episodio 1727 con pago -200.0
# Episodio 1728 con pago -200.0
# Episodio 1729 con pago -200.0
# Episodio 1730 con pago -200.0
# Episodio 1731 con pago -200.0
# Episodio 1732 con pago -200.0
# Episodio 1733 con pago -200.0
# Episodio 1734 con pago -178.0
# Episodio 1735 con pago -187.0
# Episodio 1736 con pago -200.0
# Episodio 1737 con pago -172.0
# Episodio 1738 con pago -200.0
# Episodio 1739 con pago -200.0
# Episodio 1740 con pago -200.0
# Episodio 1741 con pago -200.0
# Episodio 1742 con pago -200.0
# Episodio 1743 con pago -200.0
# Episodio 1744 con pago -200.0
# Episodio 1745 con pago -165.0
# Episodio 1746 con pago -172.0
# Episodio 1747 con pago -167.0
# Episodio 1748 con pago -169.0
# Episodio 1749 con pago -200.0
# Episodio 1750 con pago -170.0
# Episodio 1751 con pago -175.0
# Episodio 1752 con pago -200.0
# Episodio 1753 con pago -200.0
# Episodio 1754 con pago -200.0
# Episodio 1755 con pago -190.0
# Episodio 1756 con pago -200.0
# Episodio 1757 con pago -200.0
# Episodio 1758 con pago -182.0
# Episodio 1759 con pago -200.0
# Episodio 1760 con pago -174.0
# Episodio 1761 con pago -200.0
# Episodio 1762 con pago -200.0
# Episodio 1763 con pago -200.0
# Episodio 1764 con pago -200.0
# Episodio 1765 con pago -200.0
# Episodio 1766 con pago -190.0
# Episodio 1767 con pago -167.0
# Episodio 1768 con pago -200.0
# Episodio 1769 con pago -200.0
# Episodio 1770 con pago -200.0
# Episodio 1771 con pago -200.0
# Episodio 1772 con pago -200.0
# Episodio 1773 con pago -200.0
# Episodio 1774 con pago -200.0
# Episodio 1775 con pago -200.0
# Episodio 1776 con pago -200.0
# Episodio 1777 con pago -200.0
# Episodio 1778 con pago -200.0
# Episodio 1779 con pago -163.0
# Episodio 1780 con pago -140.0
# Episodio 1781 con pago -176.0
# Episodio 1782 con pago -156.0
# Episodio 1783 con pago -152.0
# Episodio 1784 con pago -166.0
# Episodio 1785 con pago -154.0
# Episodio 1786 con pago -200.0
# Episodio 1787 con pago -200.0
# Episodio 1788 con pago -200.0
# Episodio 1789 con pago -200.0
# Episodio 1790 con pago -184.0
# Episodio 1791 con pago -199.0
# Episodio 1792 con pago -192.0
# Episodio 1793 con pago -170.0
# Episodio 1794 con pago -200.0
# Episodio 1795 con pago -167.0
# Episodio 1796 con pago -200.0
# Episodio 1797 con pago -200.0
# Episodio 1798 con pago -200.0
# Episodio 1799 con pago -200.0
# Episodio 1800 con pago -182.0
# Episodio 1801 con pago -200.0
# Episodio 1802 con pago -174.0
# Episodio 1803 con pago -200.0
# Episodio 1804 con pago -200.0
# Episodio 1805 con pago -167.0
# Episodio 1806 con pago -174.0
# Episodio 1807 con pago -163.0
# Episodio 1808 con pago -172.0
# Episodio 1809 con pago -186.0
# Episodio 1810 con pago -176.0
# Episodio 1811 con pago -200.0
# Episodio 1812 con pago -179.0
# Episodio 1813 con pago -180.0
# Episodio 1814 con pago -200.0
# Episodio 1815 con pago -162.0
# Episodio 1816 con pago -177.0
# Episodio 1817 con pago -200.0
# Episodio 1818 con pago -191.0
# Episodio 1819 con pago -200.0
# Episodio 1820 con pago -167.0
# Episodio 1821 con pago -200.0
# Episodio 1822 con pago -200.0
# Episodio 1823 con pago -200.0
# Episodio 1824 con pago -200.0
# Episodio 1825 con pago -200.0
# Episodio 1826 con pago -200.0
# Episodio 1827 con pago -200.0
# Episodio 1828 con pago -200.0
# Episodio 1829 con pago -200.0
# Episodio 1830 con pago -200.0
# Episodio 1831 con pago -200.0
# Episodio 1832 con pago -200.0
# Episodio 1833 con pago -175.0
# Episodio 1834 con pago -174.0
# Episodio 1835 con pago -163.0
# Episodio 1836 con pago -200.0
# Episodio 1837 con pago -166.0
# Episodio 1838 con pago -172.0
# Episodio 1839 con pago -160.0
# Episodio 1840 con pago -176.0
# Episodio 1841 con pago -168.0
# Episodio 1842 con pago -163.0
# Episodio 1843 con pago -158.0
# Episodio 1844 con pago -169.0
# Episodio 1845 con pago -179.0
# Episodio 1846 con pago -183.0
# Episodio 1847 con pago -200.0
# Episodio 1848 con pago -151.0
# Episodio 1849 con pago -200.0
# Episodio 1850 con pago -200.0
# Episodio 1851 con pago -200.0
# Episodio 1852 con pago -190.0
# Episodio 1853 con pago -151.0
# Episodio 1854 con pago -138.0
# Episodio 1855 con pago -147.0
# Episodio 1856 con pago -147.0
# Episodio 1857 con pago -145.0
# Episodio 1858 con pago -152.0
# Episodio 1859 con pago -155.0
# Episodio 1860 con pago -160.0
# Episodio 1861 con pago -200.0
# Episodio 1862 con pago -200.0
# Episodio 1863 con pago -189.0
# Episodio 1864 con pago -200.0
# Episodio 1865 con pago -200.0
# Episodio 1866 con pago -178.0
# Episodio 1867 con pago -164.0
# Episodio 1868 con pago -200.0
# Episodio 1869 con pago -200.0
# Episodio 1870 con pago -200.0
# Episodio 1871 con pago -200.0
# Episodio 1872 con pago -200.0
# Episodio 1873 con pago -184.0
# Episodio 1874 con pago -161.0
# Episodio 1875 con pago -162.0
# Episodio 1876 con pago -158.0
# Episodio 1877 con pago -172.0
# Episodio 1878 con pago -180.0
# Episodio 1879 con pago -167.0
# Episodio 1880 con pago -175.0
# Episodio 1881 con pago -200.0
# Episodio 1882 con pago -200.0
# Episodio 1883 con pago -200.0
# Episodio 1884 con pago -200.0
# Episodio 1885 con pago -200.0
# Episodio 1886 con pago -200.0
# Episodio 1887 con pago -165.0
# Episodio 1888 con pago -160.0
# Episodio 1889 con pago -158.0
# Episodio 1890 con pago -200.0
# Episodio 1891 con pago -185.0
# Episodio 1892 con pago -200.0
# Episodio 1893 con pago -158.0
# Episodio 1894 con pago -166.0
# Episodio 1895 con pago -160.0
# Episodio 1896 con pago -200.0
# Episodio 1897 con pago -200.0
# Episodio 1898 con pago -200.0
# Episodio 1899 con pago -200.0
# Episodio 1900 con pago -200.0
# Episodio 1901 con pago -200.0
# Episodio 1902 con pago -200.0
# Episodio 1903 con pago -200.0
# Episodio 1904 con pago -200.0
# Episodio 1905 con pago -200.0
# Episodio 1906 con pago -200.0
# Episodio 1907 con pago -177.0
# Episodio 1908 con pago -162.0
# Episodio 1909 con pago -175.0
# Episodio 1910 con pago -200.0
# Episodio 1911 con pago -172.0
# Episodio 1912 con pago -200.0
# Episodio 1913 con pago -200.0
# Episodio 1914 con pago -200.0
# Episodio 1915 con pago -160.0
# Episodio 1916 con pago -200.0
# Episodio 1917 con pago -200.0
# Episodio 1918 con pago -200.0
# Episodio 1919 con pago -200.0
# Episodio 1920 con pago -200.0
# Episodio 1921 con pago -200.0
# Episodio 1922 con pago -200.0
# Episodio 1923 con pago -200.0
# Episodio 1924 con pago -200.0
# Episodio 1925 con pago -200.0
# Episodio 1926 con pago -200.0
# Episodio 1927 con pago -200.0
# Episodio 1928 con pago -200.0
# Episodio 1929 con pago -200.0
# Episodio 1930 con pago -200.0
# Episodio 1931 con pago -200.0
# Episodio 1932 con pago -200.0
# Episodio 1933 con pago -200.0
# Episodio 1934 con pago -200.0
# Episodio 1935 con pago -200.0
# Episodio 1936 con pago -200.0
# Episodio 1937 con pago -200.0
# Episodio 1938 con pago -200.0
# Episodio 1939 con pago -200.0
# Episodio 1940 con pago -200.0
# Episodio 1941 con pago -200.0
# Episodio 1942 con pago -200.0
# Episodio 1943 con pago -200.0
# Episodio 1944 con pago -200.0
# Episodio 1945 con pago -200.0
# Episodio 1946 con pago -200.0
# Episodio 1947 con pago -200.0
# Episodio 1948 con pago -200.0
# Episodio 1949 con pago -200.0
# Episodio 1950 con pago -200.0
# Episodio 1951 con pago -200.0
# Episodio 1952 con pago -200.0
# Episodio 1953 con pago -200.0
# Episodio 1954 con pago -200.0
# Episodio 1955 con pago -200.0
# Episodio 1956 con pago -200.0
# Episodio 1957 con pago -200.0
# Episodio 1958 con pago -200.0
# Episodio 1959 con pago -200.0
# Episodio 1960 con pago -200.0
# Episodio 1961 con pago -200.0
# Episodio 1962 con pago -200.0
# Episodio 1963 con pago -200.0
# Episodio 1964 con pago -178.0
# Episodio 1965 con pago -171.0
# Episodio 1966 con pago -163.0
# Episodio 1967 con pago -168.0
# Episodio 1968 con pago -163.0
# Episodio 1969 con pago -200.0
# Episodio 1970 con pago -200.0
# Episodio 1971 con pago -200.0
# Episodio 1972 con pago -200.0
# Episodio 1973 con pago -166.0
# Episodio 1974 con pago -165.0
# Episodio 1975 con pago -161.0
# Episodio 1976 con pago -172.0
# Episodio 1977 con pago -172.0
# Episodio 1978 con pago -200.0
# Episodio 1979 con pago -180.0
# Episodio 1980 con pago -174.0
# Episodio 1981 con pago -200.0
# Episodio 1982 con pago -162.0
# Episodio 1983 con pago -157.0
# Episodio 1984 con pago -160.0
# Episodio 1985 con pago -169.0
# Episodio 1986 con pago -158.0
# Episodio 1987 con pago -173.0
# Episodio 1988 con pago -200.0
# Episodio 1989 con pago -152.0
# Episodio 1990 con pago -168.0
# Episodio 1991 con pago -172.0
# Episodio 1992 con pago -163.0
# Episodio 1993 con pago -168.0
# Episodio 1994 con pago -160.0
# Episodio 1995 con pago -170.0
# Episodio 1996 con pago -155.0
# Episodio 1997 con pago -200.0
# Episodio 1998 con pago -156.0
# Episodio 1999 con pago -163.0
# Episodio 2000 con pago -159.0
# (Dict{Any,Any}(Pair{Any,Any}((Float32[-0.24,-0.05],0),-53.792),Pair{Any,Any}((Float32[-0.48,-0.07],0),-1.71042),Pair{Any,Any}((Float32[0.36,0.05],2),-2.24177),Pair{Any,Any}((Float32[0.0,0.03],2),-45.4146),Pair{Any,Any}((Float32[-0.96,0.03],0),-53.9319),Pair{Any,Any}((Float32[-1.08,-0.01],0),-59.8119),Pair{Any,Any}((Float32[-0.96,0.03],2),-44.2811),Pair{Any,Any}((Float32[-0.36,0.05],1),-46.0131),Pair{Any,Any}((Float32[0.0,0.05],2),-27.7692),Pair{Any,Any}((Float32[-0.24,-0.03],1),-65.3071)…),Any[-200.0,-200.0,-200.0,-200.0,-200.0,-200.0,-200.0,-200.0,-200.0,-200.0  …  -172.0,-163.0,-168.0,-160.0,-170.0,-155.0,-200.0,-156.0,-163.0,-159.0],Any[200,200,200,200,200,200,200,200,200,200  …  172,163,168,160,170,155,200,156,163,159])

# %% [markdown]
# **EJEMPLO DE USO**

# %%
Pkg.add("Plots")
#Pkg.add("GR")
#Pkg.update()
using Plots; gr()
plot_every = 100
roll_mean = []
for i in 1:50
   push!(roll_mean, mean(reward_history[(plot_every*(i-1)+1):(plot_every*i)])) 
end
plot(roll_mean, title = "Retorno promedio en batches de 100 episodios")
# Out:
# INFO: Nothing to be done
# INFO: METADATA is out-of-date — you may not have the latest version of Plots
# INFO: Use `Pkg.update()` to get the latest versions of your packages
# BoundsError: attempt to access 2000-element Array{Any,1} at index [2001:2100]
#
#  in throw_boundserror(::Array{Any,1}, ::Tuple{UnitRange{Int64}}) at ./abstractarray.jl:363
#  in checkbounds at ./abstractarray.jl:292 [inlined]
#  in getindex(::Array{Any,1}, ::UnitRange{Int64}) at ./array.jl:392
#  in macro expansion; at ./In[23]:8 [inlined]
#  in anonymous at ./<missing>:?

# %% [markdown]
# ### <span style='color: red'> Ejercicio 4 </span>
#
# 1. Replica el codigo anterior de entrenamiento en 5000 episodios haciendo los cambios necesarios para aprender con Q-Learning en vez de SARSA.

# %%
"""
The following function plays a gym_episode and learns using Q-Learning. It receives a current estimate of Q and 
returns an improved estimate Q, the episode reward and the number of steps.
"""
function learn_episode_with_qlearning(
        gym_env, # an openai gym environment
        current_Q = Dict() # current estimation of Q
        ; # the rest are keyword argument, not positional arguments
        preprocess_state = x -> x, # state preprocessing, identity by default
        learning_rate = 0.1,
        discount_rate = 0.999,
        exploration_rate = 0.1,
        render = false, # show game visualization (slower when rendering...)
    )
    # Rename variables for formula simplicity following Sutton
    ϵ, α, γ = exploration_rate, learning_rate, discount_rate
    action_space = 0:(gym_env[:action_space][:n] - 1)
    Q = deepcopy(current_Q) # Q will store the improved Q estimate
    # Reset environment
    state = gym_env[:reset]() # regresa el ambiente al comienzo de un episodio
    state = preprocess_state(state)
    render && gym_env[:render]() # si render es true, crea la visualizacion del estado del juego
    # Get initial action
    action = policy(state, action_space, Q, ϵ) # selecionar accion con politica
    !haskey(Q, (state, action)) && (Q[(state, action)] = 0.) # add key if missing
    # Episode iteration information
    done = false # sera true cuando termine el episodio
    ep_reward = 0. # iniciar pago total en el episodio
    ep_steps = 0 # iniciar pasos totales en el episodio
    while !done 
        # Simulate transition
        new_state, reward, done, info = gym_env[:step](action) # simula una transicion
        new_state = preprocess_state(new_state)
        new_action = policy(new_state, action_space, Q, ϵ) # selecionar accion con politica
        !haskey(Q, (new_state, new_action)) && (Q[(new_state, new_action)] = 0.) # add key if missing
        # Compute δ
        max_Q = maximum([get(Q,(new_state,new_action),0.) for a in action_space])#Maximizo y obtengo la política optima
        δ = reward + γ*max_Q  - Q[(state, action)] 
        # Update Q 
        Q[(state, action)] = Q[(state, action)] + α*δ
        # Change new states to old states for next step
        state = new_state
        action = new_action
        # Save step information and render if needed
        render && gym_env[:render]()
        ep_reward += reward # agrega el pago de la transicion al pago del ep.
        ep_steps += 1 # agrega un paso al total de pasos en el episodio
    end
    render && gym_env[:render](close = true)
    return Q, ep_reward, ep_steps
end

# %%
function learn_episodes_with_qlearning(
        n_episodes, # number of episodes
        gym_env, # an openai gym environment
        current_Q = Dict() # current estimation of Q
        ; # the rest are keyword argument, not positional arguments
        preprocess_state = x -> x, # state preprocessing, identity by default
        learning_rate = 0.1,
        discount_rate = 0.999,
        exploration_rate = 0.1,
        exploration_decay =  1 - log(2) / n_episodes, # se reducira a la mitad al final del episodio
        render = false, # show game visualization (slower when rendering...)
        verbose = true
    )
    Q = deepcopy(current_Q)
    # Iterate episodes
    reward_history = []
    steps_history = []
    for i in 1:n_episodes
        # learn from episode
        Q, reward, steps = learn_episode_with_qlearning(gym_env, Q, 
                                                    learning_rate = learning_rate, 
                                                    discount_rate = discount_rate, 
                                                    exploration_rate = exploration_rate, 
                                                    render = render,
                                                    preprocess_state = preprocess_state)
        verbose && println("Episodio ", i, " con pago ", reward)
        # reduce exploration_rate
        exploration_rate *= exploration_decay
        # save episode information
        push!(reward_history, reward)
        push!(steps_history, steps)
    end
    return Q, reward_history, steps_history
end

# %%
Q = Dict()
Q, reward, steps = learn_episode_with_qlearning(mountain_car, Q, preprocess_state = preprocess, render = true)
# Out:
# (Dict{Any,Any}(Pair{Any,Any}((Float32[-0.6,0.01],0),-1.39414),Pair{Any,Any}((Float32[-0.36,-0.01],1),-0.399939),Pair{Any,Any}((Float32[-0.72,-0.01],0),-0.1),Pair{Any,Any}((Float32[-0.72,0.01],1),-0.19),Pair{Any,Any}((Float32[-0.72,0.01],0),-0.1),Pair{Any,Any}((Float32[-0.6,-0.01],2),-1.48362),Pair{Any,Any}((Float32[-0.48,0.01],1),-0.972331),Pair{Any,Any}((Float32[-0.6,-0.01],0),-1.62645),Pair{Any,Any}((Float32[-0.72,0.01],2),-0.19),Pair{Any,Any}((Float32[-0.48,-0.01],1),-1.28377)…),-200.0,200)

# %%
Q, reward_history, steps_history = learn_episodes_with_qlearning(
    2000, mountain_car, Dict(), 
    preprocess_state = preprocess,
    learning_rate = 0.05,
    exploration_rate = 0.25,
    exploration_decay = 1 - log(25) / 2000, # will reduce to 0.01 at the end of training
    render = true # be patient, enjoy watching, switch to false for speed
)
# Out:
# Episodio 1 con pago -200.0
# Episodio 2 con pago -200.0
# Episodio 3 con pago -200.0
# Episodio 4 con pago -200.0
# Episodio 5 con pago -200.0
# Episodio 6 con pago -200.0
# Episodio 7 con pago -200.0
# Episodio 8 con pago -200.0
# Episodio 9 con pago -200.0
# Episodio 10 con pago -200.0
# Episodio 11 con pago -200.0
# Episodio 12 con pago -200.0
# Episodio 13 con pago -200.0
# Episodio 14 con pago -200.0
# Episodio 15 con pago -200.0
# Episodio 16 con pago -200.0
# Episodio 17 con pago -200.0
# Episodio 18 con pago -200.0
# Episodio 19 con pago -200.0
# Episodio 20 con pago -200.0
# Episodio 21 con pago -200.0
# Episodio 22 con pago -200.0
